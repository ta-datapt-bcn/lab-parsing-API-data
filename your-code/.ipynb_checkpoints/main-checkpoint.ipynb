# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
# Import libraries.
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#Define the initial API endpoint URL.

url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}

# %%
#Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.

response = requests.get(url,headers=headers)
results = response.json()
results
# Out:
# {'total_count': 53198,
#  'pagination': {'page_count': 634, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'OS322T06P-Q11',
#    'name': 'ONSCOME TRUCKER   - Veste en jean - black denim',
#    'price': {'original': '33,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'only-and-sons-onscome-trucker-veste-en-jean-black-denim-os322t06p-q11',
#    'media': [{'path': 'OS/32/2T/06/PQ/11/OS322T06P-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'OS/32/2T/06/PQ/11/OS322T06P-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [{'sku': 'OS322T06P-Q11',
#      'url_key': 'only-and-sons-onscome-trucker-veste-en-jean-black-denim-os322t06p-q11',
#      'media': [{'path': 'OS/32/2T/06/PQ/11/OS322T06P-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'ONSCOME TRUCKER   - Veste en jean - black denim',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '33,99\xa0€',
#       'promotional': '27,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-18%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-18%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JAM22Q01I-K11',
#    'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - maritime blue',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-maritime-blue-jam22q01i-k11',
#    'media': [{'path': 'JA/M2/2Q/01/IK/11/JAM22Q01I-K11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JA/M2/2Q/01/IK/11/JAM22Q01I-K11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones PREMIUM',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JAM22Q01I-K11',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-maritime-blue-jam22q01i-k11',
#      'media': [{'path': 'JA/M2/2Q/01/IK/11/JAM22Q01I-K11@14.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - maritime blue',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '41,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JAM22Q01I-G11',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-jam22q01i-g11',
#      'media': [{'path': 'JA/M2/2Q/01/IG/11/JAM22Q01I-G11@23.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - fired brick',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,99\xa0€',
#       'promotional': '59,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JAM22Q01I-C12',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-jam22q01i-c12',
#      'media': [{'path': 'JA/M2/2Q/01/IC/12/JAM22Q01I-C12@20.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - grey melange',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '38,99\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JAM22Q01I-Q11',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-jam22q01i-q11',
#      'media': [{'path': 'JA/M2/2Q/01/IQ/11/JAM22Q01I-Q11@22.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,99\xa0€',
#       'promotional': '59,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JAM22Q01I-M11',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-jam22q01i-m11',
#      'media': [{'path': 'JA/M2/2Q/01/IM/11/JAM22Q01I-M11@21.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - darkest spruce',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,99\xa0€',
#       'promotional': '59,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JAM22Q01I-C11',
#      'url_key': 'jack-and-jones-premium-jprmark-crew-neck-pullover-jam22q01i-c11',
#      'media': [{'path': 'JA/M2/2Q/01/IC/11/JAM22Q01I-C11@14.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JPRMARK MERINO KNIT CREW NECK - Pullover - oatmeal melange',
#      'sizes': ['XS', 'S', 'M', 'L', 'XXL'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '41,99\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'C1822O04J-A11',
#    'name': 'CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé - bright white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L', 'XL', 'XXL'],
#    'url_key': 'calvin-klein-jeans-core-institutional-logo-slim-tee-t-shirt-imprime-c1822o04j-a11',
#    'media': [{'path': 'C1/82/2O/04/JA/11/C1822O04J-A11@20.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'C1/82/2O/04/JA/11/C1822O04J-A11@18.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Calvin Klein Jeans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'C1822O04J-A11',
#      'url_key': 'calvin-klein-jeans-core-institutional-logo-slim-tee-t-shirt-imprime-c1822o04j-a11',
#      'media': [{'path': 'C1/82/2O/04/JA/11/C1822O04J-A11@16.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé - bright white',
#      'sizes': ['XS', 'S', 'L', 'XL', 'XXL'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '23,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'C1822O04J-K11',
#      'url_key': 'calvin-klein-jeans-core-institutional-logo-slim-tee-t-shirt-imprime-c1822o04j-k11',
#      'media': [{'path': 'C1/82/2O/04/JK/11/C1822O04J-K11@20.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé - night sky',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '29,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'C1822O04J-Q11',
#      'url_key': 'calvin-klein-jeans-core-institutional-logo-slim-tee-t-shirt-imprime-ck-black-c1822o04j-q11',
#      'media': [{'path': 'C1/82/2O/04/JQ/11/C1822O04J-Q11@18.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé - ck black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '26,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'C1822O04J-C11',
#      'url_key': 'calvin-klein-jeans-core-institutional-logo-slim-tee-t-shirt-imprime-c1822o04j-c11',
#      'media': [{'path': 'C1/82/2O/04/JC/11/C1822O04J-C11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé - grey heather',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '26,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA222S03K-Q11',
#    'name': 'CLASSIC HOODIE - Sweat à capuche - black/white',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '48,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'vans-classic-hoodie-sweatshirt-va222s03k-q11',
#    'media': [{'path': 'VA/22/2S/03/KQ/11/VA222S03K-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VA/22/2S/03/KQ/11/VA222S03K-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'VA222S03K-Q11',
#      'url_key': 'vans-classic-hoodie-sweatshirt-va222s03k-q11',
#      'media': [{'path': 'VA/22/2S/03/KQ/11/VA222S03K-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CLASSIC HOODIE - Sweat à capuche - black/white',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '48,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-25%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'VA222S03K-C11',
#      'url_key': 'vans-classic-hoodie-sweatshirt-cement-heatherblack-va222s03k-c11',
#      'media': [{'path': 'VA/22/2S/03/KC/11/VA222S03K-C11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CLASSIC HOODIE - Sweat à capuche - cement heather/black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '51,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'VA222S03K-M11',
#      'url_key': 'vans-classic-hoodie-sweatshirt-va222s03k-m11',
#      'media': [{'path': 'VA/22/2S/03/KM/11/VA222S03K-M11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CLASSIC HOODIE - Sweat à capuche - oil blue',
#      'sizes': ['L'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '45,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'VA222S03K-A11',
#      'url_key': 'vans-classic-hoodie-sweatshirt-va222s03k-a11',
#      'media': [{'path': 'VA/22/2S/03/KA/11/VA222S03K-A11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'CLASSIC HOODIE - Sweat à capuche - white/racing red',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '64,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'VA222S03K-G11',
#      'url_key': 'vans-classic-hoodie-sweatshirt-va222s03k-g11',
#      'media': [{'path': 'VA/22/2S/03/KG/11/VA222S03K-G11@7.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'CLASSIC HOODIE - Sweat à capuche - port royale/white',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '64,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'outfits': [{'id': 'AkWBSfFFTU2',
#      'url_key': '/outfits/AkWBSfFFTU2',
#      'media': [{'path': '31f1e8deb5754ffeafe5018bbcbed05c/edab180bbdee4b78bdf3313a5b30beb0.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'men',
#      'creator': {'id': '168611f1-3a16-4936-aa2b-dfdde45c4ed8',
#       'name': 'abrahamdailydosis',
#       'media': [{'path': 'dba7b8e488cb47609e83c367515d9631/7bf2317ddedb48bfbd448a77d74949b8.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'JA222T0EI-Q11'},
#       {'id': 'VA222S03K-Q11'},
#       {'id': 'BRH22G001-C11'},
#       {'id': 'DO215C00J-802'}]}],
#    'delivery_promises': []},
#   {'sku': 'JA222O2QK-K11',
#    'name': 'JCOSHAWN TEE CREW NECK - T-shirt imprimé - sky captain',
#    'price': {'original': '12,95\xa0€',
#     'promotional': '7,74\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'jack-and-jones-jcoshawn-tee-crew-neck-t-shirt-imprime-ja222o2qk-k11',
#    'media': [{'path': 'JA/22/2O/2Q/KK/11/JA222O2QK-K11@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JA/22/2O/2Q/KK/11/JA222O2QK-K11@18.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JA222O2QK-K11',
#      'url_key': 'jack-and-jones-jcoshawn-tee-crew-neck-t-shirt-imprime-ja222o2qk-k11',
#      'media': [{'path': 'JA/22/2O/2Q/KK/11/JA222O2QK-K11@14.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JCOSHAWN TEE CREW NECK - T-shirt imprimé - sky captain',
#      'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '7,74\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'JA222O2QK-B11',
#      'url_key': 'jack-and-jones-jcoshawn-tee-crew-neck-t-shirt-imprime-dune-ja222o2qk-b11',
#      'media': [{'path': 'JA/22/2O/2Q/KB/11/JA222O2QK-B11@17.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JCOSHAWN TEE CREW NECK - T-shirt imprimé - dune',
#      'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '7,74\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TP822D0E3-Q11',
#    'name': 'FLORAL SHEER PLACEMENT - Chemise - black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '44,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'topman-floral-sheer-placement-chemise-black-tp822d0e3-q11',
#    'media': [{'path': 'TP/82/2D/0E/3Q/11/TP822D0E3-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TP/82/2D/0E/3Q/11/TP822D0E3-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Topman',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TP822D0E3-Q11',
#      'url_key': 'topman-floral-sheer-placement-chemise-black-tp822d0e3-q11',
#      'media': [{'path': 'TP/82/2D/0E/3Q/11/TP822D0E3-Q11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'FLORAL SHEER PLACEMENT - Chemise - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '44,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-25%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222O2RV-A11',
#    'name': 'JORDARK CITY TEE CREW NECK REGULAR - T-shirt imprimé - cloud dancer',
#    'price': {'original': '12,95\xa0€',
#     'promotional': '9,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XXL'],
#    'url_key': 'jack-and-jones-jordark-city-tee-crew-neck-regular-t-shirt-imprime-ja222o2rv-a11',
#    'media': [{'path': 'JA/22/2O/2R/VA/11/JA222O2RV-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JA/22/2O/2R/VA/11/JA222O2RV-A11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JA222O2RV-A11',
#      'url_key': 'jack-and-jones-jordark-city-tee-crew-neck-regular-t-shirt-imprime-ja222o2rv-a11',
#      'media': [{'path': 'JA/22/2O/2R/VA/11/JA222O2RV-A11@13.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JORDARK CITY TEE CREW NECK REGULAR - T-shirt imprimé - cloud dancer',
#      'sizes': ['XS', 'S', 'M', 'L', 'XXL'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '9,69\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-25%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JA222O2RV-Q11',
#      'url_key': 'jack-and-jones-jordark-city-tee-crew-neck-regular-t-shirt-imprime-tap-shoe-ja222o2rv-q11',
#      'media': [{'path': 'JA/22/2O/2R/VQ/11/JA222O2RV-Q11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JORDARK CITY TEE CREW NECK REGULAR - T-shirt imprimé - tap shoe',
#      'sizes': ['XS', 'S', 'M', 'XXL'],
#      'price': {'original': '12,95\xa0€',
#       'promotional': '12,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222S02D-K11',
#    'name': 'Sweatshirt - marine',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '76,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-sweatshirt-marine-la222s02d-k11',
#    'media': [{'path': 'LA/22/2S/02/DK/11/LA222S02D-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2S/02/DK/11/LA222S02D-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [{'sku': 'LA222S02D-K11',
#      'url_key': 'lacoste-sweatshirt-marine-la222s02d-k11',
#      'media': [{'path': 'LA/22/2S/02/DK/11/LA222S02D-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - marine',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '76,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LA222S02D-Q11',
#      'url_key': 'lacoste-sweatshirt-noir-la222s02d-q11',
#      'media': [{'path': 'LA/22/2S/02/DQ/11/LA222S02D-Q11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - noir',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '87,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LA222S02D-M12',
#      'url_key': 'lacoste-sweatshirt-baobab-la222s02d-m12',
#      'media': [{'path': 'LA/22/2S/02/DM/12/LA222S02D-M12@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - baobab',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '76,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LA222S02D-A11',
#      'url_key': 'lacoste-sweatshirt-blanc-la222s02d-a11',
#      'media': [{'path': 'LA/22/2S/02/DA/11/LA222S02D-A11@12.2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - blanc',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '76,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LA222S02D-J11',
#      'url_key': 'lacoste-sweatshirt-princesse-la222s02d-j11',
#      'media': [{'path': 'LA/22/2S/02/DJ/11/LA222S02D-J11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - princesse',
#      'sizes': ['XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '76,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LA222S02D-C11',
#      'url_key': 'lacoste-sweatshirt-argent-chine-la222s02d-c11',
#      'media': [{'path': 'LA/22/2S/02/DC/11/LA222S02D-C11@13.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Sweatshirt - argent chine',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '76,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222S165-K12',
#    'name': 'JORHIDE CREW NECK - Sweatshirt - navy blazer',
#    'price': {'original': '23,99\xa0€',
#     'promotional': '16,79\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'jack-and-jones-jorhide-crew-neck-sweatshirt-ja222s165-k12',
#    'media': [{'path': 'JA/22/2S/16/5K/12/JA222S165-K12@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JA/22/2S/16/5K/12/JA222S165-K12@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JA222S165-K12',
#      'url_key': 'jack-and-jones-jorhide-crew-neck-sweatshirt-ja222s165-k12',
#      'media': [{'path': 'JA/22/2S/16/5K/12/JA222S165-K12@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JORHIDE CREW NECK - Sweatshirt - navy blazer',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '23,99\xa0€',
#       'promotional': '16,79\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JA222S165-M11',
#      'url_key': 'jack-and-jones-jorhide-crew-neck-sweatshirt-ja222s165-m11',
#      'media': [{'path': 'JA/22/2S/16/5M/11/JA222S165-M11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JORHIDE CREW NECK - Sweatshirt - forest night',
#      'sizes': ['XS', 'S', 'M', 'XXL'],
#      'price': {'original': '24,99\xa0€',
#       'promotional': '24,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JA222S165-G12',
#      'url_key': 'jack-and-jones-jorhide-crew-neck-sweatshirt-ja222s165-g12',
#      'media': [{'path': 'JA/22/2S/16/5G/12/JA222S165-G12@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'JORHIDE CREW NECK - Sweatshirt - brick red',
#      'sizes': ['XS', 'S', 'M'],
#      'price': {'original': '24,99\xa0€',
#       'promotional': '16,19\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OS322E07L-C11',
#    'name': 'ONSLINUS CHECK PANT - Pantalon classique - almond',
#    'price': {'original': '38,99\xa0€',
#     'promotional': '27,29\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'only-and-sons-onslinus-check-pant-pantalon-classique-almond-os322e07l-c11',
#    'media': [{'path': 'OS/32/2E/07/LC/11/OS322E07L-C11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'OS/32/2E/07/LC/11/OS322E07L-C11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [{'sku': 'OS322E07L-C11',
#      'url_key': 'only-and-sons-onslinus-check-pant-pantalon-classique-almond-os322e07l-c11',
#      'media': [{'path': 'OS/32/2E/07/LC/11/OS322E07L-C11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'ONSLINUS CHECK PANT - Pantalon classique - almond',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '38,99\xa0€',
#       'promotional': '27,29\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OS322O0M6-Q11',
#    'name': '3PACK - T-shirt basique - black/white/grey',
#    'price': {'original': '34,99\xa0€',
#     'promotional': '22,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'only-and-sons-onsmatt-longy-tee-3-pack-t-shirt-basique-blackwhitegrey-os322o0m6-q11',
#    'media': [{'path': 'OS/32/2O/0M/6Q/11/OS322O0M6-Q11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'OS/32/2O/0M/6Q/11/OS322O0M6-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [{'sku': 'OS322O0M6-Q11',
#      'url_key': 'only-and-sons-onsmatt-longy-tee-3-pack-t-shirt-basique-blackwhitegrey-os322o0m6-q11',
#      'media': [{'path': 'OS/32/2O/0M/6Q/11/OS322O0M6-Q11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': '3PACK - T-shirt basique - black/white/grey',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '34,99\xa0€',
#       'promotional': '22,69\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222T0E4-Q11',
#    'name': "JOREXPLORE - Veste d'hiver - black/solid",
#    'price': {'original': '79,99\xa0€',
#     'promotional': '47,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'jack-and-jones-jorexplore-jacket-parka-ja222t0e4-q11',
#    'media': [{'path': 'JA/22/2T/0E/4Q/11/JA222T0E4-Q11@16.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'JA/22/2T/0E/4Q/11/JA222T0E4-Q11@21.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JA222T0E4-Q11',
#      'url_key': 'jack-and-jones-jorexplore-jacket-parka-ja222t0e4-q11',
#      'media': [{'path': 'JA/22/2T/0E/4Q/11/JA222T0E4-Q11@19.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - black/solid",
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,99\xa0€',
#       'promotional': '47,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JA222T0E4-B11',
#      'url_key': 'jack-and-jones-jorexplore-jacket-parka-aluminumsolid-ja222t0e4-b11',
#      'media': [{'path': 'JA/22/2T/0E/4B/11/JA222T0E4-B11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - aluminum/solid",
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '89,99\xa0€',
#       'promotional': '71,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JA222T0E4-O11',
#      'url_key': 'jack-and-jones-jorexplore-jacket-veste-mi-saison-ja222t0e4-o11',
#      'media': [{'path': 'JA/22/2T/0E/4O/11/JA222T0E4-O11@23.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - golden brown",
#      'sizes': ['S', 'XL'],
#      'price': {'original': '79,99\xa0€',
#       'promotional': '79,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JA222T0E4-K11',
#      'url_key': 'jack-and-jones-jorexplore-jacket-parka-ja222t0e4-k11',
#      'media': [{'path': 'JA/22/2T/0E/4K/11/JA222T0E4-K11@18.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - navy blazer",
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '89,99\xa0€',
#       'promotional': '71,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'JA222T0E4-A11',
#      'url_key': 'jack-and-jones-jorexplore-jacket-parka-ja222t0e4-a11',
#      'media': [{'path': 'JA/22/2T/0E/4A/11/JA222T0E4-A11@21.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - asphalt/solid",
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '89,99\xa0€',
#       'promotional': '89,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'JA222T0E4-K12',
#      'url_key': 'jack-and-jones-jorexplore-jacket-parka-ja222t0e4-k12',
#      'media': [{'path': 'JA/22/2T/0E/4K/12/JA222T0E4-K12@18.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "JOREXPLORE - Veste d'hiver - forest night",
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '79,99\xa0€',
#       'promotional': '55,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PI922PA09-Q11',
#    'name': 'Polo - black',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '15,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'pier-one-polo-black-pi922pa09-q11',
#    'media': [{'path': 'PI/92/2P/A0/9Q/11/PI922PA09-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PI/92/2P/A0/9Q/11/PI922PA09-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [{'sku': 'PI922PA09-Q11',
#      'url_key': 'pier-one-polo-black-pi922pa09-q11',
#      'media': [{'path': 'PI/92/2P/A0/9Q/11/PI922PA09-Q11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Polo - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '19,99\xa0€',
#       'promotional': '15,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'PI922PA09-G11',
#      'url_key': 'pier-one-polo-bordeaux-pi922pa09-g11',
#      'media': [{'path': 'PI/92/2P/A0/9G/11/PI922PA09-G11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Polo - bordeaux',
#      'sizes': ['XS', 'S'],
#      'price': {'original': '19,99\xa0€',
#       'promotional': '11,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'},
#       {'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []},
#     {'sku': 'PI922PA09-K12',
#      'url_key': 'pier-one-polo-blue-melange-pi922pa09-k12',
#      'media': [{'path': 'PI/92/2P/A0/9K/12/PI922PA09-K12@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Polo - blue melange',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '19,99\xa0€',
#       'promotional': '15,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'PI922PA09-K11',
#      'url_key': 'pier-one-polo-dark-blue-pi922pa09-k11',
#      'media': [{'path': 'PI/92/2P/A0/9K/11/PI922PA09-K11@12.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Polo - dark blue',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '19,99\xa0€',
#       'promotional': '15,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'PI922PA09-A11',
#      'url_key': 'pier-one-polo-white-pi922pa09-a11',
#      'media': [{'path': 'PI/92/2P/A0/9A/11/PI922PA09-A11@12.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Polo - white',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '21,99\xa0€',
#       'promotional': '17,59\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TOB22E009-I11',
#    'name': 'SLIM FERRY - Chino - navy blazer',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '84,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x34',
#     '28x36',
#     '29x34',
#     '29x36',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x30',
#     '31x32',
#     '31x34',
#     '31x36',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x34',
#     '33x36',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '38x30',
#     '38x32',
#     '38x34',
#     '38x36'],
#    'url_key': 'tommy-jeans-slim-ferry-chino-tob22e009-i11',
#    'media': [{'path': 'TO/B2/2E/00/9I/11/TOB22E009-I11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/2E/00/9I/11/TOB22E009-I11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TOB22E009-I11',
#      'url_key': 'tommy-jeans-slim-ferry-chino-tob22e009-i11',
#      'media': [{'path': 'TO/B2/2E/00/9I/11/TOB22E009-I11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SLIM FERRY - Chino - navy blazer',
#      'sizes': ['28x34',
#       '28x36',
#       '29x34',
#       '29x36',
#       '30x30',
#       '30x32',
#       '30x34',
#       '30x36',
#       '31x30',
#       '31x32',
#       '31x34',
#       '31x36',
#       '32x30',
#       '32x32',
#       '32x34',
#       '32x36',
#       '33x30',
#       '33x34',
#       '33x36',
#       '34x30',
#       '34x32',
#       '34x34',
#       '34x36',
#       '36x30',
#       '36x32',
#       '36x34',
#       '36x36',
#       '38x30',
#       '38x32',
#       '38x34',
#       '38x36'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '84,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'TOB22E009-B11',
#      'url_key': 'tommy-jeans-slim-ferry-chino-beige-tob22e009-b11',
#      'media': [{'path': 'TO/B2/2E/00/9B/11/TOB22E009-B11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SLIM FERRY - Chino - beige',
#      'sizes': ['28x30',
#       '28x32',
#       '29x30',
#       '29x32',
#       '29x34',
#       '29x36',
#       '30x30',
#       '30x32',
#       '30x34',
#       '30x36',
#       '31x30',
#       '31x32',
#       '31x34',
#       '31x36',
#       '32x30',
#       '32x32',
#       '32x36',
#       '33x30',
#       '33x32',
#       '33x34',
#       '33x36',
#       '34x30',
#       '34x32',
#       '34x34',
#       '34x36',
#       '36x30',
#       '36x32',
#       '36x34',
#       '36x36',
#       '38x30',
#       '38x32',
#       '38x34',
#       '38x36'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '84,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
# ...
#     {'key': 'VA1', 'label': 'Vagabond', 'is_family': False},
#     {'key': 'VL7', 'label': 'Van Lier', 'is_family': False},
#     {'key': 'VA2', 'label': 'Vans', 'is_family': False},
#     {'key': 'VA4', 'label': 'Vaude', 'is_family': False},
#     {'key': 'VEK', 'label': 'Veganino', 'is_family': False},
#     {'key': 'VJ2', 'label': 'Veja', 'is_family': False},
#     {'key': 'VERS', 'label': 'Versace', 'is_family': True},
#     {'key': '1VE', 'label': 'Versace', 'is_family': False},
#     {'key': 'VC1',
#      'label': 'Versace Collection',
#      'family_id': 'VERS',
#      'is_family': False},
#     {'key': 'VEI',
#      'label': 'Versace Jeans Couture',
#      'family_id': 'VERS',
#      'is_family': False},
#     {'key': 'V14', 'label': 'Victorinox', 'is_family': False},
#     {'key': 'VIA', 'label': 'Viggo', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'V11', 'label': 'Vilebrequin', 'is_family': False},
#     {'key': 'VIO', 'label': 'Vintage Supply', 'is_family': False},
#     {'key': 'VIG', 'label': 'Vitaly', 'is_family': False},
#     {'key': 'VIVI', 'label': 'Vivienne Westwood', 'is_family': True},
#     {'key': 'VW9',
#      'label': 'Vivienne Westwood',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VW6',
#      'label': 'Vivienne Westwood Anglomania',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VB7', 'label': 'Voile Blanche', 'is_family': False},
#     {'key': 'V19', 'label': 'Volcom', 'is_family': False},
#     {'key': 'VO7', 'label': 'Volé la lumière', 'is_family': False},
#     {'key': 'V17', 'label': 'Vossen', 'is_family': False},
#     {'key': 'WY0', 'label': 'W6YZ', 'is_family': False},
#     {'key': 'W02', 'label': 'Walk London', 'is_family': False},
#     {'key': 'WAJ', 'label': 'WAWWA', 'is_family': False},
#     {'key': 'WEA', 'label': 'We are Cph', 'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'CLC', 'label': 'Wearcolour', 'is_family': False},
#     {'key': 'WEB', 'label': 'Weekday', 'is_family': False},
#     {'key': 'WE7', 'label': 'Weleda', 'is_family': False},
#     {'key': 'WEE', 'label': 'Wella EIMI', 'is_family': False},
#     {'key': 'WM1', 'label': 'Wemoto', 'is_family': False},
#     {'key': 'WE1', 'label': 'WeSC', 'is_family': False},
#     {'key': 'WH4', 'label': 'White Mountaineering', 'is_family': False},
#     {'key': 'WIA', 'label': 'Wild Feet', 'is_family': False},
#     {'key': 'WIC', 'label': 'Wildwuchs Bartpflege', 'is_family': False},
#     {'key': 'WO3', 'label': 'Won Hundred', 'is_family': False},
#     {'key': 'WO4', 'label': 'Wood Wood', 'is_family': False},
#     {'key': 'WOD', 'label': 'Woodbird', 'is_family': False},
#     {'key': 'WR1',
#      'label': 'Wrangler',
#      'family_id': 'WR00',
#      'is_family': False},
#     {'key': 'YE1', 'label': 'Yellow Cab', 'is_family': False},
#     {'key': 'YE9', 'label': 'YETI', 'is_family': False},
#     {'key': 'YO4', 'label': 'YMC You Must Create', 'is_family': False},
#     {'key': 'YO8', 'label': 'YOU & OIL', 'is_family': False},
#     {'key': 'YOA', 'label': 'Young and Reckless', 'is_family': False},
#     {'key': 'YT1',
#      'label': 'Your Turn Active',
#      'family_id': 'YOUR',
#      'is_family': False},
#     {'key': 'YOUR', 'label': 'YOURTURN', 'is_family': True},
#     {'key': 'YO1',
#      'label': 'YOURTURN',
#      'family_id': 'YOUR',
#      'is_family': False},
#     {'key': 'Z21',
#      'label': 'Zadig & Voltaire',
#      'family_id': 'ZA00',
#      'is_family': False},
#     {'key': 'ZA8',
#      'label': 'Zalando Essentials',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'ZED', 'label': 'Zew for Men', 'is_family': False},
#     {'key': 'Z10', 'label': 'Ziener', 'is_family': False},
#     {'key': 'ZI1', 'label': 'Zign', 'family_id': 'ZIGN', 'is_family': False},
#     {'key': 'ZW1', 'label': 'Zwilling', 'is_family': False},
#     {'key': '47B', 'label': "'47", 'is_family': False},
#     {'key': '111', 'label': '11 DEGREES', 'is_family': False},
#     {'key': '190', 'label': '1904', 'is_family': False},
#     {'key': '310', 'label': '3.1 Phillip Lim', 'is_family': False},
#     {'key': '7F1', 'label': '7 for all mankind', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 3.89,
#     'max': 2200.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'pure_cashmere', 'label': 'cachemire (100%)'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'camouflage', 'label': 'camouflage'},
#     {'key': 'checked', 'label': 'carreaux'},
#     {'key': 'herring_bone', 'label': 'chevrons'},
#     {'key': 'flecked', 'label': 'chiné'},
#     {'key': 'plain', 'label': 'couleur unie'},
#     {'key': 'gradient', 'label': 'dégradé'},
#     {'key': 'burnout', 'label': 'dévoré'},
#     {'key': 'pinstripe', 'label': 'fines rayures'},
#     {'key': 'floral', 'label': 'floral'},
#     {'key': 'print', 'label': 'imprimé'},
#     {'key': 'animal_print', 'label': 'imprimé animal'},
#     {'key': 'leopard', 'label': 'imprimé léopard'},
#     {'key': 'photo_print', 'label': 'imprimé photo'},
#     {'key': 'colored', 'label': 'multicolore'},
#     {'key': 'paisley', 'label': 'Paisley/cachemire'},
#     {'key': 'striped', 'label': 'rayures'},
#     {'key': 'polka_dot', 'label': 'à pois'}]},
#   {'key': 'lengths',
#    'label': 'Longueur',
#    'url_key': 'length',
#    'kind': 'values',
#    'values': [{'key': 'normal', 'label': 'normale'},
#     {'key': 'extra_short', 'label': 'extra courte'},
#     {'key': 'short', 'label': 'courte'},
#     {'key': 'thigh_length', 'label': 'Longueur mi-cuisse'},
#     {'key': 'knee_length', 'label': 'Jusqu’aux genoux'},
#     {'key': 'calf_length', 'label': 'Longueur midi'},
#     {'key': '3_4_length', 'label': '3/4'},
#     {'key': '7_8_length', 'label': '7/8'},
#     {'key': 'ankle_length', 'label': 'socquettes'},
#     {'key': 'long', 'label': 'longue'},
#     {'key': 'extra_long', 'label': 'extra longue'},
#     {'key': '26', 'label': '26'},
#     {'key': '28', 'label': '28'},
#     {'key': '29', 'label': '29'},
#     {'key': '30', 'label': '30'},
#     {'key': '31', 'label': '31'},
#     {'key': '32', 'label': '32'},
#     {'key': '33', 'label': '33'},
#     {'key': '34', 'label': '34'},
#     {'key': '35', 'label': '35'},
#     {'key': '36', 'label': '36'},
#     {'key': '38', 'label': '38'},
#     {'key': '40', 'label': '40'},
#     {'key': '44', 'label': '44'},
#     {'key': '46', 'label': '46'},
#     {'key': '48', 'label': '48'},
#     {'key': '50', 'label': '50'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'Casual'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 53197,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '9191',
#    'url_key': 'promo-homme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-homme/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9205',
#      'url_key': 'promo-mode-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-homme/?order=sale',
#      'children': [],
#      'article_count': 37733},
#     {'label': 'Chaussures',
#      'id': '9192',
#      'url_key': 'promo-chaussures-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-homme/?order=sale',
#      'children': [],
#      'article_count': 10383},
#     {'label': 'Sport',
#      'id': '13690',
#      'url_key': 'promo-sport-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-homme/?order=sale',
#      'children': [],
#      'article_count': 6636},
#     {'label': 'Accessoires',
#      'id': '9222',
#      'url_key': 'promo-accessoires-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-homme/?order=sale',
#      'children': [],
#      'article_count': 4637},
#     {'label': 'Luxe',
#      'id': '13825',
#      'url_key': 'promo-luxe-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-homme/?order=sale',
#      'children': [],
#      'article_count': 4419},
#     {'label': 'Beauté',
#      'id': '13865',
#      'url_key': 'beaute-homme-soins-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-homme-soins-promo/?order=sale',
#      'children': [],
#      'article_count': 244}],
#    'article_count': 53200}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Homme',
#      'url_key': 'homme',
#      'full_url': '/homme/?order=sale'},
#     {'label': 'Soldes',
#      'url_key': 'promo-homme',
#      'full_url': '/promo-homme/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-homme',
#       'url_key': 'promo-homme',
#       'label': 'Soldes',
#       'seo_label': 'Promotions homme',
#       'reset_url': '/?order=sale',
#       'id': '9191'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-homme/?order=sale',
#   'reset_url': '/promo-homme/?order=sale',
#   'app_url': '?urlKey=promo-homme&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-homme',
#     'url_key': 'promo-homme',
#     'label': 'Soldes',
#     'seo_label': 'Promotions homme',
#     'reset_url': '/?order=sale',
#     'id': '9191'}]},
#  'selectedFilters': {'categories': ['promo-homme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'search-dialog-mobile': [14],
#   'search-dialog-fullwidth': [24],
#   'search-dialog': [18],
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': None,
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flat_data = json_normalize(results)
flat_data
# Out:
#    total_count  sort                                           articles  \
# 0        53198  sale  [{'sku': 'OS322T06P-Q11', 'name': 'ONSCOME TRU...
#
#                      query_path        previous_page_path  \
# 0  /promo-homme/?p=2&order=sale  /promo-homme/?order=sale
#
#                  next_page_path page_gender  premium  \
# 0  /promo-homme/?p=3&order=sale         men    False
#
#                                              filters  total_article_count  \
# 0  [{'key': 'sizes', 'label': 'Taille', 'url_key'...                53197
#
#    ... iconPaths.filters.standard_delivery_filter  \
# 0  ...                            icons/truck.svg
#
#   iconPaths.filters.fast_delivery_filter iconPaths.filters.zalando_plus  \
# 0                   icons/truck-fast.svg         icons/plus-short-1.svg
#
#   iconPaths.mobileFilters.standard_delivery_filter  \
# 0                                  icons/truck.svg
#
#    iconPaths.mobileFilters.fast_delivery_filter  \
# 0                          icons/truck-fast.svg
#
#   iconPaths.mobileFilters.zalando_plus iconPaths.flags.slow_delivery_flag  \
# 0               icons/plus-short-1.svg                    icons/clock.svg
#
#    iconPaths.flags.fast_delivery_flag iconPaths.flags.plus_delivery_flag  \
# 0       icons/truck-fast-orange-3.svg             icons/plus-short-1.svg
#
#    iconPaths.flags.zalando_plus
# 0        icons/zalando-plus.svg
#
# [1 rows x 80 columns]

# %%
flat_data = json_normalize(flat_data.articles[0])
flat_data
# Out:
#               sku                                               name  \
# 0   OS322T06P-Q11    ONSCOME TRUCKER   - Veste en jean - black denim
# 1   JAM22Q01I-K11  JPRMARK MERINO KNIT CREW NECK - Pullover - mar...
# 2   C1822O04J-A11  CORE INSTITUTIONAL LOGO TEE - T-shirt imprimé ...
# 3   VA222S03K-Q11     CLASSIC HOODIE - Sweat à capuche - black/white
# 4   JA222O2QK-K11  JCOSHAWN TEE CREW NECK - T-shirt imprimé - sky...
# ..            ...                                                ...
# 79  JA222P04R-A11                            JJEBASIC - Polo - white
# 80  PI922S049-Q11                                 Sweatshirt - black
# 81  GY322G00Z-K11                          Jeans Skinny - raw indigo
# 82  PI922D01Q-A11                                       Polo - white
# 83  KIE22E00Z-C11  ALDEN SMART JOGGERS  - Pantalon de survêtement...
#
#                           sizes  \
# 0             [XS, S, M, L, XL]
# 1        [XS, S, M, L, XL, XXL]
# 2           [XS, S, L, XL, XXL]
# 3             [XS, S, M, L, XL]
# 4   [XXS, XS, S, M, L, XL, XXL]
# ..                          ...
# 79       [XS, S, M, L, XL, XXL]
# 80       [XS, S, M, L, XL, XXL]
# 81         [28, 30, 32, 34, 36]
# 82  [XS, S, M, L, XL, XXL, 3XL]
# 83            [XS, S, M, L, XL]
#
#                                               url_key  \
# 0   only-and-sons-onscome-trucker-veste-en-jean-bl...
# 1   jack-and-jones-premium-jprmark-crew-neck-pullo...
# 2   calvin-klein-jeans-core-institutional-logo-sli...
# 3        vans-classic-hoodie-sweatshirt-va222s03k-q11
# 4   jack-and-jones-jcoshawn-tee-crew-neck-t-shirt-...
# ..                                                ...
# 79         jack-and-jones-jjebasic-polo-ja222p04r-a11
# 80            pier-one-sweatshirt-black-pi922s049-q11
# 81     gym-king-jeans-skinny-raw-indigo-gy322g00z-k11
# 82                  pier-one-polo-blanc-pi922d01q-a11
# 83  kings-will-dream-alden-smart-joggers-pantalon-...
#
#                                                 media            brand_name  \
# 0   [{'path': 'OS/32/2T/06/PQ/11/OS322T06P-Q11@8.j...           Only & Sons
# 1   [{'path': 'JA/M2/2Q/01/IK/11/JAM22Q01I-K11@13....  Jack & Jones PREMIUM
# 2   [{'path': 'C1/82/2O/04/JA/11/C1822O04J-A11@20....    Calvin Klein Jeans
# 3   [{'path': 'VA/22/2S/03/KQ/11/VA222S03K-Q11@7.j...                  Vans
# 4   [{'path': 'JA/22/2O/2Q/KK/11/JA222O2QK-K11@17....          Jack & Jones
# ..                                                ...                   ...
# 79  [{'path': 'JA/22/2P/04/RA/11/JA222P04R-A11@8.j...          Jack & Jones
# 80  [{'path': 'PI/92/2S/04/9Q/11/PI922S049-Q11@9.j...              Pier One
# 81  [{'path': 'GY/32/2G/00/ZK/11/GY322G00Z-K11@9.j...              Gym King
# 82  [{'path': 'PI/92/2D/01/QA/11/PI922D01Q-A11@17....              Pier One
# 83  [{'path': 'KI/E2/2E/00/ZC/11/KIE22E00Z-C11@9.j...      Kings Will Dream
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'OS322T06P-Q11', 'url_key': 'only-and...
# 1        False  [{'sku': 'JAM22Q01I-K11', 'url_key': 'jack-and...
# 2        False  [{'sku': 'C1822O04J-A11', 'url_key': 'calvin-k...
# 3        False  [{'sku': 'VA222S03K-Q11', 'url_key': 'vans-cla...
# 4        False  [{'sku': 'JA222O2QK-K11', 'url_key': 'jack-and...
# ..         ...                                                ...
# 79       False  [{'sku': 'JA222P04R-A11', 'url_key': 'jack-and...
# 80       False  [{'sku': 'PI922S049-Q11', 'url_key': 'pier-one...
# 81       False  [{'sku': 'GY322G00Z-K11', 'url_key': 'gym-king...
# 82       False  [{'sku': 'PI922D01Q-A11', 'url_key': 'pier-one...
# 83       False  [{'sku': 'KIE22E00Z-C11', 'url_key': 'kings-wi...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-18%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        33,99 €           27,99 €
# 1                 []        59,95 €           41,99 €
# 2                 []        29,95 €           23,95 €
# 3                 []        64,95 €           48,45 €
# 4                 []        12,95 €            7,74 €
# ..               ...            ...               ...
# 79                []        14,99 €           11,99 €
# 80                []        27,95 €           19,59 €
# 81                []        59,95 €           38,95 €
# 82                []        14,99 €           11,99 €
# 83                []        47,95 €           31,15 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'id': 'AkWBSfFFTU2', 'url_key': '/outfits/Ak...
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
# [84 rows x 18 columns]

# %%
#Find out the total page count in the 1st page data.

page_count = results['pagination']['page_count'] 
page_count
# Out:
# 634

# %%
#Use a FOR loop to make requests for the additional pages from 2 to page count. 
#Append the data of each additional page to the flatterned data object.

data = pd.DataFrame()


for page in range(page_count):
    url='https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=' + str(page*84) + '&sort=sale'
    r = requests.get(url, headers=headers)
    result = r.json()
    flat_data2 = json_normalize(result)
    flat_data2 = json_normalize(flat_data2.articles[0]) 
    flat_data.append(flat_data2)
    data = data.append(flat_data2)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
data.shape
# Out:
# (53189, 20)

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53189 entries, 0 to 16
# Data columns (total 20 columns):
# amount                                       1186 non-null object
# brand_name                                   53189 non-null object
# delivery_promises                            53189 non-null object
# family_articles                              53189 non-null object
# flags                                        53189 non-null object
# is_premium                                   53189 non-null bool
# media                                        53189 non-null object
# name                                         53189 non-null object
# outfits                                      1222 non-null object
# price.base_price                             200 non-null object
# price.has_different_original_prices          53189 non-null bool
# price.has_different_prices                   53189 non-null bool
# price.has_different_promotional_prices       53189 non-null bool
# price.has_discount_on_selected_sizes_only    53189 non-null bool
# price.original                               53189 non-null object
# price.promotional                            53189 non-null object
# product_group                                53189 non-null object
# sizes                                        53189 non-null object
# sku                                          53189 non-null object
# url_key                                      53189 non-null object
# dtypes: bool(5), object(15)
# memory usage: 6.7+ MB

# %%
data['brand_name'].value_counts().head(1)
# Out:
# Pier One    2222
# Name: brand_name, dtype: int64

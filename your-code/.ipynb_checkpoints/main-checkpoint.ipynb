# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-sport-homme&limit=84&offset=0&sort=popularity'

# %%
# Out:
# <Response [200]>

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
#1. IMPORT LIBRARIES
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#2. DEFINE API ENDPOINT
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=0&sort=sale'
header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}

response = requests.get(url, headers=header)

# %%
#3.1 MAKE REQUEST (for the 1rst page)

result = response.json()
result
# Out:
# {'total_count': 22054,
#  'pagination': {'page_count': 263, 'current_page': 1, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'NI116D04L-Q11',
#    'name': 'COURT BOROUGH MID BOOT WINTERIZED - Chaussures de skate - black/white',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '43,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#    'url_key': 'nike-sportswear-court-borough-mid-boot-winterized-baskets-montantes-blackwhite-ni116d04l-q11',
#    'media': [{'path': 'NI/11/6D/04/LQ/11/NI116D04L-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI116D04L-Q11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-winterized-baskets-montantes-blackwhite-ni116d04l-q11',
#      'media': [{'path': 'NI/11/6D/04/LQ/11/NI116D04L-Q11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID BOOT WINTERIZED - Chaussures de skate - black/white',
#      'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '43,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI116D04L-K11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-winterized-baskets-montantes-ni116d04l-k11',
#      'media': [{'path': 'NI/11/6D/04/LK/11/NI116D04L-K11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID BOOT WINTERIZED - Chaussures de skate - blue void/blue stardust/coast/topaz mist/photo blue',
#      'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '43,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30020668:NI116D04L-Q11&c=30020668&a=30020672&s=NI116D04L-Q11&is=1689&at=browser&cm=150434&ovm=576&r=0.0068522607907652855&ts=0&cs=1324770614'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30020668:NI116D04L-Q11&c=30020668&a=30020672&s=NI116D04L-Q11&is=1689&at=browser&cm=150434&ovm=576&r=0.0068522607907652855&ts=0&cs=1324770614',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0B9-Q14',
#    'name': 'AIR MAX 200 - Baskets basses - black/metallic silver/thunder grey/aurora green/hyper violet/barely volt',
#    'price': {'original': '104,95\xa0€',
#     'promotional': '83,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36.5', '37.5', '38', '38.5', '40'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q14',
#    'media': [{'path': 'NI/11/4D/0B/9Q/14/NI114D0B9-Q14@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D0B9-Q14',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q14',
#      'media': [{'path': 'NI/11/4D/0B/9Q/14/NI114D0B9-Q14@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/metallic silver/thunder grey/aurora green/hyper violet/barely volt',
#      'sizes': ['35.5', '36.5', '37.5', '38', '38.5', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-Q15',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q15',
#      'media': [{'path': 'NI/11/4D/0B/9Q/15/NI114D0B9-Q15@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/metallic gold/anthracite',
#      'sizes': ['36.5', '37.5', '38.5', '39'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '73,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-E11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-e11',
#      'media': [{'path': 'NI/11/4D/0B/9E/11/NI114D0B9-E11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - team gold/university red/black/white',
#      'sizes': ['37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-Q11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q11',
#      'media': [{'path': 'NI/11/4D/0B/9Q/11/NI114D0B9-Q11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/anthracite',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '88,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-K11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-k11',
#      'media': [{'path': 'NI/11/4D/0B/9K/11/NI114D0B9-K11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - royal pulse/oil grey/light aqua/ember glow',
#      'sizes': ['36.5', '38', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '67,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-Q12',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q12',
#      'media': [{'path': 'NI/11/4D/0B/9Q/12/NI114D0B9-Q12@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/white',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-J11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-j11',
#      'media': [{'path': 'NI/11/4D/0B/9J/11/NI114D0B9-J11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - off noir/iced lilac/smoke grey/white',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '105,00\xa0€',
#       'promotional': '105,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-A12',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-a12',
#      'media': [{'path': 'NI/11/4D/0B/9A/12/NI114D0B9-A12@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - white/university red/metallic silver',
#      'sizes': ['36.5', '38', '38.5', '39', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-A13',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-a13',
#      'media': [{'path': 'NI/11/4D/0B/9A/13/NI114D0B9-A13@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - white/metallic silver',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '105,00\xa0€',
#       'promotional': '105,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-A11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-whiteblackbright-crimsonuniversity-gold-ni114d0b9-a11',
#      'media': [{'path': 'NI/11/4D/0B/9A/11/NI114D0B9-A11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - white/black/bright crimson/university gold',
#      'sizes': ['35.5', '37.5', '39'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B9-Q13',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-q13',
#      'media': [{'path': 'NI/11/4D/0B/9Q/13/NI114D0B9-Q13@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/chrome yellow/white/bright crimson',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '104,95\xa0€',
#       'promotional': '83,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30020668:NI114D0B9-Q14&c=30020668&a=30020672&s=NI114D0B9-Q14&is=1689&at=browser&cm=123706&ovm=576&r=0.004660804755985737&ts=0&cs=2035070232'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30020668:NI114D0B9-Q14&c=30020668&a=30020672&s=NI114D0B9-Q14&is=1689&at=browser&cm=123706&ovm=576&r=0.004660804755985737&ts=0&cs=2035070232',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO113I00G-K11',
#    'name': 'Bottines - blue',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '66,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '33', '34', '35', '36', '37', '38', '40'],
#    'url_key': 'tommy-hilfiger-bottines-blue-to113i00g-k11',
#    'media': [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TO113I00G-K11',
#      'url_key': 'tommy-hilfiger-bottines-blue-to113i00g-k11',
#      'media': [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Bottines - blue',
#      'sizes': ['28', '29', '30', '33', '34', '35', '36', '37', '38', '40'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '66,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30032878:TO113I00G-K11&c=30032878&a=30032882&s=TO113I00G-K11&is=1689&at=browser&cm=129185&ovm=573&r=0.0044588809832930565&ts=0&cs=668068816'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=be27acc6-6d12-4fbb-8885-13280425fd0f&b=35d0b4ca-67f0-4ccf-9315-47ec5c21e8e5:30032878:TO113I00G-K11&c=30032878&a=30032882&s=TO113I00G-K11&is=1689&at=browser&cm=129185&ovm=573&r=0.0044588809832930565&ts=0&cs=668068816',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D007-A11',
#    'name': 'STAN SMITH - Baskets basses - white',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '38,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '29',
#     '30',
#     '31',
#     '32',
#     '33',
#     '34',
#     '35',
#     '28 1/2',
#     '30 1/2',
#     '33 1/2'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d007-a11',
#    'media': [{'path': 'AD/11/6D/00/7A/11/AD116D007-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D007-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d007-a11',
#      'media': [{'path': 'AD/11/6D/00/7A/11/AD116D007-A11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white',
#      'sizes': ['28',
#       '29',
#       '30',
#       '31',
#       '32',
#       '33',
#       '34',
#       '35',
#       '28 1/2',
#       '30 1/2',
#       '33 1/2'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '38,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D007-A13',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d007-a13',
#      'media': [{'path': 'AD/11/6D/00/7A/13/AD116D007-A13@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/bold pink',
#      'sizes': ['28',
#       '29',
#       '30',
#       '31',
#       '32',
#       '33',
#       '34',
#       '35',
#       '30 1/2',
#       '33 1/2'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '41,15\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -25%',
#        'tracking_value': 'discount rate'},
#       {'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD126L00J-Q11',
#    'name': "JACKET - Veste d'hiver - black/white",
#    'price': {'original': '64,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a', '4-5a', '5-6a', '6-7a', '7-8a'],
#    'url_key': 'adidas-originals-jacket-veste-dhiver-blackwhite-ad126l00j-q11',
#    'media': [{'path': 'AD/12/6L/00/JQ/11/AD126L00J-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD126L00J-Q11',
#      'url_key': 'adidas-originals-jacket-veste-dhiver-blackwhite-ad126l00j-q11',
#      'media': [{'path': 'AD/12/6L/00/JQ/11/AD126L00J-Q11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': "JACKET - Veste d'hiver - black/white",
#      'sizes': ['3-4a', '4-5a', '5-6a', '6-7a', '7-8a'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '41,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE223K01U-C11',
#    'name': 'KEY ITEM LOGO CREW - Sweatshirt - grey heather',
#    'price': {'original': '38,95\xa0€',
#     'promotional': '31,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-key-item-logo-crew-sweatshirt-le223k01u-c11',
#    'media': [{'path': 'LE/22/3K/01/UC/11/LE223K01U-C11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE223K01U-C11',
#      'url_key': 'levisr-key-item-logo-crew-sweatshirt-le223k01u-c11',
#      'media': [{'path': 'LE/22/3K/01/UC/11/LE223K01U-C11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'KEY ITEM LOGO CREW - Sweatshirt - grey heather',
#      'sizes': ['4a', '5a', '8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '38,95\xa0€',
#       'promotional': '31,15\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LE223K01U-A11',
#      'url_key': 'levisr-key-item-logo-crew-sweatshirt-le223k01u-a11',
#      'media': [{'path': 'LE/22/3K/01/UA/11/LE223K01U-A11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'KEY ITEM LOGO CREW - Sweatshirt - red/white',
#      'sizes': ['3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '39,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'LE223K01U-C12',
#      'url_key': 'levisr-key-item-logo-crew-sweatshirt-le223k01u-c12',
#      'media': [{'path': 'LE/22/3K/01/UC/12/LE223K01U-C12@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'KEY ITEM LOGO CREW - Sweatshirt - light gray heather',
#      'sizes': ['3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'new', 'value': 'Nouveau', 'tracking_value': 'new'}],
#      'delivery_promises': []},
#     {'sku': 'LE223K01U-J11',
#      'url_key': 'levisr-key-item-logo-crew-sweatshirt-pink-lady-le223k01u-j11',
#      'media': [{'path': 'LE/22/3K/01/UJ/11/LE223K01U-J11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'KEY ITEM LOGO CREW - Sweatshirt - pink lady',
#      'sizes': ['4a', '5a', '8a'],
#      'price': {'original': '38,95\xa0€',
#       'promotional': '38,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI113D091-A11',
#    'name': 'AIR MAX 200  - Baskets basses - white/metallic gold/cool grey/anthracite',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '87,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-whitemetallic-goldcool-greyanthracite-ni113d091-a11',
#    'media': [{'path': 'NI/11/3D/09/1A/11/NI113D091-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI113D091-A11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-whitemetallic-goldcool-greyanthracite-ni113d091-a11',
#      'media': [{'path': 'NI/11/3D/09/1A/11/NI113D091-A11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200  - Baskets basses - white/metallic gold/cool grey/anthracite',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5'],
#      'price': {'original': '109,95\xa0€',
#       'promotional': '87,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114F009-Q13',
#    'name': 'Baskets basses - black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19.5', '21', '22', '25', '26', '27'],
#    'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-q13',
#    'media': [{'path': 'NI/11/4F/00/9Q/13/NI114F009-Q13@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114F009-Q13',
#      'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-q13',
#      'media': [{'path': 'NI/11/4F/00/9Q/13/NI114F009-Q13@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Baskets basses - black',
#      'sizes': ['19.5', '21', '22', '25', '26', '27'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '41,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114F009-Q11',
#      'url_key': 'nike-sportswear-air-max-axis-baskets-basses-blackanthracite-ni114f009-q11',
#      'media': [{'path': 'NI/11/4F/00/9Q/11/NI114F009-Q11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Baskets basses - black/anthracite',
#      'sizes': ['19.5'],
#      'price': {'original': '60,00\xa0€',
#       'promotional': '60,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114F009-Q12',
#      'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-q12',
#      'media': [{'path': 'NI/11/4F/00/9Q/12/NI114F009-Q12@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Baskets basses - black/white',
#      'sizes': ['18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '47,95\xa0€',
#       'promotional': '47,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'PRIX MINI',
#        'tracking_value': 'fr_prixmini_old_season_2019_28'}],
#      'delivery_promises': []},
#     {'sku': 'NI114F009-A12',
#      'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-a12',
#      'media': [{'path': 'NI/11/4F/00/9A/12/NI114F009-A12@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Baskets basses - white/black',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '59,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114F009-Q14',
#      'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni114f009-q14',
#      'media': [{'path': 'NI/11/4F/00/9Q/14/NI114F009-Q14@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Baskets basses - black/spirit teal/white/platinum tint',
#      'sizes': ['19.5'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '47,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0AQ-Q11',
#    'name': 'AIR MAX 270 REACT - Baskets basses - black/vast grey/off noir/white',
#    'price': {'original': '134,95\xa0€',
#     'promotional': '93,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-q11',
#    'media': [{'path': 'NI/11/4D/0A/QQ/11/NI114D0AQ-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D0AQ-Q11',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-q11',
#      'media': [{'path': 'NI/11/4D/0A/QQ/11/NI114D0AQ-Q11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - black/vast grey/off noir/white',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '93,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-Q13',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-q13',
#      'media': [{'path': 'NI/11/4D/0A/QQ/13/NI114D0AQ-Q13@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - black/white',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '134,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-C13',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-c13',
#      'media': [{'path': 'NI/11/4D/0A/QC/13/NI114D0AQ-C13@21.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - iron grey/black/white/red',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '134,90\xa0€',
#       'promotional': '134,90\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-C12',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-c12',
#      'media': [{'path': 'NI/11/4D/0A/QC/12/NI114D0AQ-C12@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - gunsmoke/reflect silver/aurora green/hyper violet/barely volt/thunder grey',
#      'sizes': ['37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '107,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-Q12',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-q12',
#      'media': [{'path': 'NI/11/4D/0A/QQ/12/NI114D0AQ-Q12@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - black/bicycle yellow/teal tint/violet star',
#      'sizes': ['36.5', '37.5', '39'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '107,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-K11',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-ni114d0aq-k11',
#      'media': [{'path': 'NI/11/4D/0A/QK/11/NI114D0AQ-K11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - blue void/blue stardust/coast/topaz mist/photo blue',
#      'sizes': ['35.5', '38'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '80,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AQ-C11',
#      'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-phantomuniversity-goldkinetic-greenuniversity-red-ni114d0aq-c11',
#      'media': [{'path': 'NI/11/4D/0A/QC/11/NI114D0AQ-C11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270 REACT - Baskets basses - phantom/university gold/kinetic green/university red',
#      'sizes': ['35.5', '38.5'],
#      'price': {'original': '134,95\xa0€',
#       'promotional': '107,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI113D07Y-A11',
#    'name': 'RENEW LUCENT - Baskets basses - white/black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '47,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-a11',
#    'media': [{'path': 'NI/11/3D/07/YA/11/NI113D07Y-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI113D07Y-A11',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-a11',
#      'media': [{'path': 'NI/11/3D/07/YA/11/NI113D07Y-A11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - white/black',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '47,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D07Y-Q11',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-q11',
#      'media': [{'path': 'NI/11/3D/07/YQ/11/NI113D07Y-Q11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - black/white',
#      'sizes': ['35.5', '36', '37.5', '38.5', '39', '40'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '58,46\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D07Y-C11',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-c11',
#      'media': [{'path': 'NI/11/3D/07/YC/11/NI113D07Y-C11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - atmosphere grey/black/thunder grey/white',
#      'sizes': ['40'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '25,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D07Y-Q13',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-q13',
#      'media': [{'path': 'NI/11/3D/07/YQ/13/NI113D07Y-Q13@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - black/volt/pure platinum/dark grey',
#      'sizes': ['39', '40'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '57,53\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-11%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D07Y-K11',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-whitephoto-bluehyper-pinkblack-ni113d07y-k11',
#      'media': [{'path': 'NI/11/3D/07/YK/11/NI113D07Y-K11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - white/photo blue/hyper pink/black',
#      'sizes': ['40'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '51,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D07Y-Q12',
#      'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-q12',
#      'media': [{'path': 'NI/11/3D/07/YQ/12/NI113D07Y-Q12@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RENEW LUCENT - Baskets basses - anthracite/blue hero/cosmic clay/black/white',
#      'sizes': ['36.5', '38', '38.5', '39', '40'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '47,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0AT-Q14',
#    'name': 'AIR MAX 200 - Baskets basses - black/metallic gold/anthracite',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '52,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-q14',
#    'media': [{'path': 'NI/11/4D/0A/TQ/14/NI114D0AT-Q14@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D0AT-Q14',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-q14',
#      'media': [{'path': 'NI/11/4D/0A/TQ/14/NI114D0AT-Q14@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/metallic gold/anthracite',
#      'sizes': ['28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '74,95\xa0€',
#       'promotional': '52,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AT-Q11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-q11',
#      'media': [{'path': 'NI/11/4D/0A/TQ/11/NI114D0AT-Q11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/anthracite',
#      'sizes': ['28', '28.5', '30', '31', '31.5', '32', '34', '35'],
#      'price': {'original': '74,95\xa0€',
#       'promotional': '59,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AT-A11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-whiteblackbright-crimsonuniversity-gold-ni114d0at-a11',
#      'media': [{'path': 'NI/11/4D/0A/TA/11/NI114D0AT-A11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - white/black/bright crimson/university gold',
#      'sizes': ['28', '29.5', '30', '31', '31.5', '33.5', '34'],
#      'price': {'original': '74,95\xa0€',
#       'promotional': '63,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AT-K11',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-k11',
#      'media': [{'path': 'NI/11/4D/0A/TK/11/NI114D0AT-K11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - royal pulse/oil grey/light aqua/ember glow',
#      'sizes': ['28', '30'],
#      'price': {'original': '74,95\xa0€',
#       'promotional': '59,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AT-Q13',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-q13',
#      'media': [{'path': 'NI/11/4D/0A/TQ/13/NI114D0AT-Q13@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/white',
#      'sizes': ['28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '74,95\xa0€',
#       'promotional': '74,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D0AT-Q12',
#      'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0at-q12',
#      'media': [{'path': 'NI/11/4D/0A/TQ/12/NI114D0AT-Q12@21.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 200 - Baskets basses - black/metalic silver/thunder grey/aurora green/hyper violet/barely volt',
#      'sizes': ['28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '69,95\xa0€',
#       'promotional': '59,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D00A-A11',
#    'name': 'SUPERSTAR - Baskets basses - white/core black',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '55,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-superstar-baskets-basses-blanc-ad116d00a-a11',
#    'media': [{'path': 'AD/11/6D/00/AA/11/AD116D00A-A11@18.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D00A-A11',
#      'url_key': 'adidas-originals-superstar-baskets-basses-blanc-ad116d00a-a11',
#      'media': [{'path': 'AD/11/6D/00/AA/11/AD116D00A-A11@18.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SUPERSTAR - Baskets basses - white/core black',
#      'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '69,95\xa0€',
#       'promotional': '55,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
# ...
#     {'key': 'S0T', 'label': 'Sense Organics', 'is_family': False},
#     {'key': 'SHG', 'label': 'shoeb76', 'is_family': False},
#     {'key': 'E39', 'label': 'Shoesme', 'is_family': False},
#     {'key': 'P02',
#      'label': 'Shoo Pom',
#      'family_id': 'POMD',
#      'is_family': False},
#     {'key': 'SK1',
#      'label': 'Skechers',
#      'family_id': 'SKEC',
#      'is_family': False},
#     {'key': 'SK7', 'label': 'Skiny', 'is_family': False},
#     {'key': 'SKF', 'label': 'Skip Hop', 'is_family': False},
#     {'key': 'SL1', 'label': 'Slazenger', 'is_family': False},
#     {'key': 'SMC', 'label': 'Smitten Organic', 'is_family': False},
#     {'key': 'SMA', 'label': 'Småfolk', 'is_family': False},
#     {'key': 'SG9', 'label': 'Soft Gallery', 'is_family': False},
#     {'key': 'SOV', 'label': 'sondico', 'is_family': False},
#     {'key': 'SO6', 'label': 'Sorel', 'is_family': False},
#     {'key': 'SOY', 'label': 'SoulCal', 'is_family': False},
#     {'key': '1SP', 'label': 'Speedo', 'is_family': False},
#     {'key': 'SY0', 'label': 'Spyder', 'is_family': False},
#     {'key': 'STF', 'label': 'Staccato', 'is_family': False},
#     {'key': 'ST02', 'label': 'Steiff', 'is_family': True},
#     {'key': 'S15',
#      'label': 'Steiff Collection',
#      'family_id': 'ST02',
#      'is_family': False},
#     {'key': 'STZ',
#      'label': 'Steiff Shoes',
#      'family_id': 'ST02',
#      'is_family': False},
#     {'key': 'S0Y',
#      'label': 'Stella McCartney',
#      'family_id': 'ST03',
#      'is_family': False},
#     {'key': 'ST3',
#      'label': 'Steve Madden',
#      'family_id': 'ST01',
#      'is_family': False},
#     {'key': 'SUF', 'label': 'Sunnylife', 'is_family': False},
#     {'key': 'SUN', 'label': 'Sunuva', 'is_family': False},
#     {'key': 'SU2', 'label': 'Superdry', 'is_family': False},
#     {'key': 'LE3', 'label': 'Superfit', 'is_family': False},
#     {'key': 'SU1', 'label': 'Superga', 'is_family': False},
#     {'key': 'SUS', 'label': 'SuperRebel', 'is_family': False},
#     {'key': 'THN', 'label': 'The New', 'is_family': False},
#     {'key': 'TH3', 'label': 'The North Face', 'is_family': False},
#     {'key': 'T1B', 'label': 'The Rocks Push', 'is_family': False},
#     {'key': 'TF3', 'label': 'Tiffosi', 'is_family': False},
#     {'key': 'TI1', 'label': 'Timberland', 'is_family': False},
#     {'key': 'TIC', 'label': 'TINYCOTTONS', 'is_family': False},
#     {'key': 'TOP', 'label': 'Tobias & The Bear', 'is_family': False},
#     {'key': '4JO', 'label': 'Tom Joule', 'is_family': False},
#     {'key': 'TO2',
#      'label': 'TOM TAILOR',
#      'family_id': 'TOMT',
#      'is_family': False},
#     {'key': 'TO1',
#      'label': 'Tommy Hilfiger',
#      'family_id': 'TOMM',
#      'is_family': False},
#     {'key': 'TRI', 'label': 'TrollKids', 'is_family': False},
#     {'key': 'TU4', 'label': "Tumble 'n dry", 'is_family': False},
#     {'key': 'TUA', 'label': 'Turtledove', 'is_family': False},
#     {'key': 'UG1', 'label': 'UGG', 'is_family': False},
#     {'key': 'UH1', 'label': 'Uhlsport', 'is_family': False},
#     {'key': 'UM1', 'label': 'Umbro', 'family_id': 'UM00', 'is_family': False},
#     {'key': 'UNG', 'label': 'Unauthorized', 'is_family': False},
#     {'key': 'UN2', 'label': 'Under Armour', 'is_family': False},
#     {'key': 'UN1', 'label': 'Unisa', 'family_id': 'UN00', 'is_family': False},
#     {'key': 'VA2', 'label': 'Vans', 'is_family': False},
#     {'key': 'VA4', 'label': 'Vaude', 'is_family': False},
#     {'key': 'VJ2', 'label': 'Veja', 'is_family': False},
#     {'key': '1VE', 'label': 'Versace', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'V20', 'label': 'Vingino', 'is_family': False},
#     {'key': 'VB7', 'label': 'Voile Blanche', 'is_family': False},
#     {'key': 'V19', 'label': 'Volcom', 'is_family': False},
#     {'key': 'WAG', 'label': 'Walkiddy', 'is_family': False},
#     {'key': 'WAE', 'label': 'Walnut', 'is_family': False},
#     {'key': 'BAS',
#      'label': 'WAUW CAPOW by Bangbang Copenhagen',
#      'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'WE7', 'label': 'Weleda', 'is_family': False},
#     {'key': 'WHA', 'label': 'Wheat', 'is_family': False},
#     {'key': 'WH9', 'label': 'White Stuff', 'is_family': False},
#     {'key': 'WO8', 'label': 'Woden', 'is_family': False},
#     {'key': 'Z21',
#      'label': 'Zadig & Voltaire',
#      'family_id': 'ZA00',
#      'is_family': False},
#     {'key': 'ZAF',
#      'label': 'Zalando Essentials Kids',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'Z10', 'label': 'Ziener', 'is_family': False},
#     {'key': 'ZI7', 'label': 'Zip and Zoe', 'is_family': False},
#     {'key': '4CE', 'label': '18CRR81 Cerruti', 'is_family': False},
#     {'key': 'PO9', 'label': '3 Pommes', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 355.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '8', 'label': '8 packs'},
#     {'key': '9', 'label': '9 packs'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'CHECKERED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'FLORAL', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'STRIPED', 'label': 'rayures'},
#     {'key': 'POLKA_DOT', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'kids_comics_cartoons', 'label': 'BD et dessins animés'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 22057,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/?order=sale',
#      'children': [],
#      'article_count': 14590},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/?order=sale',
#      'children': [],
#      'article_count': 5419},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/?order=sale',
#      'children': [],
#      'article_count': 2738},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/?order=sale',
#      'children': [],
#      'article_count': 1240},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/?order=sale',
#      'children': [],
#      'article_count': 2008}],
#    'article_count': 22056}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/?order=sale'},
#     {'label': 'Soldes',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Soldes',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/?order=sale',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/?order=sale',
#   'reset_url': '/promo-enfant/?order=sale',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Soldes',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/?order=sale',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': None,
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
#3.2. FLATTEN THE DATA
flattened_data = json_normalize(result)
flattened_data
# Out:
#    total_count  sort                                           articles  \
# 0        22054  sale  [{'sku': 'NI116D04L-Q11', 'name': 'COURT BOROU...
#
#                   query_path                 next_page_path page_gender  \
# 0  /promo-enfant/?order=sale  /promo-enfant/?p=2&order=sale        kids
#
#    premium                                            filters  \
# 0    False  [{'key': 'sizes', 'label': 'Taille', 'url_key'...
#
#    total_article_count    plusStatus  ...  \
# 0                22057  non-eligible  ...
#
#   iconPaths.filters.standard_delivery_filter  \
# 0                            icons/truck.svg
#
#   iconPaths.filters.fast_delivery_filter iconPaths.filters.zalando_plus  \
# 0                   icons/truck-fast.svg         icons/plus-short-1.svg
#
#    iconPaths.mobileFilters.standard_delivery_filter  \
# 0                                   icons/truck.svg
#
#   iconPaths.mobileFilters.fast_delivery_filter  \
# 0                         icons/truck-fast.svg
#
#   iconPaths.mobileFilters.zalando_plus  iconPaths.flags.slow_delivery_flag  \
# 0               icons/plus-short-1.svg                     icons/clock.svg
#
#   iconPaths.flags.fast_delivery_flag  iconPaths.flags.plus_delivery_flag  \
# 0      icons/truck-fast-orange-3.svg              icons/plus-short-1.svg
#
#   iconPaths.flags.zalando_plus
# 0       icons/zalando-plus.svg
#
# [1 rows x 76 columns]

# %%
goods = json_normalize(flattened_data.articles[0])
goods
# Out:
#               sku                                               name  \
# 0   NI116D04L-Q11  COURT BOROUGH MID BOOT WINTERIZED - Chaussures...
# 1   NI114D0B9-Q14  AIR MAX 200 - Baskets basses - black/metallic ...
# 2   TO113I00G-K11                                    Bottines - blue
# 3   AD116D007-A11                STAN SMITH - Baskets basses - white
# 4   AD126L00J-Q11               JACKET - Veste d'hiver - black/white
# ..            ...                                                ...
# 79  AD114D00P-A11                TOP TEN - Baskets montantes - white
# 80  AD116D008-A12      STAN SMITH - Baskets basses - white/bold pink
# 81  NI114D0CX-B11       FORCE 1 - Baskets basses - wheat/light brown
# 82  NA824L0D7-M11    NKMMALIEN JACKET - Veste d'hiver - green gables
# 83  TF324L01D-C11                        ABEL - Veste d'hiver - grey
#
#                                                 sizes  \
# 0        [28, 28.5, 29.5, 30, 31.5, 32, 33.5, 34, 35]
# 1                    [35.5, 36.5, 37.5, 38, 38.5, 40]
# 2            [28, 29, 30, 33, 34, 35, 36, 37, 38, 40]
# 3   [28, 29, 30, 31, 32, 33, 34, 35, 28 1/2, 30 1/...
# 4                      [3-4a, 4-5a, 5-6a, 6-7a, 7-8a]
# ..                                                ...
# 79               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# 80       [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# 81             [29.5, 30, 31.5, 32, 33, 33.5, 34, 35]
# 82                  [8a, 9a, 10a, 11a, 12a, 13a, 14a]
# 83                [5-6a, 7-8a, 9-10a, 11-12a, 13-14a]
#
#                                               url_key  \
# 0   nike-sportswear-court-borough-mid-boot-winteri...
# 1   nike-sportswear-air-max-200-baskets-basses-ni1...
# 2          tommy-hilfiger-bottines-blue-to113i00g-k11
# 3   adidas-originals-stan-smith-baskets-basses-bla...
# 4   adidas-originals-jacket-veste-dhiver-blackwhit...
# ..                                                ...
# 79  adidas-originals-top-ten-baskets-montantes-bla...
# 80  adidas-originals-stan-smith-baskets-basses-ad1...
# 81  nike-sportswear-force-1-baskets-basses-wheatli...
# 82  name-it-nkmmalien-jacket-veste-dhiver-green-ga...
# 83            tiffosi-abel-veste-dhiver-tf324l01d-c11
#
#                                                 media        brand_name  \
# 0   [{'path': 'NI/11/6D/04/LQ/11/NI116D04L-Q11@8.j...   Nike Sportswear
# 1   [{'path': 'NI/11/4D/0B/9Q/14/NI114D0B9-Q14@9.j...   Nike Sportswear
# 2   [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1...    Tommy Hilfiger
# 3   [{'path': 'AD/11/6D/00/7A/11/AD116D007-A11@12....  adidas Originals
# 4   [{'path': 'AD/12/6L/00/JQ/11/AD126L00J-Q11@8.j...  adidas Originals
# ..                                                ...               ...
# 79  [{'path': 'AD/11/4D/00/PA/11/AD114D00P-A11@12....  adidas Originals
# 80  [{'path': 'AD/11/6D/00/8A/12/AD116D008-A12@12....  adidas Originals
# 81  [{'path': 'NI/11/4D/0C/XB/11/NI114D0CX-B11@11....   Nike Sportswear
# 82  [{'path': 'NA/82/4L/0D/7M/11/NA824L0D7-M11@9.j...           Name it
# 83  [{'path': 'TF/32/4L/01/DC/11/TF324L01D-C11@7.j...           Tiffosi
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'NI116D04L-Q11', 'url_key': 'nike-spo...
# 1        False  [{'sku': 'NI114D0B9-Q14', 'url_key': 'nike-spo...
# 2        False  [{'sku': 'TO113I00G-K11', 'url_key': 'tommy-hi...
# 3        False  [{'sku': 'AD116D007-A11', 'url_key': 'adidas-o...
# 4        False  [{'sku': 'AD126L00J-Q11', 'url_key': 'adidas-o...
# ..         ...                                                ...
# 79       False  [{'sku': 'AD114D00P-A11', 'url_key': 'adidas-o...
# 80       False  [{'sku': 'AD116D008-A12', 'url_key': 'adidas-o...
# 81       False  [{'sku': 'NI114D0CX-B11', 'url_key': 'nike-spo...
# 82       False  [{'sku': 'NA824L0D7-M11', 'url_key': 'name-it-...
# 83       False  [{'sku': 'TF324L01D-C11', 'url_key': 'tiffosi-...
#
#                                                 flags product_group  ...  \
# 0   [{'key': 'discountRate', 'value': 'Jusqu’à -20...          shoe  ...
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe  ...
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe  ...
# 3   [{'key': 'discountRate', 'value': 'Jusqu’à -30...          shoe  ...
# 4   [{'key': 'discountRate', 'value': 'Jusqu’à -35...      clothing  ...
# ..                                                ...           ...  ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -20...          shoe  ...
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -30...          shoe  ...
# 81  [{'key': 'discountRate', 'value': 'Jusqu’à -20...          shoe  ...
# 82  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing  ...
# 83  [{'key': 'discountRate', 'value': '-55%', 'tra...      clothing  ...
#
#    price.original price.promotional price.has_different_prices  \
# 0         54,95 €           43,95 €                       True
# 1        104,95 €           83,95 €                      False
# 2         94,95 €           66,45 €                       True
# 3         54,95 €           38,45 €                       True
# 4         64,95 €           41,95 €                       True
# ..            ...               ...                        ...
# 79        44,95 €           35,95 €                       True
# 80        64,95 €           45,45 €                       True
# 81        54,95 €           43,95 €                       True
# 82        48,99 €           19,59 €                      False
# 83        34,95 €           15,65 €                      False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                     True
# 3                                     True
# 4                                     True
# ..                                     ...
# 79                                    True
# 80                                    True
# 81                                    True
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#          tracking_information.metrigo_impression_urls  \
# 0   [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# 1   [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# 2   [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                tracking_information.impression_beacon  \
# 0   https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# 1   https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# 2   https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#    tracking_information.source amount
# 0                          ccp    NaN
# 1                          ccp    NaN
# 2                          ccp    NaN
# 3                          NaN    NaN
# 4                          NaN    NaN
# ..                         ...    ...
# 79                         NaN    NaN
# 80                         NaN    NaN
# 81                         NaN    NaN
# 82                         NaN    NaN
# 83                         NaN    NaN
#
# [84 rows x 21 columns]

# %%
#4. FIND THE TOTAL NUMBER OF PAGES

page_number= result['pagination']['page_count']
page_number
# Out:
# 263

# %%
#5. Append the data of each additional page to the flatterned data object.

complete = []
for i in range(page_number):
    offset=i*84
    url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=0'+str(offset)+'&sort=sale'
    
    response = requests.get(url, headers=header)
    results = response.json()
    x = json_normalize(result)
    flattened_data1 = json_normalize(x.articles[0])
    complete.append(flattened_data1)

data = pd.concat(complete, sort=False)
data.set_index('sku',inplace=True)
data
# Out:
#                                                             name  \
# sku
# NI116D04L-Q11  COURT BOROUGH MID BOOT WINTERIZED - Chaussures...
# NI114D0B9-Q14  AIR MAX 200 - Baskets basses - black/metallic ...
# TO113I00G-K11                                    Bottines - blue
# AD116D007-A11                STAN SMITH - Baskets basses - white
# AD126L00J-Q11               JACKET - Veste d'hiver - black/white
# ...                                                          ...
# AD114D00P-A11                TOP TEN - Baskets montantes - white
# AD116D008-A12      STAN SMITH - Baskets basses - white/bold pink
# NI114D0CX-B11       FORCE 1 - Baskets basses - wheat/light brown
# NA824L0D7-M11    NKMMALIEN JACKET - Veste d'hiver - green gables
# TF324L01D-C11                        ABEL - Veste d'hiver - grey
#
#                                                            sizes  \
# sku
# NI116D04L-Q11       [28, 28.5, 29.5, 30, 31.5, 32, 33.5, 34, 35]
# NI114D0B9-Q14                   [35.5, 36.5, 37.5, 38, 38.5, 40]
# TO113I00G-K11           [28, 29, 30, 33, 34, 35, 36, 37, 38, 40]
# AD116D007-A11  [28, 29, 30, 31, 32, 33, 34, 35, 28 1/2, 30 1/...
# AD126L00J-Q11                     [3-4a, 4-5a, 5-6a, 6-7a, 7-8a]
# ...                                                          ...
# AD114D00P-A11               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# AD116D008-A12       [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# NI114D0CX-B11             [29.5, 30, 31.5, 32, 33, 33.5, 34, 35]
# NA824L0D7-M11                  [8a, 9a, 10a, 11a, 12a, 13a, 14a]
# TF324L01D-C11                [5-6a, 7-8a, 9-10a, 11-12a, 13-14a]
#
#                                                          url_key  \
# sku
# NI116D04L-Q11  nike-sportswear-court-borough-mid-boot-winteri...
# NI114D0B9-Q14  nike-sportswear-air-max-200-baskets-basses-ni1...
# TO113I00G-K11         tommy-hilfiger-bottines-blue-to113i00g-k11
# AD116D007-A11  adidas-originals-stan-smith-baskets-basses-bla...
# AD126L00J-Q11  adidas-originals-jacket-veste-dhiver-blackwhit...
# ...                                                          ...
# AD114D00P-A11  adidas-originals-top-ten-baskets-montantes-bla...
# AD116D008-A12  adidas-originals-stan-smith-baskets-basses-ad1...
# NI114D0CX-B11  nike-sportswear-force-1-baskets-basses-wheatli...
# NA824L0D7-M11  name-it-nkmmalien-jacket-veste-dhiver-green-ga...
# TF324L01D-C11            tiffosi-abel-veste-dhiver-tf324l01d-c11
#
#                                                            media  \
# sku
# NI116D04L-Q11  [{'path': 'NI/11/6D/04/LQ/11/NI116D04L-Q11@8.j...
# NI114D0B9-Q14  [{'path': 'NI/11/4D/0B/9Q/14/NI114D0B9-Q14@9.j...
# TO113I00G-K11  [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1...
# AD116D007-A11  [{'path': 'AD/11/6D/00/7A/11/AD116D007-A11@12....
# AD126L00J-Q11  [{'path': 'AD/12/6L/00/JQ/11/AD126L00J-Q11@8.j...
# ...                                                          ...
# AD114D00P-A11  [{'path': 'AD/11/4D/00/PA/11/AD114D00P-A11@12....
# AD116D008-A12  [{'path': 'AD/11/6D/00/8A/12/AD116D008-A12@12....
# NI114D0CX-B11  [{'path': 'NI/11/4D/0C/XB/11/NI114D0CX-B11@11....
# NA824L0D7-M11  [{'path': 'NA/82/4L/0D/7M/11/NA824L0D7-M11@9.j...
# TF324L01D-C11  [{'path': 'TF/32/4L/01/DC/11/TF324L01D-C11@7.j...
#
#                      brand_name  is_premium  \
# sku
# NI116D04L-Q11   Nike Sportswear       False
# NI114D0B9-Q14   Nike Sportswear       False
# TO113I00G-K11    Tommy Hilfiger       False
# AD116D007-A11  adidas Originals       False
# AD126L00J-Q11  adidas Originals       False
# ...                         ...         ...
# AD114D00P-A11  adidas Originals       False
# AD116D008-A12  adidas Originals       False
# NI114D0CX-B11   Nike Sportswear       False
# NA824L0D7-M11           Name it       False
# TF324L01D-C11           Tiffosi       False
#
#                                                  family_articles  \
# sku
# NI116D04L-Q11  [{'sku': 'NI116D04L-Q11', 'url_key': 'nike-spo...
# NI114D0B9-Q14  [{'sku': 'NI114D0B9-Q14', 'url_key': 'nike-spo...
# TO113I00G-K11  [{'sku': 'TO113I00G-K11', 'url_key': 'tommy-hi...
# AD116D007-A11  [{'sku': 'AD116D007-A11', 'url_key': 'adidas-o...
# AD126L00J-Q11  [{'sku': 'AD126L00J-Q11', 'url_key': 'adidas-o...
# ...                                                          ...
# AD114D00P-A11  [{'sku': 'AD114D00P-A11', 'url_key': 'adidas-o...
# AD116D008-A12  [{'sku': 'AD116D008-A12', 'url_key': 'adidas-o...
# NI114D0CX-B11  [{'sku': 'NI114D0CX-B11', 'url_key': 'nike-spo...
# NA824L0D7-M11  [{'sku': 'NA824L0D7-M11', 'url_key': 'name-it-...
# TF324L01D-C11  [{'sku': 'TF324L01D-C11', 'url_key': 'tiffosi-...
#
#                                                            flags  \
# sku
# NI116D04L-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# NI114D0B9-Q14  [{'key': 'discountRate', 'value': '-20%', 'tra...
# TO113I00G-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# AD116D007-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# AD126L00J-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -35...
# ...                                                          ...
# AD114D00P-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# AD116D008-A12  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# NI114D0CX-B11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
# NA824L0D7-M11  [{'key': 'discountRate', 'value': '-60%', 'tra...
# TF324L01D-C11  [{'key': 'discountRate', 'value': '-55%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# NI116D04L-Q11          shoe                []        54,95 €
# NI114D0B9-Q14          shoe                []       104,95 €
# TO113I00G-K11          shoe                []        94,95 €
# AD116D007-A11          shoe                []        54,95 €
# AD126L00J-Q11      clothing                []        64,95 €
# ...                     ...               ...            ...
# AD114D00P-A11          shoe                []        44,95 €
# AD116D008-A12          shoe                []        64,95 €
# NI114D0CX-B11          shoe                []        54,95 €
# NA824L0D7-M11      clothing                []        48,99 €
# TF324L01D-C11      clothing                []        34,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# NI116D04L-Q11           43,95 €                        True
# NI114D0B9-Q14           83,95 €                       False
# TO113I00G-K11           66,45 €                        True
# AD116D007-A11           38,45 €                        True
# AD126L00J-Q11           41,95 €                        True
# ...                         ...                         ...
# AD114D00P-A11           35,95 €                        True
# AD116D008-A12           45,45 €                        True
# NI114D0CX-B11           43,95 €                        True
# NA824L0D7-M11           19,59 €                       False
# TF324L01D-C11           15,65 €                       False
#
#                price.has_different_original_prices  \
# sku
# NI116D04L-Q11                                False
# NI114D0B9-Q14                                False
# TO113I00G-K11                                False
# AD116D007-A11                                False
# AD126L00J-Q11                                False
# ...                                            ...
# AD114D00P-A11                                False
# AD116D008-A12                                False
# NI114D0CX-B11                                False
# NA824L0D7-M11                                False
# TF324L01D-C11                                False
#
#                price.has_different_promotional_prices  \
# sku
# NI116D04L-Q11                                    True
# NI114D0B9-Q14                                   False
# TO113I00G-K11                                    True
# AD116D007-A11                                    True
# AD126L00J-Q11                                    True
# ...                                               ...
# AD114D00P-A11                                    True
# AD116D008-A12                                    True
# NI114D0CX-B11                                    True
# NA824L0D7-M11                                   False
# TF324L01D-C11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# NI116D04L-Q11                                      False
# NI114D0B9-Q14                                      False
# TO113I00G-K11                                      False
# AD116D007-A11                                      False
# AD126L00J-Q11                                      False
# ...                                                  ...
# AD114D00P-A11                                      False
# AD116D008-A12                                      False
# NI114D0CX-B11                                      False
# NA824L0D7-M11                                      False
# TF324L01D-C11                                      False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# NI116D04L-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# NI114D0B9-Q14  [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# TO113I00G-K11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=b...
# AD116D007-A11                                                NaN
# AD126L00J-Q11                                                NaN
# ...                                                          ...
# AD114D00P-A11                                                NaN
# AD116D008-A12                                                NaN
# NI114D0CX-B11                                                NaN
# NA824L0D7-M11                                                NaN
# TF324L01D-C11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# NI116D04L-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# NI114D0B9-Q14  https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# TO113I00G-K11  https://ccp-et.metrigo.zalan.do/event/sbv?z=be...
# AD116D007-A11                                                NaN
# AD126L00J-Q11                                                NaN
# ...                                                          ...
# AD114D00P-A11                                                NaN
# AD116D008-A12                                                NaN
# NI114D0CX-B11                                                NaN
# NA824L0D7-M11                                                NaN
# TF324L01D-C11                                                NaN
#
#               tracking_information.source amount
# sku
# NI116D04L-Q11                         ccp    NaN
# NI114D0B9-Q14                         ccp    NaN
# TO113I00G-K11                         ccp    NaN
# AD116D007-A11                         NaN    NaN
# AD126L00J-Q11                         NaN    NaN
# ...                                   ...    ...
# AD114D00P-A11                         NaN    NaN
# AD116D008-A12                         NaN    NaN
# NI114D0CX-B11                         NaN    NaN
# NA824L0D7-M11                         NaN    NaN
# TF324L01D-C11                         NaN    NaN
#
# [22092 rows x 20 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
#1. Trending brand

trending = data['brand_name'].value_counts().to_frame()

trending.head(1)
# Out:
#                  brand_name
# Nike Sportswear        9994

# %%
#2. Products with the higher discount
discounts = pd.DataFrame()
discounts['price.original'] = data['price.original'].str.replace('€', '', regex=True).str.replace(',', '.', regex=True)
discounts['price.promotional'] = data['price.promotional'].str.replace('€', '', regex=True).str.replace(',', '.', regex=True)

#change data type to float
discounts[['price.original','price.promotional']] = discounts[['price.original','price.promotional']].astype('float64')

# create discount column substracting original to promotional
discounts['discount'] = discounts['price.original'] - discounts['price.promotional']
discounts = discounts.sort_values('discount', ascending=False)

#Top 10 products
discounts.head(10)
# Out:
#                price.original  price.promotional  discount
# sku
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99
# QU124L020-K11          129.99               65.0     64.99

# %%
#3. Sum of discounts of all goods 
discounts_goods = data[['brand_name','price.original', 'price.promotional']]
discounts_goods['price.original'] = discounts_goods['price.original'].str.replace('€', '', regex=True).str.replace(',', '.', regex=True)
discounts_goods['price.promotional'] = discounts_goods['price.promotional'].str.replace('€', '', regex=True).str.replace(',', '.', regex=True)

#change data type to float
discounts_goods[['price.original','price.promotional']] = discounts_goods[['price.original','price.promotional']].astype('float64')
# create discount column substracting original to promotional
discounts_goods['discounts'] = discounts_goods['price.original'] - discounts_goods['price.promotional']

# group by brand name
discounts_goods = discounts_goods[['price.original', 'price.promotional', 'discounts', 'brand_name']].groupby('brand_name').sum()
discounts_goods = discounts_goods.sort_values('discounts', ascending=False)

discounts_goods
# Out:
# C:\Users\unoma\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\unoma\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\unoma\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                   price.original  price.promotional  discounts
# brand_name
# Nike Sportswear        802702.30          622626.20  180076.10
# adidas Originals       151869.35          106475.55   45393.80
# Quiksilver              88620.48           44312.87   44307.61
# Levi's®                 65657.95           50719.55   14938.40
# Tommy Hilfiger          55190.55           41448.80   13741.75
# Boboli                  37793.10           26431.50   11361.60
# River Island            27325.70           16095.60   11230.10
# Name it                 12884.37            5152.17    7732.20
# Diesel                  13136.85            5904.35    7232.50
# Blue Seven              11821.85            4720.85    7101.00
# Nike Performance        19698.70           14570.20    5128.50
# Tiffosi                  9191.85            4115.95    5075.90
# LMTD                     9717.85            4852.35    4865.50
# New Era                 11282.70            6706.50    4576.20
# DC Shoes                 6561.85            3274.35    3287.50
# Converse                14451.85           11558.85    2893.00
# Guess                   12873.85           10296.45    2577.40
# Nike SB                 10506.85            8402.85    2104.00
# s.Oliver                10254.37            8202.97    2051.40
# Redskins                 6561.85            5246.85    1315.00

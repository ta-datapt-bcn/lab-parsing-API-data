# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url1='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'
url_OK = 'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
url_corta = 'https://www.zalando.fr/api/catalog/articles'

# %%
# headers definition
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# %%
params = {'categories': 'promo-enfant',
          'limit': '84',
          'offset': '0'}

# %%
zalando = requests.get(url_corta, headers=headers, params=params)

# %%
zalando.status_code
# Out:
# 200

# %%
zalando.ok
# Out:
# True

# %%
zalando.text
# Out:
# '{"total_count":16574,"pagination":{"page_count":198,"current_page":1,"per_page":84},"sort":"popularity","articles":[{"sku":"NI113D0A6-Q11","name":"AIR MAX 90 UNISEX - Baskets basses - black/white","price":{"original":"59,95\xa0\xa0€","promotional":"50,95\xa0\xa0€","has_different_prices":false,"has_different_original_prices":false,"has_different_promotional_prices":false,"has_discount_on_selected_sizes_only":false},"sizes":["17","18.5","19.5","21","22","23.5"],"url_key":"nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11","media":[{"path":"spp-media-p1/59cf7517d4473bdd8c4014db282fa5f3/3e0c06f7ac104665b8fe49cde6a729d3.jpg","role":"DEFAULT","packet_shot":false},{"path":"spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg","role":"HOVER","packet_shot":false}],"brand_name":"Nike Sportswear","is_premium":false,"family_articles":[{"sku":"NI113D0A6-Q11","url_key":"nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11","media":[{"path":"spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg","role":"FAMILY","packet_shot":false}],"name":"AIR MAX 90 UNISEX - Baskets basses - black/white","sizes":["17","18.5","19.5","21","22","23.5"],"price":{"original":"59,95\xa0\xa0€","promotional":"50,95\xa0\xa0€","has_different_prices":false,"has_different_original_prices":false,"has_different_promotional_prices":false,"has_discount_on_selected_sizes_only":false},"flags":[{"key":"discountRate","value":"-15%","tracking_value":"discount rate"}],"delivery_promises":[]},{"sku":"NI113D0A6-Q15","url_key":"nike-sportswear-air-max-90-unisex-baskets-basses-blackmetallic-silversunset-pulse-ni113d0a6-q15","media":[{"path":"spp-media-p1/27404412b11d3031ba0cd4aa6fcea9ff/10c616afb86d4ea7aeda4028c6778b8e.jpg","role":"FAMILY","packet_shot":true}],"name":"AIR MAX 90 UNISEX - Baskets basses - black/metallic silver/sunset pulse","sizes":["17","18.5","19.5","22","23.5","25","26","27"],"price":{"original":"64,95\xa0\xa0€","promotional":"64,95\xa0\xa0€","has_different_prices":false,"has_different_original_prices":false,"has_different_promotional_prices":false,"has_discount_on_selected_sizes_only":false},"flags":[],"delivery_promises":[]},{"sku":"NI113D0A6-A15","url_key":"nike-sportswear-air-max-90-unisex-baskets-basses-whiteiron-greychlorine-blue-ni113d0a6-a15","media":[{"path":"spp-media-p1/7cebdcbf506d382d9782f0a00ddf4a3d/cd8a82315de34e74a65ac2990637033d.jpg","role":"FAMILY","packet_shot":true}],"name":"AIR MAX 90 UNISEX - Baskets basses - white/iron grey/chlorine blue","sizes":["17","18.5","19.5","21","22","23.5","25","26"],"price":{"original":"64,95\xa0\xa0€","promotional":"64,95\xa0\xa0€","has_different_prices":false,"has_different_original_prices":false,"has_different_promotional_prices":false,"has_discount_on_selected_sizes_only":false},"flags":[],"delivery_promises":[]},{"sku":"NI113D0A6-Q12","url_key":"nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q12","media":[{"path":"spp-media-p1/7064c6d1c40832fa9ad33902e16201e2/222f7148e8724c599c4b672b9407eb2e.jpg","role":"FAMILY","packet_shot":true}],"name":"AIR MAX 90 UNISEX - Baskets basses - black/white","sizes":["17","18.5","19.5","21","22","23.5","25","26","27"],"price":{"original":"59,95\xa0\xa0€","promotional":"50,95\xa0\xa0€","has_different_prices":true,"has_different_original_prices":false,"has_different_promotional_prices":true,"has_discount_on_selected_sizes_only":false},"flags":[{"key":"discountRate","value":"Jusqu’à -15%","tracking_value":"discount rate"}],"delivery_promises":[]},{"sku":"NI113D0A6-Q13","url_key":"nike-sportswear-air-max-90-baskets-basses-ni113d0a6-q13","media":[{"path":"spp-media-p1/a964ad2723ed38ca8611c3109719711d/30ef9c4d91144100893e31623dd25174.jpg","role":"FAMILY","packet_shot":true}],"name":"AIR MAX 90 UNISEX - Baskets basses - black/light arctic pink/white/dark sulfur","sizes":["17","18.5","19.5"],"price":{"original":"64,99\xa0\xa0€","promotional":"64,99\xa0\xa0€","has_different_prices":false ...

# %%
zalando.json()
# Out:
# {'total_count': 16574,
#  'pagination': {'page_count': 198, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'NI113D0A6-Q11',
#    'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '50,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5'],
#    'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11',
#    'media': [{'path': 'spp-media-p1/59cf7517d4473bdd8c4014db282fa5f3/3e0c06f7ac104665b8fe49cde6a729d3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI113D0A6-Q11',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11',
#      'media': [{'path': 'spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '50,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q15',
#      'url_key': 'nike-sportswear-air-max-90-unisex-baskets-basses-blackmetallic-silversunset-pulse-ni113d0a6-q15',
#      'media': [{'path': 'spp-media-p1/27404412b11d3031ba0cd4aa6fcea9ff/10c616afb86d4ea7aeda4028c6778b8e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/metallic silver/sunset pulse',
#      'sizes': ['17', '18.5', '19.5', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-A15',
#      'url_key': 'nike-sportswear-air-max-90-unisex-baskets-basses-whiteiron-greychlorine-blue-ni113d0a6-a15',
#      'media': [{'path': 'spp-media-p1/7cebdcbf506d382d9782f0a00ddf4a3d/cd8a82315de34e74a65ac2990637033d.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - white/iron grey/chlorine blue',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q12',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q12',
#      'media': [{'path': 'spp-media-p1/7064c6d1c40832fa9ad33902e16201e2/222f7148e8724c599c4b672b9407eb2e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '50,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q13',
#      'url_key': 'nike-sportswear-air-max-90-baskets-basses-ni113d0a6-q13',
#      'media': [{'path': 'spp-media-p1/a964ad2723ed38ca8611c3109719711d/30ef9c4d91144100893e31623dd25174.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/light arctic pink/white/dark sulfur',
#      'sizes': ['17', '18.5', '19.5'],
#      'price': {'original': '64,99\xa0\xa0€',
#       'promotional': '64,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-J11',
#      'url_key': 'nike-sportswear-air-max-90-baskets-basses-ni113d0a6-j11',
#      'media': [{'path': 'spp-media-p1/0c91e5de8ad93e2eb754dfd9e4933db5/65bdb70cb88340c6a3b2eb2e3d9fa093.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - barely rose/white/black',
#      'sizes': ['17', '18.5', '19.5'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-A11',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-a11',
#      'media': [{'path': 'spp-media-p1/a272840440863532b56b03ef9b50587e/a851ae6d98b44f76831a04d766facbd2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - white/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '53,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=5694a196-5721-4e79-ab95-22c5c50ea3a7&c=30078628&a=30078629&s=NI113D0A6-Q11&is=1689&at=browser&cm=360000&ovm=1905&r=0.008419834077358246&lt=f&ts=0&cs=2464258966'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=5694a196-5721-4e79-ab95-22c5c50ea3a7&c=30078628&a=30078629&s=NI113D0A6-Q11&is=1689&at=browser&cm=360000&ovm=1905&r=0.008419834077358246&lt=f&ts=0&cs=2464258966',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ON523G00J-J11',
#    'name': 'S/SLV ALL YEAR SHORTSLEEVE - T-shirt imprimé - cabaret',
#    'price': {'original': '17,99\xa0\xa0€',
#     'promotional': '9,00\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '12a', '14a'],
#    'url_key': 'oneill-sslv-all-year-shortsleeve-t-shirt-imprime-cabaret-on523g00j-j11',
#    'media': [{'path': 'spp-media-p1/fc18f4a0b2e13d818a06f52e0f5f06c9/40c1af954a144eb1a58186d8df7aefcc.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': "O'Neill",
#    'is_premium': False,
#    'family_articles': [{'sku': 'ON523G00J-J11',
#      'url_key': 'oneill-sslv-all-year-shortsleeve-t-shirt-imprime-cabaret-on523g00j-j11',
#      'media': [{'path': 'spp-media-p1/fc18f4a0b2e13d818a06f52e0f5f06c9/40c1af954a144eb1a58186d8df7aefcc.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'S/SLV ALL YEAR SHORTSLEEVE - T-shirt imprimé - cabaret',
#      'sizes': ['8a', '12a', '14a'],
#      'price': {'original': '17,99\xa0\xa0€',
#       'promotional': '9,00\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'ON523G00J-K11',
#      'url_key': 'oneill-sslv-all-year-shortsleeve-t-shirt-imprime-ink-blue-on523g00j-k11',
#      'media': [{'path': 'spp-media-p1/25a44eb43b0d39a98ae4f7af4b5ea48f/4ea2c2f0f9f14ce1a91478d26774a260.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'S/SLV ALL YEAR SHORTSLEEVE - T-shirt imprimé - ink blue',
#      'sizes': ['8a', '10a', '12a'],
#      'price': {'original': '17,99\xa0\xa0€',
#       'promotional': '9,00\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'ON523G00J-C11',
#      'url_key': 'oneill-sslv-all-year-shortsleeve-t-shirt-imprime-silver-melee-on523g00j-c11',
#      'media': [{'path': 'spp-media-p1/ce08e48fc7573b16bd9e92346f461c02/7790465161114a65b386e3eff3009ed4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'S/SLV ALL YEAR SHORTSLEEVE - T-shirt imprimé - silver melee',
#      'sizes': ['10a', '12a', '14a', '16a'],
#      'price': {'original': '17,99\xa0\xa0€',
#       'promotional': '9,00\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=27de5659-8300-4307-9fa8-3a901850b1f2&c=30081784&a=30081795&s=ON523G00J-J11&is=1689&at=browser&cm=370000&ovm=1849&r=0.005149907898157835&lt=f&ts=0&cs=962339039'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=27de5659-8300-4307-9fa8-3a901850b1f2&c=30081784&a=30081795&s=ON523G00J-J11&is=1689&at=browser&cm=370000&ovm=1849&r=0.005149907898157835&lt=f&ts=0&cs=962339039',
#     'source': 'ccp'},
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'SA543A079-K11',
#    'name': 'SPEEDCROSS UNISEX - Chaussures de marche - turkish sea/little boy blue/lemon zest',
#    'price': {'original': '74,95\xa0\xa0€',
#     'promotional': '63,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '33', '34', '35', '36', '37', '38', '39'],
#    'url_key': 'salomon-speedcross-unisex-chaussures-de-marche-turkish-sealittle-boy-bluelemon-zest-sa543a079-k11',
#    'media': [{'path': 'spp-media-p1/3d72a3ed3fd63fdcb6cc3170382e45f2/86a4417deb9940d18f6d2dd60a4737bb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Salomon',
#    'is_premium': False,
#    'family_articles': [{'sku': 'SA543A079-K11',
#      'url_key': 'salomon-speedcross-unisex-chaussures-de-marche-turkish-sealittle-boy-bluelemon-zest-sa543a079-k11',
#      'media': [{'path': 'spp-media-p1/3d72a3ed3fd63fdcb6cc3170382e45f2/86a4417deb9940d18f6d2dd60a4737bb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SPEEDCROSS UNISEX - Chaussures de marche - turkish sea/little boy blue/lemon zest',
#      'sizes': ['32', '33', '34', '35', '36', '37', '38', '39'],
#      'price': {'original': '74,95\xa0\xa0€',
#       'promotional': '63,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=8d2d8864-15b4-4d00-bf60-fa35753bba21&c=30082746&a=30082749&s=SA543A079-K11&is=1689&at=browser&cm=420000&ovm=1633&r=0.004404212813824415&lt=f&ts=0&cs=238995698'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=141343be-3800-47c1-ac97-c14658608e30&b=8d2d8864-15b4-4d00-bf60-fa35753bba21&c=30082746&a=30082749&s=SA543A079-K11&is=1689&at=browser&cm=420000&ovm=1633&r=0.004404212813824415&lt=f&ts=0&cs=238995698',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA214D00F-Q11',
#    'name': 'OLD SKOOL  - Baskets basses - black/true white',
#    'price': {'original': '50,00\xa0\xa0€',
#     'promotional': '41,05\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27', '28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'vans-baskets-basses-black-true-white-va214d00f-q11',
#    'media': [{'path': 'spp-media-p1/95d2a499250f3a188daca0bd4600e61b/b6f3105f0e64483b902c718c75722ad3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'VA214D00F-Q11',
#      'url_key': 'vans-baskets-basses-black-true-white-va214d00f-q11',
#      'media': [{'path': 'spp-media-p1/95d2a499250f3a188daca0bd4600e61b/b6f3105f0e64483b902c718c75722ad3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'OLD SKOOL  - Baskets basses - black/true white',
#      'sizes': ['27', '28', '29', '30', '31', '32', '33', '34'],
#      'price': {'original': '50,00\xa0\xa0€',
#       'promotional': '41,05\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -18%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -18%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JAN24B004-Q11',
#    'name': 'Pantalon cargo - black',
#    'price': {'original': '49,95\xa0\xa0€',
#     'promotional': '34,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '10a', '11a', '12a', '13a', '14a', '15a', '16a'],
#    'url_key': 'jackandjones-junior-pantalon-cargo-black-jan24b004-q11',
#    'media': [{'path': 'spp-media-p1/6272154bdaec3231bf44b917907edaf1/2c7676f41e0e45d4b4f6819397e2148b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Jack & Jones Junior',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JAN24B004-Q11',
#      'url_key': 'jackandjones-junior-pantalon-cargo-black-jan24b004-q11',
#      'media': [{'path': 'spp-media-p1/6272154bdaec3231bf44b917907edaf1/2c7676f41e0e45d4b4f6819397e2148b.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon cargo - black',
#      'sizes': ['8a', '9a', '10a', '11a', '12a', '13a', '14a', '15a', '16a'],
#      'price': {'original': '49,95\xa0\xa0€',
#       'promotional': '34,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D008-A11',
#    'name': 'STAN SMITH - Baskets basses - white/green',
#    'price': {'original': '64,95\xa0\xa0€',
#     'promotional': '45,45\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#    'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D008-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#      'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/green',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '45,45\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A12',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#      'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/bold pink',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A15',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a15',
#      'media': [{'path': 'spp-media-p1/32b1d11842a63545bc860debc9bcbc6d/330d76ea4a9f4040869fe91b37c787f6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - running white-bold pink',
#      'sizes': ['36 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,94\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1243A113-Q11',
#    'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/white/anthracite',
#    'price': {'original': '37,95\xa0\xa0€',
#     'promotional': '30,35\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q11',
#    'media': [{'path': 'spp-media-p1/ef91b309eef63df2966125c738d6ab9a/38089ae99eb446d19e6c954a1142cc0b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243A113-Q11',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q11',
#      'media': [{'path': 'spp-media-p1/ee28745d4b78349c8ab625b01078964e/340ce276a7d14b21ba622344d19e64bb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/white/anthracite',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '30,35\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'amount': '171 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C11',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-c11',
#      'media': [{'path': 'spp-media-p1/c18ca39836203a668081d86160f46b30/85804619633a4d58835d0ae4b81b9801.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - cool grey/pure platinum/dark grey',
#      'sizes': ['27.5', '34'],
#      'price': {'original': '35,95\xa0\xa0€',
#       'promotional': '35,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': [{'key': 'slow_delivery_flag',
#        'label': 'Livraison longue distance',
#        'media_key': 'slow_delivery_flag'}]},
#     {'sku': 'N1243A113-C14',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-c14',
#      'media': [{'path': 'spp-media-p1/8034d0b6e4793484bf3d1862e171b692/c5625e2bf53444f0bf27bd4244ae4ed3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - smoke grey/pink glow/photon dust/white',
#      'sizes': ['28.5'],
#      'price': {'original': '37,99\xa0\xa0€',
#       'promotional': '37,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '177 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C18',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-smoke-greychlorine-bluehigh-voltagewhite-n1243a113-c18',
#      'media': [{'path': 'spp-media-p1/a5762e07cdaf33cebbf5484a03f5474a/c2a6cd61e42443008cba63d18cf9b2b2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - smoke grey/chlorine blue/high voltage/white',
#      'sizes': ['27.5',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '168 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q15',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-blackuniversity-redwhite-n1243a113-q15',
#      'media': [{'path': 'spp-media-p1/6905ab6547fd34c283ed973896174ad0/1d71d7a2e92844a7a5c0c4eaff0ad9ce.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/university red/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '134 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-K13',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-game-royallight-smoke-greywhite-n1243a113-k13',
#      'media': [{'path': 'spp-media-p1/2ff692da3f74309da883931fb9cd38c0/ac3095ef0c874914907a7b13e408bd15.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - game royal/light smoke grey/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '135 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-J13',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-sunset-pulseblackwhite-n1243a113-j13',
#      'media': [{'path': 'spp-media-p1/07443f4116d33730830d76bd6a52602f/01dd0ec28eee4cf796e1003a5df9cccc.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - sunset pulse/black/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '36,95\xa0\xa0€',
#       'promotional': '36,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C17',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-football-greypurple-pulsefireberrywhite-n1243a113-c17',
#      'media': [{'path': 'spp-media-p1/6bdbd183691a31f6ba04c586aff39551/67d6f4a9eaf64087b6f448b6c08da382.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - football grey/purple pulse/fireberry/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '34,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'amount': '134 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q13',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q13',
#      'media': [{'path': 'spp-media-p1/a976bca9cc1f35cc9e60c74371f5585d/966cc41bc77b41a8a7b06823c6cd7fed.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/sunset pulse',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '34,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'amount': '168 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-J12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-j12',
#      'media': [{'path': 'spp-media-p1/7100cf3ed6f733d0939c3bdc36c09a7e/8ccf85b3a3f44ecb82b3b27f543900bc.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - active fuchsia/metallic silver/black',
#      'sizes': ['32', '33', '34', '35'],
#      'price': {'original': '38,00\xa0\xa0€',
#       'promotional': '38,00\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'Prix Mini',
#        'tracking_value': 'fr_prixmini_old_season_2019_28'}],
#      'amount': '138 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-K12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-k12',
#      'media': [{'path': 'spp-media-p1/798b761ffa983fcd9d17cc5ca5fea966/dad5bbf355404bfc981d3144c1747ba3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - midnight navy/white/black',
#      'sizes': ['28', '30', '31', '32', '33', '35'],
#      'price': {'original': '37,99\xa0\xa0€',
#       'promotional': '37,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '140 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-blackanthracite-n1243a113-q12',
#      'media': [{'path': 'spp-media-p1/1d18289e94d53e09a880ceb3dcf596e1/262fa64cc78049e382d6cf78673cd3ec.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/anthracite',
#      'sizes': ['27.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '35,95\xa0\xa0€',
#       'promotional': '35,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'amount': '171 g',
#    'delivery_promises': []},
#   {'sku': 'AD116D0TD-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/silver metallic',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '41,95\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitesilver-metallic-ad116d0td-a11',
#    'media': [{'path': 'spp-media-p1/f0bebac2d9de3d85a7dc535b0d91a220/adaef1f009a845a48f90d3a5e44f38b6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D0TD-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitesilver-metallic-ad116d0td-a11',
#      'media': [{'path': 'spp-media-p1/e3be3c7d79c5399280c7aefebd5444d8/ffdac8bb1df548c999475b25d7dac289.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - footwear white/silver metallic',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D0TD-Q11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-core-blackgold-metallic-ad116d0td-q11',
#      'media': [{'path': 'spp-media-p1/1c41b064dff73880b0958fd352df31bd/1d325040019642d5979c80bce7300598.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - core black/gold metallic',
#      'sizes': ['36', '36 2/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '59,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D008-A12',
#    'name': 'STAN SMITH - Baskets basses - white/bold pink',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '41,95\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#    'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D008-A12',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#      'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/bold pink',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#      'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/green',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '45,45\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A15',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a15',
#      'media': [{'path': 'spp-media-p1/32b1d11842a63545bc860debc9bcbc6d/330d76ea4a9f4040869fe91b37c787f6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - running white-bold pink',
#      'sizes': ['36 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,94\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TH343D005-Q12',
#    'name': 'SIMPLE DOME UNISEX - T-shirt basique - black',
#    'price': {'original': '19,95\xa0\xa0€',
#     'promotional': '16,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#    'url_key': 'the-north-face-simple-dome-t-shirt-imprime-th343d005-q12',
#    'media': [{'path': 'spp-media-p1/7a8bf28e74e9324e80f46b8585ba63bb/4acb8a81d41a421397a9bede731579e4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'The North Face',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TH343D005-Q12',
#      'url_key': 'the-north-face-simple-dome-t-shirt-imprime-th343d005-q12',
#      'media': [{'path': 'spp-media-p1/7a8bf28e74e9324e80f46b8585ba63bb/4acb8a81d41a421397a9bede731579e4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - black',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '16,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-C11',
#      'url_key': 'the-north-face-simple-dome-t-shirt-basique-th343d005-c11',
#      'media': [{'path': 'spp-media-p1/28e59eb103c0384689b4390bf590be89/73feeb01b1e3418b800ad54ee2cdf31c.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - medium grey heather',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-M11',
#      'url_key': 'the-north-face-simple-dome-unisex-t-shirt-basique-green-th343d005-m11',
#      'media': [{'path': 'spp-media-p1/67276a03f20f4abbac3f3f36f1ce9b8d/649116ed90fc44a6824890a0a071300e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - green',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '16,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-N13',
#      'url_key': 'the-north-face-simple-dome-tee-t-shirt-basique-new-taupe-green-th343d005-n13',
#      'media': [{'path': 'spp-media-p1/55d1f02c508732719a85628a2aa2d39c/fc1c7fab3a824610b9f789734369fe9c.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - new taupe green',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-A12',
#      'url_key': 'the-north-face-youth-simple-dome-tee-t-shirt-imprime-whiteblack-th343d005-a12',
#      'media': [{'path': 'spp-media-p1/8a25f31036803bb39d3aa301ba53696f/95778eac7506418bb67bd5b9452a18f1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - white/black',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE226G002-G12',
#    'name': 'BATWING UNISEX - T-shirt à manches longues - red',
#    'price': {'original': '17,95\xa0\xa0€',
#     'promotional': '16,15\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#    'url_key': 'levisr-batwing-tee-baby-t-shirt-a-manches-longues-le226g002-g12',
#    'media': [{'path': 'spp-media-p1/2d560118d16f3981ac263df7aded1f64/4bec978d5f294c04bbd0524527aad100.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE226G002-G12',
#      'url_key': 'levisr-batwing-tee-baby-t-shirt-a-manches-longues-le226g002-g12',
#      'media': [{'path': 'spp-media-p1/2d560118d16f3981ac263df7aded1f64/4bec978d5f294c04bbd0524527aad100.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - red',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '16,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-K12',
#      'url_key': 'levis-batwing-unisex-t-shirt-a-manches-longues-mottled-blue-le226g002-k12',
#      'media': [{'path': 'spp-media-p1/da6693d930993bfeb388ed13a59cc0f7/320e402801974d5a8337c1921cf8711d.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - mottled blue',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-C11',
#      'url_key': 'levis-batwing-unisex-t-shirt-a-manches-longues-grey-le226g002-c11',
#      'media': [{'path': 'spp-media-p1/fcb13c0a6bba3299b2a418ea0bae2c33/a4baec04906748618ecb9e21db502b6a.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - grey',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,05\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-5%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-K11',
#      'url_key': 'levisr-batwing-baby-t-shirt-a-manches-longues-le226g002-k11',
#      'media': [{'path': 'spp-media-p1/7f9eec0ab3f03e1f8fce21c47cd93d3b/0e6d33a74a724a5c982da7e51510120e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - dress blues',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-A11',
#      'url_key': 'levisr-batwing-baby-t-shirt-a-manches-longues-le226g002-a11',
#      'media': [{'path': 'spp-media-p1/d066f68744be37a7a968a41d2bc31735/b7302e193cc1473ab3ad0bf16180130e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - white',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,05\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-5%',
# ...
#     {'key': 'YELLOW', 'label': 'jaune', 'metadata': {'hex_code': '#fd3'}},
#     {'key': 'ORANGE', 'label': 'orange', 'metadata': {'hex_code': '#fb863b'}},
#     {'key': 'RED', 'label': 'rouge', 'metadata': {'hex_code': '#ff0002'}},
#     {'key': 'PINK', 'label': 'rose', 'metadata': {'hex_code': '#f563b9'}},
#     {'key': 'PURPLE', 'label': 'violet', 'metadata': {'hex_code': '#9349aa'}},
#     {'key': 'GOLD',
#      'label': 'doré',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/gold.jpg'}},
#     {'key': 'SILVER',
#      'label': 'argenté',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/silver.jpg'}},
#     {'key': 'MULTICOLORED',
#      'label': 'multicolore',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/multicolored.jpg'}}]},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 415,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'free_delivery',
#    'label': 'Livraison gratuite',
#    'url_key': 'free_delivery',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison gratuite'}],
#    'description': 'pour toute commande d’un montant supérieur à 24,90€'},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Voir les articles issus de sources éco-responsables ou certifiés par un organisme indépendant.'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '9', 'label': '9 packs'},
#     {'key': '10', 'label': '10 packs'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'casual'},
#     {'key': 'boho_dress', 'label': 'robe bohème'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 16571,
#  'assortment_entry_points': [],
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/',
#      'children': [],
#      'article_count': 10769,
#      'entity_id': 'categ:promo-mode-enfant'},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/',
#      'children': [],
#      'article_count': 2794,
#      'entity_id': 'categ:promo-chaussures-enfant'},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/',
#      'children': [],
#      'article_count': 2792,
#      'entity_id': 'categ:promo-sport-enfant'},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/',
#      'children': [],
#      'article_count': 818,
#      'entity_id': 'categ:promo-accessoires-enfant'},
#     {'label': 'Espace Créateurs',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/',
#      'children': [],
#      'article_count': 1340,
#      'entity_id': 'categ:promo-luxe-enfant'}],
#    'article_count': 16571,
#    'entity_id': 'categ:promo-enfant'}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/'},
#     {'label': 'Promos',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promos',
#       'seo_label': 'Soldes enfant',
#       'reset_url': '/',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/',
#   'reset_url': '/promo-enfant/',
#   'app_url': '?urlKey=promo-enfant&order=popularity&appdomainId=11',
#   'url': '/promo-enfant/',
#   'positive_hidden_filters': []},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promos',
#     'seo_label': 'Soldes enfant',
#     'reset_url': '/',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'blackFridayGradientEnabled': False,
#   'cyberweekGradientEnabled': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-teaser': 12,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'size-dialog': 18,
#   'outfits': [5, 23, 35],
#   'outfits-mobile': [5, 23, 28, 35],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-mobile-teaser': 4},
#  'followBrandsBannerEnabled': True,
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'articleFlagPresetOverrides': {},
#  'teaser': None,
#  'inCatalogTeaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://crow.zalando.de/impressions/1edccda9-ab6a-43d8-a65b-2276cbf44680/141343be-3800-47c1-ac97-c14658608e30/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2533afe3-a9a9-4bdb-9dab-705d15fb6c97&timeUnit=DAY&timeUnitCount=1&uuid=e17178fc-e935-4cd4-89fe-c9b09b1f4772&bid=null&requestId=275e7ce2-f992-42f4-941a-fdef8e79720d&adLocation=catalog&frontendType=browser&shopCategoryBreadcrumbs=enfant,promo-enfant&s=4F9501261A6B41FC9E4378F47ECE97BF'],
#    'images': [{'aspect_ratio': '877:1266',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/4bc4cb1f-74a3-4a08-80e8-8955c5fb5469.jpg',
#      'image_width': 877}],
#    'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#    'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#    'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#    'text_fields': {'cta': 'Découvrez maintenant',
#     'sales_template': 'None',
#     'title': 'Carte cadeau Zalando'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'catalog',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'shop_category_breadcrumbs': 'enfant,promo-enfant',
#       'time_unit_count': 1,
#       'shop_slot_id': 'in_catalog',
#       'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#       'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#       'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#       'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#       'flow_id': 'bvPZPRp89nYQfTfB',
#       'price': 0.018522013952644745,
#       'time_unit': 'DAY',
#       'campaign_source_id': 'undefined',
#       'request_id': '275e7ce2-f992-42f4-941a-fdef8e79720d',
#       'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}},
#     'view': {'type': 'teaser view',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'name': 'Carte cadeau Zalando',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_category_breadcrumbs': 'enfant,promo-enfant',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#        'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#        'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'bvPZPRp89nYQfTfB',
#        'price': 0.018522013952644745,
#        'time_unit': 'DAY',
#        'campaign_source_id': 'undefined',
#        'request_id': '275e7ce2-f992-42f4-941a-fdef8e79720d',
#        'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}}},
#     'click': {'type': 'teaser click',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'name': 'Carte cadeau Zalando',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_category_breadcrumbs': 'enfant,promo-enfant',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#        'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#        'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'bvPZPRp89nYQfTfB',
#        'price': 0.018522013952644745,
#        'time_unit': 'DAY',
#        'campaign_source_id': 'undefined',
#        'request_id': '275e7ce2-f992-42f4-941a-fdef8e79720d',
#        'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}}}},
#    'view_pixels': ['https://crow.zalando.de/views/1edccda9-ab6a-43d8-a65b-2276cbf44680/141343be-3800-47c1-ac97-c14658608e30/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2533afe3-a9a9-4bdb-9dab-705d15fb6c97&timeUnit=DAY&timeUnitCount=1&uuid=768db568-e3d8-4ac2-8ee9-c76f73e50547&bid=19&requestId=275e7ce2-f992-42f4-941a-fdef8e79720d&adLocation=catalog&frontendType=browser&shopCategoryBreadcrumbs=enfant,promo-enfant&s=EF630E1544A62D8D2A2D270AC664E7EE'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'bvPZPRp89nYQfTfB',
#      'entity_id': None,
#      'shop_slot_id': 'in_catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#      'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'shop_category_breadcrumbs': 'enfant,promo-enfant',
#      'time_unit_count': 1,
#      'shop_slot_id': 'in_catalog',
#      'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#      'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#      'category_id': 'ab17ddc7-27f6-4306-bb10-bfff5c3c9316',
#      'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#      'flow_id': 'bvPZPRp89nYQfTfB',
#      'price': 0.018522013952644745,
#      'time_unit': 'DAY',
#      'campaign_source_id': 'undefined',
#      'request_id': '275e7ce2-f992-42f4-941a-fdef8e79720d',
#      'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#      'technical_experiments': '[]'}},
#    'click_url': 'https://www.zalando.fr/cheque-cadeau'},
#   'channel_name': 'CF',
#   'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951'},
#  'upperInCatTeaser': None,
#  'inGridTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
pd.json_normalize(zalando.json())
# Out:
#    total_count        sort                                           articles  \
# 0        16574  popularity  [{'sku': 'NI113D0A6-Q11', 'name': 'AIR MAX 90 ...
#
#        query_path      next_page_path page_gender  premium appliedSort  \
# 0  /promo-enfant/  /promo-enfant/?p=2        kids    False        None
#
#                                              filters  total_article_count  \
# 0  [{'key': 'sizes', 'label': 'Taille', 'url_key'...                16571
#
#    ... inCatalogTeaser.content.tracking_data.cf_tracking_params.flow_id  \
# 0  ...                                   bvPZPRp89nYQfTfB
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.price  \
# 0                                           0.018522
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.time_unit  \
# 0                                                DAY
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.campaign_source_id  \
# 0                                          undefined
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.request_id  \
# 0               275e7ce2-f992-42f4-941a-fdef8e79720d
#
#    inCatalogTeaser.content.tracking_data.cf_tracking_params.campaign_id  \
# 0               1edccda9-ab6a-43d8-a65b-2276cbf44680
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.technical_experiments  \
# 0                                                 []
#
#       inCatalogTeaser.content.click_url  inCatalogTeaser.channel_name  \
# 0  https://www.zalando.fr/cheque-cadeau                            CF
#
#                 inCatalogTeaser.slot_id
# 0  cb224cac-736d-4e00-b757-d8a8007ef951
#
# [1 rows x 182 columns]

# %%
#trying a shorter way to do it
zalando2 = requests.get(url_corta, headers=headers, params=params).json()

# %%
zalando2
# Out:
# {'total_count': 16574,
#  'pagination': {'page_count': 198, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'NI113D0A6-Q11',
#    'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '50,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5'],
#    'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11',
#    'media': [{'path': 'spp-media-p1/59cf7517d4473bdd8c4014db282fa5f3/3e0c06f7ac104665b8fe49cde6a729d3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI113D0A6-Q11',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q11',
#      'media': [{'path': 'spp-media-p1/41e47bd773f63fa69681015021990b5b/588d9547db774c829d2e3ccbf979e7ee.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '50,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q15',
#      'url_key': 'nike-sportswear-air-max-90-unisex-baskets-basses-blackmetallic-silversunset-pulse-ni113d0a6-q15',
#      'media': [{'path': 'spp-media-p1/27404412b11d3031ba0cd4aa6fcea9ff/10c616afb86d4ea7aeda4028c6778b8e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/metallic silver/sunset pulse',
#      'sizes': ['17', '18.5', '19.5', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-A15',
#      'url_key': 'nike-sportswear-air-max-90-unisex-baskets-basses-whiteiron-greychlorine-blue-ni113d0a6-a15',
#      'media': [{'path': 'spp-media-p1/7cebdcbf506d382d9782f0a00ddf4a3d/cd8a82315de34e74a65ac2990637033d.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - white/iron grey/chlorine blue',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q12',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-q12',
#      'media': [{'path': 'spp-media-p1/7064c6d1c40832fa9ad33902e16201e2/222f7148e8724c599c4b672b9407eb2e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '50,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-Q13',
#      'url_key': 'nike-sportswear-air-max-90-baskets-basses-ni113d0a6-q13',
#      'media': [{'path': 'spp-media-p1/a964ad2723ed38ca8611c3109719711d/30ef9c4d91144100893e31623dd25174.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - black/light arctic pink/white/dark sulfur',
#      'sizes': ['17', '18.5', '19.5'],
#      'price': {'original': '64,99\xa0\xa0€',
#       'promotional': '64,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-J11',
#      'url_key': 'nike-sportswear-air-max-90-baskets-basses-ni113d0a6-j11',
#      'media': [{'path': 'spp-media-p1/0c91e5de8ad93e2eb754dfd9e4933db5/65bdb70cb88340c6a3b2eb2e3d9fa093.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - barely rose/white/black',
#      'sizes': ['17', '18.5', '19.5'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI113D0A6-A11',
#      'url_key': 'nike-sportswear-nike-air-max-90-ltr-baskets-basses-ni113d0a6-a11',
#      'media': [{'path': 'spp-media-p1/a272840440863532b56b03ef9b50587e/a851ae6d98b44f76831a04d766facbd2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 90 UNISEX - Baskets basses - white/white',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '53,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=3b8fff5e-b702-4707-b0fe-ca297da70e74&c=30078628&a=30078629&s=NI113D0A6-Q11&is=1689&at=browser&cm=360000&ovm=1849&r=0.008419834077358246&lt=f&ts=0&cs=3166249838'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=3b8fff5e-b702-4707-b0fe-ca297da70e74&c=30078628&a=30078629&s=NI113D0A6-Q11&is=1689&at=browser&cm=360000&ovm=1849&r=0.008419834077358246&lt=f&ts=0&cs=3166249838',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'SA543A079-K11',
#    'name': 'SPEEDCROSS UNISEX - Chaussures de marche - turkish sea/little boy blue/lemon zest',
#    'price': {'original': '74,95\xa0\xa0€',
#     'promotional': '63,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '33', '34', '35', '36', '37', '38', '39'],
#    'url_key': 'salomon-speedcross-unisex-chaussures-de-marche-turkish-sealittle-boy-bluelemon-zest-sa543a079-k11',
#    'media': [{'path': 'spp-media-p1/3d72a3ed3fd63fdcb6cc3170382e45f2/86a4417deb9940d18f6d2dd60a4737bb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Salomon',
#    'is_premium': False,
#    'family_articles': [{'sku': 'SA543A079-K11',
#      'url_key': 'salomon-speedcross-unisex-chaussures-de-marche-turkish-sealittle-boy-bluelemon-zest-sa543a079-k11',
#      'media': [{'path': 'spp-media-p1/3d72a3ed3fd63fdcb6cc3170382e45f2/86a4417deb9940d18f6d2dd60a4737bb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SPEEDCROSS UNISEX - Chaussures de marche - turkish sea/little boy blue/lemon zest',
#      'sizes': ['32', '33', '34', '35', '36', '37', '38', '39'],
#      'price': {'original': '74,95\xa0\xa0€',
#       'promotional': '63,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=4dcb0ff2-6e8d-451a-b73f-3029766590cd&c=30082746&a=30082749&s=SA543A079-K11&is=1689&at=browser&cm=420000&ovm=1633&r=0.004404212813824415&lt=f&ts=0&cs=2980789673'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=4dcb0ff2-6e8d-451a-b73f-3029766590cd&c=30082746&a=30082749&s=SA543A079-K11&is=1689&at=browser&cm=420000&ovm=1633&r=0.004404212813824415&lt=f&ts=0&cs=2980789673',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D07I-Q12',
#    'name': 'AIR MAX 270  - Baskets basses - black/anthracite/white',
#    'price': {'original': '84,95\xa0\xa0€',
#     'promotional': '76,45\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-sportswear-air-max-270-baskets-basses-ni114d07i-q12',
#    'media': [{'path': 'spp-media-p1/7d0a21c70a343986a8d2d739c00ff0ea/202d7fb502454282b5f24d5fa0940038.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D07I-Q12',
#      'url_key': 'nike-sportswear-air-max-270-baskets-basses-ni114d07i-q12',
#      'media': [{'path': 'spp-media-p1/af6109647d3c3598901db3e1f570bab6/632b163389724ca894a2fdb4626a3658.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'AIR MAX 270  - Baskets basses - black/anthracite/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '84,95\xa0\xa0€',
#       'promotional': '76,45\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=3e691a08-1f37-4bda-bbd2-90d5de39a731&c=30078628&a=30078629&s=NI114D07I-Q12&is=1689&at=browser&cm=360000&ovm=1361&r=0.004538321867585182&lt=f&ts=0&cs=4136983705'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=6d086803-8650-4992-b212-2793763042be&b=3e691a08-1f37-4bda-bbd2-90d5de39a731&c=30078628&a=30078629&s=NI114D07I-Q12&is=1689&at=browser&cm=360000&ovm=1361&r=0.004538321867585182&lt=f&ts=0&cs=4136983705',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA214D00F-Q11',
#    'name': 'OLD SKOOL  - Baskets basses - black/true white',
#    'price': {'original': '50,00\xa0\xa0€',
#     'promotional': '41,05\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27', '28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'vans-baskets-basses-black-true-white-va214d00f-q11',
#    'media': [{'path': 'spp-media-p1/95d2a499250f3a188daca0bd4600e61b/b6f3105f0e64483b902c718c75722ad3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'VA214D00F-Q11',
#      'url_key': 'vans-baskets-basses-black-true-white-va214d00f-q11',
#      'media': [{'path': 'spp-media-p1/95d2a499250f3a188daca0bd4600e61b/b6f3105f0e64483b902c718c75722ad3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'OLD SKOOL  - Baskets basses - black/true white',
#      'sizes': ['27', '28', '29', '30', '31', '32', '33', '34'],
#      'price': {'original': '50,00\xa0\xa0€',
#       'promotional': '41,05\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -18%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -18%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JAN24B004-Q11',
#    'name': 'Pantalon cargo - black',
#    'price': {'original': '49,95\xa0\xa0€',
#     'promotional': '34,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '10a', '11a', '12a', '13a', '14a', '15a', '16a'],
#    'url_key': 'jackandjones-junior-pantalon-cargo-black-jan24b004-q11',
#    'media': [{'path': 'spp-media-p1/6272154bdaec3231bf44b917907edaf1/2c7676f41e0e45d4b4f6819397e2148b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Jack & Jones Junior',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JAN24B004-Q11',
#      'url_key': 'jackandjones-junior-pantalon-cargo-black-jan24b004-q11',
#      'media': [{'path': 'spp-media-p1/6272154bdaec3231bf44b917907edaf1/2c7676f41e0e45d4b4f6819397e2148b.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon cargo - black',
#      'sizes': ['8a', '9a', '10a', '11a', '12a', '13a', '14a', '15a', '16a'],
#      'price': {'original': '49,95\xa0\xa0€',
#       'promotional': '34,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D008-A11',
#    'name': 'STAN SMITH - Baskets basses - white/green',
#    'price': {'original': '64,95\xa0\xa0€',
#     'promotional': '45,45\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#    'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D008-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#      'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/green',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '45,45\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A12',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#      'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/bold pink',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A15',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a15',
#      'media': [{'path': 'spp-media-p1/32b1d11842a63545bc860debc9bcbc6d/330d76ea4a9f4040869fe91b37c787f6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - running white-bold pink',
#      'sizes': ['36 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,94\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1243A113-Q11',
#    'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/white/anthracite',
#    'price': {'original': '37,95\xa0\xa0€',
#     'promotional': '30,35\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q11',
#    'media': [{'path': 'spp-media-p1/ef91b309eef63df2966125c738d6ab9a/38089ae99eb446d19e6c954a1142cc0b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243A113-Q11',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q11',
#      'media': [{'path': 'spp-media-p1/ee28745d4b78349c8ab625b01078964e/340ce276a7d14b21ba622344d19e64bb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/white/anthracite',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '30,35\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'amount': '171 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C14',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-c14',
#      'media': [{'path': 'spp-media-p1/8034d0b6e4793484bf3d1862e171b692/c5625e2bf53444f0bf27bd4244ae4ed3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - smoke grey/pink glow/photon dust/white',
#      'sizes': ['28.5'],
#      'price': {'original': '37,99\xa0\xa0€',
#       'promotional': '37,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '177 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C11',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-c11',
#      'media': [{'path': 'spp-media-p1/c18ca39836203a668081d86160f46b30/85804619633a4d58835d0ae4b81b9801.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - cool grey/pure platinum/dark grey',
#      'sizes': ['27.5', '34'],
#      'price': {'original': '35,95\xa0\xa0€',
#       'promotional': '35,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': [{'key': 'slow_delivery_flag',
#        'label': 'Livraison longue distance',
#        'media_key': 'slow_delivery_flag'}]},
#     {'sku': 'N1243A113-C18',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-smoke-greychlorine-bluehigh-voltagewhite-n1243a113-c18',
#      'media': [{'path': 'spp-media-p1/a5762e07cdaf33cebbf5484a03f5474a/c2a6cd61e42443008cba63d18cf9b2b2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - smoke grey/chlorine blue/high voltage/white',
#      'sizes': ['27.5',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '168 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q15',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-blackuniversity-redwhite-n1243a113-q15',
#      'media': [{'path': 'spp-media-p1/6905ab6547fd34c283ed973896174ad0/1d71d7a2e92844a7a5c0c4eaff0ad9ce.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/university red/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '134 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-K13',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-game-royallight-smoke-greywhite-n1243a113-k13',
#      'media': [{'path': 'spp-media-p1/2ff692da3f74309da883931fb9cd38c0/ac3095ef0c874914907a7b13e408bd15.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - game royal/light smoke grey/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '37,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '135 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-J13',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-sunset-pulseblackwhite-n1243a113-j13',
#      'media': [{'path': 'spp-media-p1/07443f4116d33730830d76bd6a52602f/01dd0ec28eee4cf796e1003a5df9cccc.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - sunset pulse/black/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '36,95\xa0\xa0€',
#       'promotional': '36,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-C17',
#      'url_key': 'nike-performance-revolution-5-unisex-chaussures-de-running-neutres-football-greypurple-pulsefireberrywhite-n1243a113-c17',
#      'media': [{'path': 'spp-media-p1/6bdbd183691a31f6ba04c586aff39551/67d6f4a9eaf64087b6f448b6c08da382.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - football grey/purple pulse/fireberry/white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '34,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'amount': '134 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q13',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-q13',
#      'media': [{'path': 'spp-media-p1/a976bca9cc1f35cc9e60c74371f5585d/966cc41bc77b41a8a7b06823c6cd7fed.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/sunset pulse',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '37,95\xa0\xa0€',
#       'promotional': '34,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'amount': '168 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-J12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-j12',
#      'media': [{'path': 'spp-media-p1/7100cf3ed6f733d0939c3bdc36c09a7e/8ccf85b3a3f44ecb82b3b27f543900bc.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - active fuchsia/metallic silver/black',
#      'sizes': ['32', '33', '34', '35'],
#      'price': {'original': '38,00\xa0\xa0€',
#       'promotional': '38,00\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'Prix Mini',
#        'tracking_value': 'fr_prixmini_old_season_2019_28'}],
#      'amount': '138 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-K12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-n1243a113-k12',
#      'media': [{'path': 'spp-media-p1/798b761ffa983fcd9d17cc5ca5fea966/dad5bbf355404bfc981d3144c1747ba3.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - midnight navy/white/black',
#      'sizes': ['28', '30', '31', '32', '33', '35'],
#      'price': {'original': '37,99\xa0\xa0€',
#       'promotional': '37,99\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '140 g',
#      'delivery_promises': []},
#     {'sku': 'N1243A113-Q12',
#      'url_key': 'nike-performance-revolution-5-chaussures-de-running-neutres-blackanthracite-n1243a113-q12',
#      'media': [{'path': 'spp-media-p1/1d18289e94d53e09a880ceb3dcf596e1/262fa64cc78049e382d6cf78673cd3ec.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'REVOLUTION 5 UNISEX - Chaussures de running neutres - black/anthracite',
#      'sizes': ['27.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '35,95\xa0\xa0€',
#       'promotional': '35,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'amount': '136 g',
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'amount': '171 g',
#    'delivery_promises': []},
#   {'sku': 'AD116D0TD-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/silver metallic',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '41,95\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitesilver-metallic-ad116d0td-a11',
#    'media': [{'path': 'spp-media-p1/f0bebac2d9de3d85a7dc535b0d91a220/adaef1f009a845a48f90d3a5e44f38b6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D0TD-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitesilver-metallic-ad116d0td-a11',
#      'media': [{'path': 'spp-media-p1/e3be3c7d79c5399280c7aefebd5444d8/ffdac8bb1df548c999475b25d7dac289.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - footwear white/silver metallic',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D0TD-Q11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-core-blackgold-metallic-ad116d0td-q11',
#      'media': [{'path': 'spp-media-p1/1c41b064dff73880b0958fd352df31bd/1d325040019642d5979c80bce7300598.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - core black/gold metallic',
#      'sizes': ['36', '36 2/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '59,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D008-A12',
#    'name': 'STAN SMITH - Baskets basses - white/bold pink',
#    'price': {'original': '59,95\xa0\xa0€',
#     'promotional': '41,95\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#    'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD116D008-A12',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a12',
#      'media': [{'path': 'spp-media-p1/945fe01c0bb133579c457cb413cc1753/a81c895455f6470eae4592eb4a8d43cb.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/bold pink',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '59,95\xa0\xa0€',
#       'promotional': '41,95\xa0\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad116d008-a11',
#      'media': [{'path': 'spp-media-p1/6e77790477903cb2943858f41de5a3d8/296366aefff5435791aa0e9809d8d475.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - white/green',
#      'sizes': ['35.5', '36', '38', '36 2/3', '37 1/3', '38 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '45,45\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsabilité',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'AD116D008-A15',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d008-a15',
#      'media': [{'path': 'spp-media-p1/32b1d11842a63545bc860debc9bcbc6d/330d76ea4a9f4040869fe91b37c787f6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH - Baskets basses - running white-bold pink',
#      'sizes': ['36 2/3'],
#      'price': {'original': '64,95\xa0\xa0€',
#       'promotional': '64,94\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TH343D005-Q12',
#    'name': 'SIMPLE DOME UNISEX - T-shirt basique - black',
#    'price': {'original': '19,95\xa0\xa0€',
#     'promotional': '16,95\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#    'url_key': 'the-north-face-simple-dome-t-shirt-imprime-th343d005-q12',
#    'media': [{'path': 'spp-media-p1/7a8bf28e74e9324e80f46b8585ba63bb/4acb8a81d41a421397a9bede731579e4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'The North Face',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TH343D005-Q12',
#      'url_key': 'the-north-face-simple-dome-t-shirt-imprime-th343d005-q12',
#      'media': [{'path': 'spp-media-p1/7a8bf28e74e9324e80f46b8585ba63bb/4acb8a81d41a421397a9bede731579e4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - black',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '16,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-C11',
#      'url_key': 'the-north-face-simple-dome-t-shirt-basique-th343d005-c11',
#      'media': [{'path': 'spp-media-p1/28e59eb103c0384689b4390bf590be89/73feeb01b1e3418b800ad54ee2cdf31c.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - medium grey heather',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-M11',
#      'url_key': 'the-north-face-simple-dome-unisex-t-shirt-basique-green-th343d005-m11',
#      'media': [{'path': 'spp-media-p1/67276a03f20f4abbac3f3f36f1ce9b8d/649116ed90fc44a6824890a0a071300e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - green',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '16,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-N13',
#      'url_key': 'the-north-face-simple-dome-tee-t-shirt-basique-new-taupe-green-th343d005-n13',
#      'media': [{'path': 'spp-media-p1/55d1f02c508732719a85628a2aa2d39c/fc1c7fab3a824610b9f789734369fe9c.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - new taupe green',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'TH343D005-A12',
#      'url_key': 'the-north-face-youth-simple-dome-tee-t-shirt-imprime-whiteblack-th343d005-a12',
#      'media': [{'path': 'spp-media-p1/8a25f31036803bb39d3aa301ba53696f/95778eac7506418bb67bd5b9452a18f1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'SIMPLE DOME UNISEX - T-shirt basique - white/black',
#      'sizes': ['10a/12a', '12a/14a', '16a/18a', '5a/6a', '7a/8a'],
#      'price': {'original': '19,95\xa0\xa0€',
#       'promotional': '19,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE226G002-G12',
#    'name': 'BATWING UNISEX - T-shirt à manches longues - red',
#    'price': {'original': '17,95\xa0\xa0€',
#     'promotional': '16,15\xa0\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#    'url_key': 'levisr-batwing-tee-baby-t-shirt-a-manches-longues-le226g002-g12',
#    'media': [{'path': 'spp-media-p1/2d560118d16f3981ac263df7aded1f64/4bec978d5f294c04bbd0524527aad100.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE226G002-G12',
#      'url_key': 'levisr-batwing-tee-baby-t-shirt-a-manches-longues-le226g002-g12',
#      'media': [{'path': 'spp-media-p1/2d560118d16f3981ac263df7aded1f64/4bec978d5f294c04bbd0524527aad100.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - red',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '16,15\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-K12',
#      'url_key': 'levis-batwing-unisex-t-shirt-a-manches-longues-mottled-blue-le226g002-k12',
#      'media': [{'path': 'spp-media-p1/da6693d930993bfeb388ed13a59cc0f7/320e402801974d5a8337c1921cf8711d.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - mottled blue',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-C11',
#      'url_key': 'levis-batwing-unisex-t-shirt-a-manches-longues-grey-le226g002-c11',
#      'media': [{'path': 'spp-media-p1/fcb13c0a6bba3299b2a418ea0bae2c33/a4baec04906748618ecb9e21db502b6a.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - grey',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,05\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-5%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-K11',
#      'url_key': 'levisr-batwing-baby-t-shirt-a-manches-longues-le226g002-k11',
#      'media': [{'path': 'spp-media-p1/7f9eec0ab3f03e1f8fce21c47cd93d3b/0e6d33a74a724a5c982da7e51510120e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - dress blues',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,95\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'LE226G002-A11',
#      'url_key': 'levisr-batwing-baby-t-shirt-a-manches-longues-le226g002-a11',
#      'media': [{'path': 'spp-media-p1/d066f68744be37a7a968a41d2bc31735/b7302e193cc1473ab3ad0bf16180130e.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING UNISEX - T-shirt à manches longues - white',
#      'sizes': ['3m', '6m', '9m', '12m', '18m', '24m', '1.5a'],
#      'price': {'original': '17,95\xa0\xa0€',
#       'promotional': '17,05\xa0\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-5%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE226G005-A11',
#    'name': 'BATWING TEE - T-shirt imprimé - white',
#    'price': {'original': '19,90\xa0\xa0€',
#     'promotional': '15,92\xa0\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-t-shirt-imprime-white-le226g005-a11',
#    'media': [{'path': 'spp-media-p1/8d33b25d4a1b3a718e588ed512a54bfd/0fd7e0ed52b54c62997ee253694d9547.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE226G005-A11',
#      'url_key': 'levisr-t-shirt-imprime-white-le226g005-a11',
#      'media': [{'path': 'spp-media-p1/8d33b25d4a1b3a718e588ed512a54bfd/0fd7e0ed52b54c62997ee253694d9547.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BATWING TEE - T-shirt imprimé - white',
#      'sizes': ['2a', '3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '19,90\xa0\xa0€',
#       'promotional': '15,92\xa0\xa0€',
# ...
#     {'key': 'YELLOW', 'label': 'jaune', 'metadata': {'hex_code': '#fd3'}},
#     {'key': 'ORANGE', 'label': 'orange', 'metadata': {'hex_code': '#fb863b'}},
#     {'key': 'RED', 'label': 'rouge', 'metadata': {'hex_code': '#ff0002'}},
#     {'key': 'PINK', 'label': 'rose', 'metadata': {'hex_code': '#f563b9'}},
#     {'key': 'PURPLE', 'label': 'violet', 'metadata': {'hex_code': '#9349aa'}},
#     {'key': 'GOLD',
#      'label': 'doré',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/gold.jpg'}},
#     {'key': 'SILVER',
#      'label': 'argenté',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/silver.jpg'}},
#     {'key': 'MULTICOLORED',
#      'label': 'multicolore',
#      'metadata': {'image': 'https://zalando-mosaic-cdn-pnd-test.s3.eu-central-1.amazonaws.com/color-filter/multicolored.jpg'}}]},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 415,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'free_delivery',
#    'label': 'Livraison gratuite',
#    'url_key': 'free_delivery',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison gratuite'}],
#    'description': 'pour toute commande d’un montant supérieur à 24,90€'},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Voir les articles issus de sources éco-responsables ou certifiés par un organisme indépendant.'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '9', 'label': '9 packs'},
#     {'key': '10', 'label': '10 packs'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'casual'},
#     {'key': 'boho_dress', 'label': 'robe bohème'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 16571,
#  'assortment_entry_points': [],
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/',
#      'children': [],
#      'article_count': 10769,
#      'entity_id': 'categ:promo-mode-enfant'},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/',
#      'children': [],
#      'article_count': 2794,
#      'entity_id': 'categ:promo-chaussures-enfant'},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/',
#      'children': [],
#      'article_count': 2792,
#      'entity_id': 'categ:promo-sport-enfant'},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/',
#      'children': [],
#      'article_count': 818,
#      'entity_id': 'categ:promo-accessoires-enfant'},
#     {'label': 'Espace Créateurs',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/',
#      'children': [],
#      'article_count': 1340,
#      'entity_id': 'categ:promo-luxe-enfant'}],
#    'article_count': 16571,
#    'entity_id': 'categ:promo-enfant'}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/'},
#     {'label': 'Promos',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promos',
#       'seo_label': 'Soldes enfant',
#       'reset_url': '/',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/',
#   'reset_url': '/promo-enfant/',
#   'app_url': '?urlKey=promo-enfant&order=popularity&appdomainId=11',
#   'url': '/promo-enfant/',
#   'positive_hidden_filters': []},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promos',
#     'seo_label': 'Soldes enfant',
#     'reset_url': '/',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'blackFridayGradientEnabled': False,
#   'cyberweekGradientEnabled': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-teaser': 12,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'size-dialog': 18,
#   'outfits': [5, 23, 35],
#   'outfits-mobile': [5, 23, 28, 35],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-mobile-teaser': 4},
#  'followBrandsBannerEnabled': True,
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'articleFlagPresetOverrides': {},
#  'teaser': None,
#  'inCatalogTeaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://crow.zalando.de/impressions/1edccda9-ab6a-43d8-a65b-2276cbf44680/6d086803-8650-4992-b212-2793763042be/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2533afe3-a9a9-4bdb-9dab-705d15fb6c97&timeUnit=DAY&timeUnitCount=1&uuid=f79395da-30bf-4718-af23-b3e3458c124c&bid=null&requestId=020b3401-f452-488f-8b37-c4d9eac40f30&adLocation=catalog&frontendType=browser&shopCategoryBreadcrumbs=enfant,promo-enfant&s=BAB3517CE1833FA3C96ADCA220CF024F'],
#    'images': [{'aspect_ratio': '877:1266',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/4bc4cb1f-74a3-4a08-80e8-8955c5fb5469.jpg',
#      'image_width': 877}],
#    'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#    'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#    'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#    'text_fields': {'cta': 'Découvrez maintenant',
#     'sales_template': 'None',
#     'title': 'Carte cadeau Zalando'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'catalog',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'shop_category_breadcrumbs': 'enfant,promo-enfant',
#       'time_unit_count': 1,
#       'shop_slot_id': 'in_catalog',
#       'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#       'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#       'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#       'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#       'flow_id': 'GDj43Dsr7tHuTo0h',
#       'price': 0.018522062074905872,
#       'time_unit': 'DAY',
#       'campaign_source_id': 'undefined',
#       'request_id': '020b3401-f452-488f-8b37-c4d9eac40f30',
#       'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}},
#     'view': {'type': 'teaser view',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'name': 'Carte cadeau Zalando',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_category_breadcrumbs': 'enfant,promo-enfant',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#        'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#        'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'GDj43Dsr7tHuTo0h',
#        'price': 0.018522062074905872,
#        'time_unit': 'DAY',
#        'campaign_source_id': 'undefined',
#        'request_id': '020b3401-f452-488f-8b37-c4d9eac40f30',
#        'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}}},
#     'click': {'type': 'teaser click',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'name': 'Carte cadeau Zalando',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_category_breadcrumbs': 'enfant,promo-enfant',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#        'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#        'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'GDj43Dsr7tHuTo0h',
#        'price': 0.018522062074905872,
#        'time_unit': 'DAY',
#        'campaign_source_id': 'undefined',
#        'request_id': '020b3401-f452-488f-8b37-c4d9eac40f30',
#        'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680'}}}},
#    'view_pixels': ['https://crow.zalando.de/views/1edccda9-ab6a-43d8-a65b-2276cbf44680/6d086803-8650-4992-b212-2793763042be/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2533afe3-a9a9-4bdb-9dab-705d15fb6c97&timeUnit=DAY&timeUnitCount=1&uuid=938e77bf-3db6-49e9-aded-63f5fc499fef&bid=19&requestId=020b3401-f452-488f-8b37-c4d9eac40f30&adLocation=catalog&frontendType=browser&shopCategoryBreadcrumbs=enfant,promo-enfant&s=0BD5ECC50BEA7118EADFAAD48B9A3BE1'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'GDj43Dsr7tHuTo0h',
#      'entity_id': None,
#      'shop_slot_id': 'in_catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#      'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'shop_category_breadcrumbs': 'enfant,promo-enfant',
#      'time_unit_count': 1,
#      'shop_slot_id': 'in_catalog',
#      'creative_id': '2533afe3-a9a9-4bdb-9dab-705d15fb6c97',
#      'campaign_name': 'FR_Incat_Giftcards_Easter_March_2021',
#      'business_unit_id': 'cf54d79c-490a-4655-9559-3a3eca6abb9e',
#      'category_id': 'ab17ddc7-27f6-4306-bb10-bfff5c3c9316',
#      'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#      'flow_id': 'GDj43Dsr7tHuTo0h',
#      'price': 0.018522062074905872,
#      'time_unit': 'DAY',
#      'campaign_source_id': 'undefined',
#      'request_id': '020b3401-f452-488f-8b37-c4d9eac40f30',
#      'campaign_id': '1edccda9-ab6a-43d8-a65b-2276cbf44680',
#      'technical_experiments': '[]'}},
#    'click_url': 'https://www.zalando.fr/cheque-cadeau'},
#   'channel_name': 'CF',
#   'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951'},
#  'upperInCatTeaser': None,
#  'inGridTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
df = pd.json_normalize(zalando2['articles'])

# %%
df.head(5)
# Out:
#              sku                                               name  \
# 0  NI113D0A6-Q11   AIR MAX 90 UNISEX - Baskets basses - black/white
# 1  SA543A079-K11  SPEEDCROSS UNISEX - Chaussures de marche - tur...
# 2  NI114D07I-Q12  AIR MAX 270  - Baskets basses - black/anthraci...
# 3  VA214D00F-Q11     OLD SKOOL  - Baskets basses - black/true white
# 4  JAN24B004-Q11                             Pantalon cargo - black
#
#                                                sizes  \
# 0                     [17, 18.5, 19.5, 21, 22, 23.5]
# 1                   [32, 33, 34, 35, 36, 37, 38, 39]
# 2  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# 3                   [27, 28, 29, 30, 31, 32, 33, 34]
# 4        [8a, 9a, 10a, 11a, 12a, 13a, 14a, 15a, 16a]
#
#                                              url_key  \
# 0  nike-sportswear-nike-air-max-90-ltr-baskets-ba...
# 1  salomon-speedcross-unisex-chaussures-de-marche...
# 2  nike-sportswear-air-max-270-baskets-basses-ni1...
# 3  vans-baskets-basses-black-true-white-va214d00f...
# 4  jackandjones-junior-pantalon-cargo-black-jan24...
#
#                                                media           brand_name  \
# 0  [{'path': 'spp-media-p1/59cf7517d4473bdd8c4014...      Nike Sportswear
# 1  [{'path': 'spp-media-p1/3d72a3ed3fd63fdcb6cc31...              Salomon
# 2  [{'path': 'spp-media-p1/7d0a21c70a343986a8d2d7...      Nike Sportswear
# 3  [{'path': 'spp-media-p1/95d2a499250f3a188daca0...                 Vans
# 4  [{'path': 'spp-media-p1/6272154bdaec3231bf44b9...  Jack & Jones Junior
#
#    is_premium                                    family_articles  \
# 0       False  [{'sku': 'NI113D0A6-Q11', 'url_key': 'nike-spo...
# 1       False  [{'sku': 'SA543A079-K11', 'url_key': 'salomon-...
# 2       False  [{'sku': 'NI114D07I-Q12', 'url_key': 'nike-spo...
# 3       False  [{'sku': 'VA214D00F-Q11', 'url_key': 'vans-bas...
# 4       False  [{'sku': 'JAN24B004-Q11', 'url_key': 'jackandj...
#
#                                                flags product_group  ...  \
# 0  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe  ...
# 1  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe  ...
# 2  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe  ...
# 3  [{'key': 'discountRate', 'value': 'Jusqu’à -18...          shoe  ...
# 4  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing  ...
#
#   price.original price.promotional price.has_different_prices  \
# 0       59,95  €          50,95  €                      False
# 1       74,95  €          63,95  €                      False
# 2       84,95  €          76,45  €                      False
# 3       50,00  €          41,05  €                       True
# 4       49,95  €          34,95  €                      False
#
#    price.has_different_original_prices  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#         tracking_information.metrigo_impression_urls  \
# 0  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                NaN
# 4                                                NaN
#
#               tracking_information.impression_beacon  \
# 0  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                NaN
# 4                                                NaN
#
#   tracking_information.source amount
# 0                         ccp    NaN
# 1                         ccp    NaN
# 2                         ccp    NaN
# 3                         NaN    NaN
# 4                         NaN    NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (84, 21)

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
zalando2['pagination']
# Out:
# {'page_count': 198, 'current_page': 1, 'per_page': 84}

# %%
zalando2['total_count']
# Out:
# 16574

# %%
#we create the urls for all pages
url_list = []
offsets = [(x*84) for x in range(199)][1:]
for page_number in offsets: 
    url_list.append(f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={page_number}')      
url_list
# Out:
# ['https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=168',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=252',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=336',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=420',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=504',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=588',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=672',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=756',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=840',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=924',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1008',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1092',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1176',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1260',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1344',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1428',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1512',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1596',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1680',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1764',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1848',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=1932',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2016',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2100',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2184',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2268',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2352',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2436',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2520',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2604',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2688',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2772',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2856',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=2940',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3024',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3108',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3192',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3276',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3360',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3444',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3528',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3612',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3696',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3780',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3864',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=3948',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4032',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4116',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4200',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4284',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4368',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4452',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4536',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4620',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4704',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4788',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4872',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=4956',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5040',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5124',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5208',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5292',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5376',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5460',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5544',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5628',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5712',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5796',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5880',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=5964',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6048',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6132',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6216',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6300',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6384',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6468',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6552',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6636',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6720',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6804',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6888',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=6972',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7056',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7140',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7224',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7308',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7392',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7476',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7560',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7644',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7728',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7812',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7896',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=7980',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8064',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8148',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8232',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8316',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8400',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8484',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8568',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8652',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8736',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8820',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8904',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=8988',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9072',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9156',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9240',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9324',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9408',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9492',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9576',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9660',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9744',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9828',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9912',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=9996',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10080',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10164',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10248',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10332',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10416',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10500',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10584',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10668',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10752',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10836',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=10920',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11004',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11088',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11172',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11256',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11340',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11424',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11508',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11592',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11676',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11760',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11844',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=11928',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12012',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12096',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12180',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12264',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12348',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12432',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12516',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12600',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12684',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12768',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12852',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=12936',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13020',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13104',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13188',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13272',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13356',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13440',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13524',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13608',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13692',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13776',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13860',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=13944',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14028',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14112',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14196',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14280',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14364',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14448',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14532',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14616',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14700',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14784',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14868',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=14952',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15036',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15120',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15204',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15288',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15372',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15456',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15540',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15624',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15708',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15792',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15876',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=15960',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16044',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16128',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16212',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16296',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16380',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16464',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16548',
#  'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=16632']

# %%
#testing even shorter way to do it
df5 = pd.json_normalize(requests.get(url_new, headers=headers).json()['articles'])

# %%
#we obtain a list of dataframes with every page and concatenate them
appended_data = []
for url in url_list:
    data = pd.json_normalize(requests.get(url, headers=headers).json()['articles'])
    appended_data.append(data)

# %%
df6 = pd.concat(appended_data)

# %%
df6.shape
# Out:
# (16490, 20)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16490 entries, 0 to 25
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   sku                                        16490 non-null  object
#  1   name                                       16490 non-null  object
#  2   sizes                                      16490 non-null  object
#  3   url_key                                    16490 non-null  object
#  4   media                                      16490 non-null  object
#  5   brand_name                                 16490 non-null  object
#  6   is_premium                                 16490 non-null  bool
#  7   family_articles                            16490 non-null  object
#  8   flags                                      16490 non-null  object
#  9   product_group                              16490 non-null  object
#  10  delivery_promises                          16490 non-null  object
#  11  price.original                             16490 non-null  object
#  12  price.promotional                          16490 non-null  object
#  13  price.has_different_prices                 16490 non-null  bool
#  14  price.has_different_original_prices        16490 non-null  bool
#  15  price.has_different_promotional_prices     16490 non-null  bool
#  16  price.has_discount_on_selected_sizes_only  16490 non-null  bool
#  17  amount                                     238 non-null    object
#  18  condition                                  200 non-null    object
#  19  condition_key                              200 non-null    object
# dtypes: bool(5), object(15)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df6['brand_name'].value_counts().nlargest(1)
# Out:
# Name it    1143
# Name: brand_name, dtype: int64

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers.
# your code

# %%
df6['price.original_clean'] = df6['price.original'].apply(lambda x: float((x.split('€')[0]).replace(',', '.')))

# %%
df6['price.original_clean']
# Out:
# 0     19.90
# 1     29.95
# 2     17.95
# 3     47.95
# 4     33.00
#       ...
# 21     9.95
# 22    24.95
# 23    24.95
# 24    14.99
# 25    79.95
# Name: price.original_clean, Length: 16490, dtype: float64

# %%
df6['price.promotional_clean'] = df6['price.promotional'].apply(lambda x: float((x.split('€')[0]).replace(',', '.')))

# %%
df6['discount'] = df6['price.original_clean']-df6['price.promotional_clean']

# %%
df6.groupby('brand_name').sum()['discount'].sort_values(ascending=False).nlargest(1)
# Out:
# brand_name
# Tommy Hilfiger    7048.23
# Name: discount, dtype: float64

# %% [markdown]
# #### Display the brands without discount at all

# %%
#first attempt:
df6.groupby('brand_name').sum()['discount'].sort_values().apply(lambda x: x == 0)
# Out:
# brand_name
# 24Bottles             True
# Ebbe                  True
# Havaianas             True
# Head                  True
# Hurley                True
#                      ...
# Polo Ralph Lauren    False
# O'Neill              False
# Boboli               False
# Name it              False
# Tommy Hilfiger       False
# Name: discount, Length: 387, dtype: bool

# %%
#we use the method Series.items() to iterate through the index and value of this series:
for index, value in (df6.groupby('brand_name').sum()['discount']).items():
    if value == 0:
        print(index)
# Out:
# 24Bottles
# 3 Pommes
# ALDO
# Bergstein
# Billybandit
# Bloch
# D-XEL
# Ebbe
# Havaianas
# Head
# Hurley
# Ipanema
# K-Way
# Kaps
# Laura Biagiotti Roma
# Les Tropéziennes par M Belarbi
# Lil'Boo
# Lili Gaufrette
# Lucy & Sam
# Melania
# Rooskickx
# Sanetta fiftyseven
# Shoesme
# Smitten Organic
# Stella McCartney
# Sunuva
# Teva
# Tobias & The Bear
# Tumble 'n dry
# Unisa
# Veja
# Walnut
# White Stuff
# igi natur

# %%
#same thing in a list comprehension
[index for index, value in (df6.groupby('brand_name').sum()['discount']).items() if value == 0]
# Out:
# ['24Bottles',
#  '3 Pommes',
#  'ALDO',
#  'Bergstein',
#  'Billybandit',
#  'Bloch',
#  'D-XEL',
#  'Ebbe',
#  'Havaianas',
#  'Head',
#  'Hurley',
#  'Ipanema',
#  'K-Way',
#  'Kaps',
#  'Laura Biagiotti Roma',
#  'Les Tropéziennes par M Belarbi',
#  "Lil'Boo",
#  'Lili Gaufrette',
#  'Lucy & Sam',
#  'Melania',
#  'Rooskickx',
#  'Sanetta fiftyseven',
#  'Shoesme',
#  'Smitten Organic',
#  'Stella McCartney',
#  'Sunuva',
#  'Teva',
#  'Tobias & The Bear',
#  "Tumble 'n dry",
#  'Unisa',
#  'Veja',
#  'Walnut',
#  'White Stuff',
#  'igi natur']

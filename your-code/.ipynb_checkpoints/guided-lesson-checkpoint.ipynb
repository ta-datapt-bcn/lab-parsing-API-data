# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url = "https://www.zalando.fr/api/catalog/articles?campaigns=fr_aw19_eoss_wave_1_2019_50&categories=promo-enfant&limit=84&offset=84&sales=SALE&sort=popularity"

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
# headers definition
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"}

# %%
# Your code
response = requests.get(url, headers = headers) 
results = response.json()
results
# Out:
# {'total_count': 20674,
#  'pagination': {'page_count': 247, 'current_page': 2, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'NI114D03O-N11',
#    'name': 'MD RUNNER  - Baskets basses - sequoia/wolf grey/olive/sail',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '22,65\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25'],
#    'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-n11',
#    'media': [{'path': 'NI/11/4D/03/ON/11/NI114D03O-N11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D03O-N11',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-n11',
#      'media': [{'path': 'NI/11/4D/03/ON/11/NI114D03O-N11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - sequoia/wolf grey/olive/sail',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '22,65\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -35%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-K16',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-k16',
#      'media': [{'path': 'NI/11/4D/03/OK/16/NI114D03O-K16@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - gym blue/white/black',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '27,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-C19',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-c19',
#      'media': [{'path': 'NI/11/4D/03/OC/19/NI114D03O-C19@21.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - cool grey/black/white',
#      'sizes': ['17', '18.5', '19.5'],
#      'price': {'original': '35,00\xa0€',
#       'promotional': '35,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-K17',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-k17',
#      'media': [{'path': 'NI/11/4D/03/OK/17/NI114D03O-K17@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - photo blue/bright crimson/obsidian/white',
#      'sizes': ['19.5'],
#      'price': {'original': '30,95\xa0€',
#       'promotional': '30,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-C18',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-c18',
#      'media': [{'path': 'NI/11/4D/03/OC/18/NI114D03O-C18@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - gridiron/teal/pumice/faded spruce',
#      'sizes': ['17', '19.5', '21'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '24,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-Q11',
#      'url_key': 'nike-sportswear-runner-2-baskets-basses-black-white-wolf-grey-ni114d03o-q11',
#      'media': [{'path': 'NI/11/4D/03/OQ/11/NI114D03O-Q11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - black/white/wolf grey',
#      'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI114D03O-C15',
#      'url_key': 'nike-sportswear-md-runner-2-baskets-basses-ni114d03o-c15',
#      'media': [{'path': 'NI/11/4D/03/OC/15/NI114D03O-C15@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MD RUNNER  - Baskets basses - wolf grey/black/white',
#      'sizes': ['17', '18.5', '19.5', '22', '23.5', '25', '26', '27'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PE124L03K-K11',
#    'name': "SURREY - Veste d'hiver - sailor",
#    'price': {'original': '99,95\xa0€',
#     'promotional': '29,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'pepe-jeans-surrey-veste-dhiver-sailor-pe124l03k-k11',
#    'media': [{'path': 'PE/12/4L/03/KK/11/PE124L03K-K11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Pepe Jeans',
#    'is_premium': False,
#    'family_articles': [{'sku': 'PE124L03K-K11',
#      'url_key': 'pepe-jeans-surrey-veste-dhiver-sailor-pe124l03k-k11',
#      'media': [{'path': 'PE/12/4L/03/KK/11/PE124L03K-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': "SURREY - Veste d'hiver - sailor",
#      'sizes': ['4a', '6a', '8a', '10a', '12a', '14a', '16a'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '29,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -70%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NL623B02L-M11',
#    'name': 'CAMO CARGO PANT - Pantalon cargo - green',
#    'price': {'original': '31,95\xa0€',
#     'promotional': '25,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['13a', '14a', '15a'],
#    'url_key': 'new-look-915-generation-camo-cargo-pant-pantalon-cargo-green-nl623b02l-m11',
#    'media': [{'path': 'NL/62/3B/02/LM/11/NL623B02L-M11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Look 915 Generation',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NL623B02L-M11',
#      'url_key': 'new-look-915-generation-camo-cargo-pant-pantalon-cargo-green-nl623b02l-m11',
#      'media': [{'path': 'NL/62/3B/02/LM/11/NL623B02L-M11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'CAMO CARGO PANT - Pantalon cargo - green',
#      'sizes': ['13a', '14a', '15a'],
#      'price': {'original': '31,95\xa0€',
#       'promotional': '25,59\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ZAF26J004-K11',
#    'name': 'Gilet - peacoat',
#    'price': {'original': '17,99\xa0€',
#     'promotional': '10,79\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['110/116', '122/128', '134/140', '146/152', '158/164', '98/104'],
#    'url_key': 'zalando-essentials-kids-gilet-peacoat-zaf26j004-k11',
#    'media': [{'path': 'ZA/F2/6J/00/4K/11/ZAF26J004-K11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Zalando Essentials Kids',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ZAF26J004-K11',
#      'url_key': 'zalando-essentials-kids-gilet-peacoat-zaf26j004-k11',
#      'media': [{'path': 'ZA/F2/6J/00/4K/11/ZAF26J004-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Gilet - peacoat',
#      'sizes': ['110/116',
#       '122/128',
#       '134/140',
#       '146/152',
#       '158/164',
#       '98/104'],
#      'price': {'original': '17,99\xa0€',
#       'promotional': '10,79\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'ZAF26J004-J11',
#      'url_key': 'zalando-essentials-kids-gilet-pink-zaf26j004-j11',
#      'media': [{'path': 'ZA/F2/6J/00/4J/11/ZAF26J004-J11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Gilet - pink',
#      'sizes': ['110/116',
#       '122/128',
#       '134/140',
#       '146/152',
#       '158/164',
#       '98/104'],
#      'price': {'original': '17,99\xa0€',
#       'promotional': '9,89\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-45%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'ZAF26J004-C11',
#      'url_key': 'zalando-essentials-kids-gilet-light-grey-zaf26j004-c11',
#      'media': [{'path': 'ZA/F2/6J/00/4C/11/ZAF26J004-C11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Gilet - light grey',
#      'sizes': ['110/116',
#       '122/128',
#       '134/140',
#       '146/152',
#       '158/164',
#       '98/104'],
#      'price': {'original': '17,99\xa0€',
#       'promotional': '9,89\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-45%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'ZAF26J004-A11',
#      'url_key': 'zalando-essentials-kids-gilet-winter-white-zaf26j004-a11',
#      'media': [{'path': 'ZA/F2/6J/00/4A/11/ZAF26J004-A11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Gilet - winter white',
#      'sizes': ['110/116',
#       '122/128',
#       '134/140',
#       '146/152',
#       '158/164',
#       '98/104'],
#      'price': {'original': '17,99\xa0€',
#       'promotional': '11,69\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-35%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI126D00H-Q11',
#    'name': 'COVERALL BABY - Combinaison - black',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '16,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3a', '9a'],
#    'url_key': 'nike-sportswear-coverall-baby-combinaison-black-ni126d00h-q11',
#    'media': [{'path': 'NI/12/6D/00/HQ/11/NI126D00H-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI126D00H-Q11',
#      'url_key': 'nike-sportswear-coverall-baby-combinaison-black-ni126d00h-q11',
#      'media': [{'path': 'NI/12/6D/00/HQ/11/NI126D00H-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'COVERALL BABY - Combinaison - black',
#      'sizes': ['3a', '9a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '16,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ZAF24G00J-C11',
#    'name': '4 PACK - T-shirt à manches longues - light grey melange/red',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '13,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['122/128', '134/140', '146/152'],
#    'url_key': 'zalando-essentials-kids-4-pack-t-shirt-a-manches-longues-light-grey-melangered-zaf24g00j-c11',
#    'media': [{'path': 'ZA/F2/4G/00/JC/11/ZAF24G00J-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Zalando Essentials Kids',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ZAF24G00J-C11',
#      'url_key': 'zalando-essentials-kids-4-pack-t-shirt-a-manches-longues-light-grey-melangered-zaf24g00j-c11',
#      'media': [{'path': 'ZA/F2/4G/00/JC/11/ZAF24G00J-C11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': '4 PACK - T-shirt à manches longues - light grey melange/red',
#      'sizes': ['122/128', '134/140', '146/152'],
#      'price': {'original': '29,99\xa0€',
#       'promotional': '13,49\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-55%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LM523K007-C11',
#    'name': 'Sweatshirt - grau/rosa',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '8a', '10a', '12a'],
#    'url_key': 'little-marc-jacobs-sweatshirt-graurosa-lm523k007-c11',
#    'media': [{'path': 'LM/52/3K/00/7C/11/LM523K007-C11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Little Marc Jacobs',
#    'is_premium': True,
#    'family_articles': [{'sku': 'LM523K007-C11',
#      'url_key': 'little-marc-jacobs-sweatshirt-graurosa-lm523k007-c11',
#      'media': [{'path': 'LM/52/3K/00/7C/11/LM523K007-C11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Sweatshirt - grau/rosa',
#      'sizes': ['4a', '8a', '10a', '12a'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '26,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': '1FI26K000-Q11',
#    'name': 'CLASSIC LOGO HOODY - Sweat à capuche - black',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '27,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a', '5-6a', '7-8a'],
#    'url_key': 'fila-classic-logo-hoody-sweatshirt-1fi26k000-q11',
#    'media': [{'path': '1F/I2/6K/00/0Q/11/1FI26K000-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [{'sku': '1FI26K000-Q11',
#      'url_key': 'fila-classic-logo-hoody-sweatshirt-1fi26k000-q11',
#      'media': [{'path': '1F/I2/6K/00/0Q/11/1FI26K000-Q11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'CLASSIC LOGO HOODY - Sweat à capuche - black',
#      'sizes': ['3-4a', '5-6a', '7-8a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '27,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': '1FI26K000-C11',
#      'url_key': 'fila-classic-logo-hoody-sweatshirt-1fi26k000-c11',
#      'media': [{'path': '1F/I2/6K/00/0C/11/1FI26K000-C11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'CLASSIC LOGO HOODY - Sweat à capuche - light grey melange',
#      'sizes': ['3-4a', '5-6a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '27,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': '1FI26K000-I11',
#      'url_key': 'fila-classic-logo-hoody-sweatshirt-1fi26k000-i11',
#      'media': [{'path': '1F/I2/6K/00/0I/11/1FI26K000-I11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'CLASSIC LOGO HOODY - Sweat à capuche - tillandsia purple',
#      'sizes': ['3-4a', '5-6a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '38,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'F5724L00J-O11',
#    'name': "Veste d'hiver - trush",
#    'price': {'original': '48,95\xa0€',
#     'promotional': '14,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['9-10a', '11-12a', '13-14a'],
#    'url_key': 'friboo-parka-trush-f5724l00j-o11',
#    'media': [{'path': 'F5/72/4L/00/JO/11/F5724L00J-O11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Friboo',
#    'is_premium': False,
#    'family_articles': [{'sku': 'F5724L00J-O11',
#      'url_key': 'friboo-parka-trush-f5724l00j-o11',
#      'media': [{'path': 'F5/72/4L/00/JO/11/F5724L00J-O11@15.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': "Veste d'hiver - trush",
#      'sizes': ['9-10a', '11-12a', '13-14a'],
#      'price': {'original': '48,95\xa0€',
#       'promotional': '14,65\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'},
#       {'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []},
#     {'sku': 'F5724L00J-K11',
#      'url_key': 'friboo-parka-poseidon-f5724l00j-k11',
#      'media': [{'path': 'F5/72/4L/00/JK/11/F5724L00J-K11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': "Veste d'hiver - poseidon",
#      'sizes': ['9-10a', '11-12a', '13-14a'],
#      'price': {'original': '48,95\xa0€',
#       'promotional': '14,65\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'},
#       {'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI124D00Q-C11',
#    'name': 'FUTURA NOVELTY COVERALL BABY - Grenouillère - black heather',
#    'price': {'original': '31,95\xa0€',
#     'promotional': '17,55\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-3a', '3a', '6a', '9a'],
#    'url_key': 'nike-sportswear-futura-novelty-coverall-baby-combinaison-ni124d00q-c11',
#    'media': [{'path': 'NI/12/4D/00/QC/11/NI124D00Q-C11@7.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI124D00Q-C11',
#      'url_key': 'nike-sportswear-futura-novelty-coverall-baby-combinaison-ni124d00q-c11',
#      'media': [{'path': 'NI/12/4D/00/QC/11/NI124D00Q-C11@7.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'FUTURA NOVELTY COVERALL BABY - Grenouillère - black heather',
#      'sizes': ['0-3a', '3a', '6a', '9a'],
#      'price': {'original': '31,95\xa0€',
#       'promotional': '17,55\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-45%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI124D00Q-J11',
#      'url_key': 'nike-sportswear-futura-novelty-coverall-baby-combinaison-echo-pink-heather-ni124d00q-j11',
#      'media': [{'path': 'NI/12/4D/00/QJ/11/NI124D00Q-J11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'FUTURA NOVELTY COVERALL BABY - Grenouillère - echo pink heather',
#      'sizes': ['3a'],
#      'price': {'original': '30,95\xa0€',
#       'promotional': '24,75\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1243E0LT-Q11',
#    'name': 'DRY PANT  - Pantalon de survêtement - black/wolf grey/anthracite',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '27,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8-10a', '10-12a', '12-13a'],
#    'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-blackwolf-greyanthracite-n1243e0lt-q11',
#    'media': [{'path': 'N1/24/3E/0L/TQ/11/N1243E0LT-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243E0LT-Q11',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-blackwolf-greyanthracite-n1243e0lt-q11',
#      'media': [{'path': 'N1/24/3E/0L/TQ/11/N1243E0LT-Q11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY PANT  - Pantalon de survêtement - black/wolf grey/anthracite',
#      'sizes': ['8-10a', '10-12a', '12-13a'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '27,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -45%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1243E0LT-K11',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0lt-k11',
#      'media': [{'path': 'N1/24/3E/0L/TK/11/N1243E0LT-K11@9.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY PANT  - Pantalon de survêtement - coastal blue/photo blue',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '29,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -40%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1243E0LT-M11',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0lt-m11',
#      'media': [{'path': 'N1/24/3E/0L/TM/11/N1243E0LT-M11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY PANT  - Pantalon de survêtement - bicoastal/faded spruce/iridescent',
#      'sizes': ['13-15a'],
#      'price': {'original': '49,95\xa0€',
#       'promotional': '19,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0B5-B11',
#    'name': 'COURT BOROUGH MID  - Baskets montantes - wheat/medium brown',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '24,65\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-ni114d0b5-b11',
#    'media': [{'path': 'NI/11/4D/0B/5B/11/NI114D0B5-B11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D0B5-B11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-ni114d0b5-b11',
#      'media': [{'path': 'NI/11/4D/0B/5B/11/NI114D0B5-B11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID  - Baskets montantes - wheat/medium brown',
#      'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '24,65\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -55%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B5-E11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-club-goldblue-herokumquatblack-ni114d0b5-e11',
#      'media': [{'path': 'NI/11/4D/0B/5E/11/NI114D0B5-E11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID  - Baskets montantes - club gold/blue hero/kumquat/black',
#      'sizes': ['37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B5-Q11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-ni114d0b5-q11',
#      'media': [{'path': 'NI/11/4D/0B/5Q/11/NI114D0B5-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID  - Baskets montantes - black',
#      'sizes': ['36', '38', '38.5', '39', '40'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI114D0B5-O11',
#      'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-ni114d0b5-o11',
#      'media': [{'path': 'NI/11/4D/0B/5O/11/NI114D0B5-O11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH MID  - Baskets montantes - baroque brown/black/medium brown',
#      'sizes': ['35.5', '36.5', '37.5', '38', '38.5', '39', '40'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '23,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ZAF24D000-C11',
#    'name': 'Sweatshirt - light grey',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '8,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['122/128', '134/140'],
#    'url_key': 'zalando-essentials-kids-pantalon-de-survetement-light-grey-zaf24d000-c11',
#    'media': [{'path': 'ZA/F2/4D/00/0C/11/ZAF24D000-C11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Zalando Essentials Kids',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ZAF24D000-C11',
#      'url_key': 'zalando-essentials-kids-pantalon-de-survetement-light-grey-zaf24d000-c11',
#      'media': [{'path': 'ZA/F2/4D/00/0C/11/ZAF24D000-C11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Sweatshirt - light grey',
#      'sizes': ['122/128', '134/140'],
#      'price': {'original': '24,99\xa0€',
#       'promotional': '8,69\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-65%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CHT23F01N-A11',
#    'name': 'AUDRA DRESS - Robe de soirée - cream',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '21,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['9a', '10a', '11a', '14a'],
#    'url_key': 'chi-chi-girls-audra-dress-robe-de-soiree-cream-cht23f01n-a11',
#    'media': [{'path': 'CH/T2/3F/01/NA/11/CHT23F01N-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Chi Chi Girls',
#    'is_premium': False,
#    'family_articles': [{'sku': 'CHT23F01N-A11',
#      'url_key': 'chi-chi-girls-audra-dress-robe-de-soiree-cream-cht23f01n-a11',
#      'media': [{'path': 'CH/T2/3F/01/NA/11/CHT23F01N-A11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'AUDRA DRESS - Robe de soirée - cream',
#      'sizes': ['9a', '10a', '11a', '14a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '21,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO113I00G-K11',
#    'name': 'Bottines - blue',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '47,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '32', '33', '34', '35'],
#    'url_key': 'tommy-hilfiger-bottines-blue-to113i00g-k11',
#    'media': [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TO113I00G-K11',
#      'url_key': 'tommy-hilfiger-bottines-blue-to113i00g-k11',
#      'media': [{'path': 'TO/11/3I/00/GK/11/TO113I00G-K11@8.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Bottines - blue',
#      'sizes': ['28', '29', '30', '32', '33', '34', '35'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '47,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1243E0JA-Q12',
#    'name': 'DRY ACADEMY PANT - Pantalon de survêtement - black',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#    'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-q12',
#    'media': [{'path': 'N1/24/3E/0J/AQ/12/N1243E0JA-Q12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1243E0JA-Q12',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-q12',
#      'media': [{'path': 'N1/24/3E/0J/AQ/12/N1243E0JA-Q12@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - black',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '27,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1243E0JA-K11',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-k11',
#      'media': [{'path': 'N1/24/3E/0J/AK/11/N1243E0JA-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - obsidian/white',
#      'sizes': ['8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '26,15\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-25%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1243E0JA-K14',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-k14',
#      'media': [{'path': 'N1/24/3E/0J/AK/14/N1243E0JA-K14@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - valerian blue/laser crimson',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1243E0JA-Q11',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-q11',
#      'media': [{'path': 'N1/24/3E/0J/AQ/11/N1243E0JA-Q11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - black/white',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1243E0JA-K13',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-k13',
#      'media': [{'path': 'N1/24/3E/0J/AK/13/N1243E0JA-K13@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - burgundy ash/racer pink',
#      'sizes': ['6-8a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '24,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1243E0JA-K12',
#      'url_key': 'nike-performance-dry-pant-pantalon-de-survetement-n1243e0ja-k12',
#      'media': [{'path': 'N1/24/3E/0J/AK/12/N1243E0JA-K12@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'DRY ACADEMY PANT - Pantalon de survêtement - coastal blue/light photo blue',
#      'sizes': ['6-8a', '8-10a', '10-12a', '12-13a', '13-15a'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '24,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-20% EXTRA',
#        'tracking_value': 'fr_aw19_eoss_wave_1_2019_50'},
#       {'key': 'discountRate',
#        'value': 'Jusqu’à -30%',
# ...
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '8', 'label': '8 packs'},
#     {'key': '9', 'label': '9 packs'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_eoss_wave_1_2019_50',
#      'label': '-20% EXTRA',
#      'applied': True},
#     {'key': 'kids_comics_cartoons', 'label': 'BD et dessins animés'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 20678,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#      'children': [],
#      'article_count': 13908},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#      'children': [],
#      'article_count': 4674},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#      'children': [],
#      'article_count': 3248},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#      'children': [],
#      'article_count': 1000},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#      'children': [],
#      'article_count': 1937}],
#    'article_count': 20695}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true'},
#     {'label': 'Soldes',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Soldes',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#       'id': '9574'}]},
#    {'key': 'sales',
#     'url_key': 'sale',
#     'kind': 'single_value',
#     'values': [{'key': 'SALE',
#       'url_key': 'true',
#       'label': 'Voir les Promos',
#       'seo_label': 'Voir les Promos',
#       'reset_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50'}]},
#    {'key': 'campaigns',
#     'url_key': 'camp',
#     'kind': 'values',
#     'values': [{'key': 'fr_aw19_eoss_wave_1_2019_50',
#       'url_key': 'fr_aw19_eoss_wave_1_2019_50',
#       'label': '-20% EXTRA',
#       'seo_label': '',
#       'reset_url': '/promo-enfant/?sale=true'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#   'reset_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#   'app_url': '?urlKey=promo-enfant&sale=SALE&camp=fr_aw19_eoss_wave_1_2019_50&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Soldes',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/?camp=fr_aw19_eoss_wave_1_2019_50&sale=true',
#     'id': '9574'}],
#   'sales': [{'key': 'SALE',
#     'url_key': 'true',
#     'label': 'Voir les Promos',
#     'seo_label': 'Voir les Promos',
#     'reset_url': '/promo-enfant/?camp=fr_aw19_eoss_wave_1_2019_50'}],
#   'campaigns': [{'key': 'fr_aw19_eoss_wave_1_2019_50',
#     'url_key': 'fr_aw19_eoss_wave_1_2019_50',
#     'label': '-20% EXTRA',
#     'seo_label': '',
#     'reset_url': '/promo-enfant/?sale=true'}]},
#  'selectedFilters': {'categories': ['promo-enfant'],
#   'sales': ['SALE'],
#   'campaigns': ['fr_aw19_eoss_wave_1_2019_50']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/f6735fcf-6eba-4a23-b346-48da754f7718/b6fc936f-ed1f-4d6c-8ef4-a0a597f54aa2/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=ca895d76-f8aa-4caa-b30a-6723841acc96&timeUnit=null&timeUnitCount=null&uuid=59030ead-35f6-4b6b-9a10-76e6a73aa94c&bid=null&requestId=c9b6cff2-1c12-4591-b74f-9658b5fbd50e&s=933B98EF58D7ED206A3A6FDB07A5A443'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/12fe3361ca6a491fbbe0a16d1da5b12a/eda03967f70940918904b26f33ca3f5a.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/702/599/750/spp-media-p1/274cebbd83654b0e951944f92b036c2a/af633d34af294e6bb7859134a9e767ce.jpeg',
#      'image_width': None}],
#    'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96',
#    'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#    'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#    'campaign_source_id': 'ckdnQ5SzQO-',
#    'text_fields': {'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 04/02/2020 à 23h59 sur les articles soldés et les prix minis, dès 80€ d'achat. ",
#     'voucher_code': '20CROYABLE',
#     'title': "JUSQU'À -70% ET -20% EXTRA*\t",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': "Tic tac, c'est la fin des soldes ⏰\t",
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'EHWOnk03DKMwXK1u',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'ckdnQ5SzQO-',
#       'request_id': 'c9b6cff2-1c12-4591-b74f-9658b5fbd50e',
#       'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#       'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'ckdnQ5SzQO-',
#      'name': "JUSQU'À -70% ET -20% EXTRA*\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '_m-vRawnSl6',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'EHWOnk03DKMwXK1u',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'ckdnQ5SzQO-',
#        'request_id': 'c9b6cff2-1c12-4591-b74f-9658b5fbd50e',
#        'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#        'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96'},
#       'dimension74': {'adId': '_m-vRawnSl6'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'ckdnQ5SzQO-',
#      'name': "JUSQU'À -70% ET -20% EXTRA*\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '_m-vRawnSl6',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'EHWOnk03DKMwXK1u',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'ckdnQ5SzQO-',
#        'request_id': 'c9b6cff2-1c12-4591-b74f-9658b5fbd50e',
#        'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#        'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96'},
#       'dimension74': {'adId': '_m-vRawnSl6'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/f6735fcf-6eba-4a23-b346-48da754f7718/b6fc936f-ed1f-4d6c-8ef4-a0a597f54aa2/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=ca895d76-f8aa-4caa-b30a-6723841acc96&timeUnit=null&timeUnitCount=null&uuid=0525b7f7-8c18-4915-8c21-e0b1e5922f1f&bid=null&requestId=c9b6cff2-1c12-4591-b74f-9658b5fbd50e&s=720B390BE746AB6ACC87DD0894CC8DDF'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'EHWOnk03DKMwXK1u',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'ckdnQ5SzQO-',
#      'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#      'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96',
#      'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CAMS_CAMS_-_CW49_AW19_MSC_EOSS_SalesBanner_Unisex_Generic_Wave4_ckdnQ5SzQO-_FR_C_000000',
#      'brand_code': '-1',
#      'adId': '_m-vRawnSl6',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'EHWOnk03DKMwXK1u',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'ckdnQ5SzQO-',
#      'request_id': 'c9b6cff2-1c12-4591-b74f-9658b5fbd50e',
#      'campaign_id': 'f6735fcf-6eba-4a23-b346-48da754f7718',
#      'creative_id': 'ca895d76-f8aa-4caa-b30a-6723841acc96'}}},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)
flattened_data
flattened_data["articles"]
flattened_data.articles[0]
articles = json_normalize(flattened_data.articles[0])   
articles.head(84)
# Out:
#               sku                                               name  \
# 0   NI114D03O-N11  MD RUNNER  - Baskets basses - sequoia/wolf gre...
# 1   PE124L03K-K11                    SURREY - Veste d'hiver - sailor
# 2   NL623B02L-M11           CAMO CARGO PANT - Pantalon cargo - green
# 3   ZAF26J004-K11                                    Gilet - peacoat
# 4   NI126D00H-Q11                COVERALL BABY - Combinaison - black
# ..            ...                                                ...
# 79  LA224L00G-G11       BLOUSON - Veste d'hiver - bordeaux/navy blue
# 80  SO223C06H-K11                               Short en jean - blue
# 81  NL623J018-G11                                Pullover - bordeaux
# 82  DE123G065-K11       STOCKPORT - T-shirt à manches longues - navy
# 83  AD126D02L-Q11              FLAMESTRK - Survêtement - black/white
#
#                                                 sizes  \
# 0                  [17, 18.5, 19.5, 21, 22, 23.5, 25]
# 1                    [4a, 6a, 8a, 10a, 12a, 14a, 16a]
# 2                                     [13a, 14a, 15a]
# 3   [110/116, 122/128, 134/140, 146/152, 158/164, ...
# 4                                            [3a, 9a]
# ..                                                ...
# 79               [4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# 80  [11axREG, 12axREG, 13axREG, 14axREG, 15axREG, ...
# 81                       [9a, 10-11a, 12-13a, 14-15a]
# 82                                     [8a, 10a, 12a]
# 83                          [0-3m, 3-6m, 6-9m, 9-12m]
#
#                                               url_key  \
# 0   nike-sportswear-md-runner-2-baskets-basses-ni1...
# 1   pepe-jeans-surrey-veste-dhiver-sailor-pe124l03...
# 2   new-look-915-generation-camo-cargo-pant-pantal...
# 3   zalando-essentials-kids-gilet-peacoat-zaf26j00...
# 4   nike-sportswear-coverall-baby-combinaison-blac...
# ..                                                ...
# 79         lacoste-blouson-veste-dhiver-la224l00g-g11
# 80           soliver-short-en-jean-blue-so223c06h-k11
# 81  new-look-915-generation-pullover-bordeaux-nl62...
# 82  desigual-stockport-t-shirt-a-manches-longues-n...
# 83  adidas-originals-flamestrk-pantalon-classique-...
#
#                                                 media  \
# 0   [{'path': 'NI/11/4D/03/ON/11/NI114D03O-N11@9.j...
# 1   [{'path': 'PE/12/4L/03/KK/11/PE124L03K-K11@2.j...
# 2   [{'path': 'NL/62/3B/02/LM/11/NL623B02L-M11@5.j...
# 3   [{'path': 'ZA/F2/6J/00/4K/11/ZAF26J004-K11@2.j...
# 4   [{'path': 'NI/12/6D/00/HQ/11/NI126D00H-Q11@9.j...
# ..                                                ...
# 79  [{'path': 'LA/22/4L/00/GG/11/LA224L00G-G11@7.j...
# 80  [{'path': 'SO/22/3C/06/HK/11/SO223C06H-K11@7.1...
# 81  [{'path': 'NL/62/3J/01/8G/11/NL623J018-G11@7.j...
# 82  [{'path': 'DE/12/3G/06/5K/11/DE123G065-K11@6.j...
# 83  [{'path': 'AD/12/6D/02/LQ/11/AD126D02L-Q11@10....
#
#                  brand_name  is_premium  \
# 0           Nike Sportswear       False
# 1                Pepe Jeans       False
# 2   New Look 915 Generation       False
# 3   Zalando Essentials Kids       False
# 4           Nike Sportswear       False
# ..                      ...         ...
# 79                  Lacoste       False
# 80                 s.Oliver       False
# 81  New Look 915 Generation       False
# 82                 Desigual       False
# 83         adidas Originals       False
#
#                                       family_articles  \
# 0   [{'sku': 'NI114D03O-N11', 'url_key': 'nike-spo...
# 1   [{'sku': 'PE124L03K-K11', 'url_key': 'pepe-jea...
# 2   [{'sku': 'NL623B02L-M11', 'url_key': 'new-look...
# 3   [{'sku': 'ZAF26J004-K11', 'url_key': 'zalando-...
# 4   [{'sku': 'NI126D00H-Q11', 'url_key': 'nike-spo...
# ..                                                ...
# 79  [{'sku': 'LA224L00G-G11', 'url_key': 'lacoste-...
# 80  [{'sku': 'SO223C06H-K11', 'url_key': 'soliver-...
# 81  [{'sku': 'NL623J018-G11', 'url_key': 'new-look...
# 82  [{'sku': 'DE123G065-K11', 'url_key': 'desigual...
# 83  [{'sku': 'AD126D02L-Q11', 'url_key': 'adidas-o...
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 82  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 83  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        34,95 €           22,65 €
# 1                 []        99,95 €           29,95 €
# 2                 []        31,95 €           25,59 €
# 3                 []        17,99 €           10,79 €
# 4                 []        54,95 €           16,45 €
# ..               ...            ...               ...
# 79                []       138,00 €           82,00 €
# 80                []        25,99 €           11,69 €
# 81                []        16,95 €           12,69 €
# 82                []        36,95 €           16,55 €
# 83                []        49,95 €           24,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                         True                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                    True
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False    NaN
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False    NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
Index(['amount', 'brand_name', 'delivery_promises', 'family_articles', 'flags',
       'is_premium', 'media', 'name', 'price.has_different_original_prices',
       'price.has_different_prices', 'price.has_different_promotional_prices',
       'price.has_discount_on_selected_sizes_only', 'price.original',
       'price.promotional', 'product_group', 'sizes', 'url_key'],
      dtype='object')

# %%
# Get the total number of pages


# Your code

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
# your code

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers.
# your code

# %% [markdown]
# #### Display the brands without discount at all

# %%
# your code

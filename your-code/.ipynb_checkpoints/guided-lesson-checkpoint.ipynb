# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
# headers definition
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) Chrome/71.0.3578.98 Safari/537.36"}
response = requests.get(url, headers = headers)
results = response.json()
flattened_data = json_normalize(results)

# %%
flattened_data.head()
# Out:
#                                             articles  articlesToShow  \
# 0  [{'sku': 'JAN24G00M-A11', 'name': 'JORHOTEL TE...              84
#
#                                          breadcrumbs carouselTeaser  \
# 0  [{'items': [{'label': 'Enfant', 'url_key': 'en...           None
#
#                                         categoryTree collection  \
# 0  [{'label': 'Promotions', 'id': '9574', 'url_ke...       None
#
#   contentPositions.entry-point-teasers  contentPositions.in-cat-carousel  \
# 0                      [7, 14, 20, 26]                                 9
#
#    contentPositions.in-cat-carousel-fullwidth  \
# 0                                           8
#
#    contentPositions.in-cat-carousel-mobile  ...  total_article_count  \
# 0                                        6  ...                20234
#
#    total_count upperInCatTeaser variants.fullWidthCatalog  \
# 0        20232             None                     False
#
#   variants.hideCategories variants.mobileLightFilters variants.myBrandsFilter  \
# 0                   False                       False                    True
#
#   variants.outwardTeaserCard  variants.premiumCatalog wishlist
# 0                      False                    False     None
#
# [1 rows x 149 columns]

# %%
articles = json_normalize(flattened_data.articles[0])
articles.columns
# Out:
# Index(['amount', 'brand_name', 'family_articles', 'flags', 'is_premium',
#        'media', 'name', 'price.has_different_original_prices',
#        'price.has_different_prices', 'price.has_different_promotional_prices',
#        'price.has_discount_on_selected_sizes_only', 'price.original',
#        'price.promotional', 'product_group', 'sizes', 'sku', 'url_key'],
#       dtype='object')

# %%
articles.head()
# Out:
#   amount           brand_name  \
# 0    NaN  Jack & Jones Junior
# 1    NaN              Name it
# 2    NaN           Quiksilver
# 3    NaN             Benetton
# 4    NaN             s.Oliver
#
#                                      family_articles  \
# 0  [{'sku': 'JAN24G00M-A11', 'url_key': 'jackandj...
# 1  [{'sku': 'NA823F0VH-K11', 'url_key': 'name-it-...
# 2  [{'sku': 'QU124L01V-K11', 'url_key': 'quiksilv...
# 3  [{'sku': '4BE23F082-A11', 'url_key': 'benetton...
# 4  [{'sku': 'SO224G0LB-K11', 'url_key': 'soliver-...
#
#                                                flags  is_premium  \
# 0  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 2  [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# 3  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 4  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                media  \
# 0  [{'path': 'JA/N2/4G/00/MA/11/JAN24G00M-A11@5.j...
# 1  [{'path': 'NA/82/3F/0V/HK/11/NA823F0VH-K11@2.j...
# 2  [{'path': 'QU/12/4L/01/VK/11/QU124L01V-K11@11....
# 3  [{'path': '4B/E2/3F/08/2A/11/4BE23F082-A11@2.j...
# 4  [{'path': 'SO/22/4G/0L/BK/11/SO224G0LB-K11@2.j...
#
#                                                 name  \
# 0  JORHOTEL TEE CREW NECK JUNIOR - T-shirt imprim...
# 1    DRESS CAMPMINI - Robe en jersey - dark sapphire
# 2                               Veste d'hiver - navy
# 3               DRESS - Robe en jersey - white/black
# 4     REGULAR FIT - T-shirt à manches longues - blue
#
#    price.has_different_original_prices  price.has_different_prices  \
# 0                                False                       False
# 1                                False                       False
# 2                                False                       False
# 3                                False                       False
# 4                                False                       False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only price.original price.promotional  \
# 0                                      False        12,95 €            3,90 €
# 1                                      False        12,95 €            3,89 €
# 2                                      False        75,99 €           38,00 €
# 3                                      False        19,95 €            6,00 €
# 4                                      False        11,99 €            5,40 €
#
#   product_group                                          sizes            sku  \
# 0      clothing                       [8a, 10a, 12a, 14a, 16a]  JAN24G00M-A11
# 1      clothing  [5a, 6a, 7a, 8a, 9a, 10a, 11a, 12a, 13a, 14a]  NA823F0VH-K11
# 2      clothing                            [8a, 10a, 12a, 14a]  QU124L01V-K11
# 3      clothing     [6-7a, 7-8a, 8-9a, 10-11a, 11-12a, 13-14a]  4BE23F082-A11
# 4      clothing              [11-12axREG, 7-8axREG, 9-10axREG]  SO224G0LB-K11
#
#                                              url_key
# 0  jackandjones-junior-jorhotel-tee-crew-neck-jun...
# 1  name-it-dress-campmini-robe-en-jersey-dark-sap...
# 2         quiksilver-veste-dhiver-navy-qu124l01v-k11
# 3  benetton-dress-robe-en-jersey-whiteblack-4be23...
# 4  soliver-regular-fit-t-shirt-a-manches-longues-...

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages

total_pages = results["pagination"]["page_count"]
total_pages

# Your code

df = pd.DataFrame(columns = articles.columns)

df

# Your code
for i in range(total_pages):
    art_per_page = i*84
    url_loop = 'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset='+str(art_per_page)+'&sort=sale'
    response_loop = requests.get(url_loop, headers = headers)
    results_loop = response_loop.json()
    flattened_data_loop = json_normalize(results_loop)
    articles_loop = json_normalize(flattened_data_loop.articles[0])
    df = df.append(articles_loop)

df = df.set_index('sku')

df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#               amount        brand_name  \
# sku
# NI114D0A8-K11    NaN   Nike Sportswear
# N1243E0J0-Q11    NaN  Nike Performance
# N1243A0XZ-C11   82 g  Nike Performance
# N1243G01D-N11    NaN  Nike Performance
# NI114D0A1-C12    NaN   Nike Sportswear
#
#                                                  family_articles  \
# sku
# NI114D0A8-K11  [{'sku': 'NI114D0A8-K11', 'url_key': 'nike-spo...
# N1243E0J0-Q11  [{'sku': 'N1243E0J0-Q11', 'url_key': 'nike-per...
# N1243A0XZ-C11  [{'sku': 'N1243A0XZ-C11', 'url_key': 'nike-per...
# N1243G01D-N11  [{'sku': 'N1243G01D-N11', 'url_key': 'nike-per...
# NI114D0A1-C12  [{'sku': 'NI114D0A1-C12', 'url_key': 'nike-spo...
#
#                                                            flags is_premium  \
# sku
# NI114D0A8-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243E0J0-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243A0XZ-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243G01D-N11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# NI114D0A1-C12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
#
#                                                            media  \
# sku
# NI114D0A8-K11  [{'path': 'NI/11/4D/0A/8K/11/NI114D0A8-K11@7.j...
# N1243E0J0-Q11  [{'path': 'N1/24/3E/0J/0Q/11/N1243E0J0-Q11@4.j...
# N1243A0XZ-C11  [{'path': 'N1/24/3A/0X/ZC/11/N1243A0XZ-C11@9.j...
# N1243G01D-N11  [{'path': 'N1/24/3G/01/DN/11/N1243G01D-N11@4.j...
# NI114D0A1-C12  [{'path': 'NI/11/4D/0A/1C/12/NI114D0A1-C12@7.j...
#
#                                                             name  \
# sku
# NI114D0A8-K11  AIR MAX 97 - Baskets basses - midnight navy/la...
# N1243E0J0-Q11         AIR PANT - Pantalon de survêtement - black
# N1243A0XZ-C11  FLEX RUNNER - Chaussures de running neutres - ...
# N1243G01D-N11  FULL ZIP - veste en sweat zippée - cargo khaki...
# NI114D0A1-C12    REACT PRESTO - Baskets basses - wolf grey/white
#
#               price.has_different_original_prices price.has_different_prices  \
# sku
# NI114D0A8-K11                               False                       True
# N1243E0J0-Q11                               False                       True
# N1243A0XZ-C11                               False                      False
# N1243G01D-N11                               False                      False
# NI114D0A1-C12                               False                       True
#
#               price.has_different_promotional_prices  \
# sku
# NI114D0A8-K11                                   True
# N1243E0J0-Q11                                   True
# N1243A0XZ-C11                                  False
# N1243G01D-N11                                  False
# NI114D0A1-C12                                   True
#
#               price.has_discount_on_selected_sizes_only price.original  \
# sku
# NI114D0A8-K11                                     False       144,95 €
# N1243E0J0-Q11                                     False        44,95 €
# N1243A0XZ-C11                                     False        29,95 €
# N1243G01D-N11                                     False        39,95 €
# NI114D0A1-C12                                     False        94,95 €
#
#               price.promotional product_group  \
# sku
# NI114D0A8-K11           58,00 €          shoe
# N1243E0J0-Q11           13,49 €      clothing
# N1243A0XZ-C11           18,00 €          shoe
# N1243G01D-N11           16,00 €      clothing
# NI114D0A1-C12           38,00 €          shoe
#
#                                                   sizes  \
# sku
# NI114D0A8-K11              [35.5, 36, 38, 38.5, 39, 40]
# N1243E0J0-Q11     [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# N1243A0XZ-C11    [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]
# N1243G01D-N11           [8-10a, 10-12a, 12-13a, 13-15a]
# NI114D0A1-C12  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
#
#                                                          url_key
# sku
# NI114D0A8-K11  nike-sportswear-air-max-97-baskets-basses-midn...
# N1243E0J0-Q11  nike-performance-air-pant-pantalon-de-survetem...
# N1243A0XZ-C11  nike-performance-flex-runner-chaussures-de-run...
# N1243G01D-N11  nike-performance-ya76-veste-en-sweat-n1243g01d...
# NI114D0A1-C12  nike-sportswear-react-presto-baskets-basses-ni...

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
# your code

df.brand_name.value_counts().head(1)
# Out:
# Friboo    905
# Name: brand_name, dtype: int64

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers.
# your code
df['price.original'] = df['price.original'].str.replace(",", ".").str.replace("€", "").str.strip()
df['price.promotional'] = df['price.promotional'].str.replace(",", ".").str.replace("€", "").str.strip()
df['price.original'] = pd.to_numeric(df['price.original'])
df['price.promotional'] = pd.to_numeric(df['price.promotional'])

# %%
df['discount'] = df['price.original'] - df['price.promotional']

# %%
df.groupby('brand_name').sum().sort_values(by=['discount'], ascending = False).head(1)
# Out:
#             price.original  price.promotional  discount
# brand_name
# Friboo            23331.75           12954.07  10377.68

# %% [markdown]
# #### Display the brands without discount at all

# %%
# your code
df.head()
# Out:
#               amount        brand_name  \
# sku
# NI114D0A8-K11    NaN   Nike Sportswear
# N1243E0J0-Q11    NaN  Nike Performance
# N1243A0XZ-C11   82 g  Nike Performance
# N1243G01D-N11    NaN  Nike Performance
# NI114D0A1-C12    NaN   Nike Sportswear
#
#                                                  family_articles  \
# sku
# NI114D0A8-K11  [{'sku': 'NI114D0A8-K11', 'url_key': 'nike-spo...
# N1243E0J0-Q11  [{'sku': 'N1243E0J0-Q11', 'url_key': 'nike-per...
# N1243A0XZ-C11  [{'sku': 'N1243A0XZ-C11', 'url_key': 'nike-per...
# N1243G01D-N11  [{'sku': 'N1243G01D-N11', 'url_key': 'nike-per...
# NI114D0A1-C12  [{'sku': 'NI114D0A1-C12', 'url_key': 'nike-spo...
#
#                                                            flags is_premium  \
# sku
# NI114D0A8-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243E0J0-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243A0XZ-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# N1243G01D-N11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
# NI114D0A1-C12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      False
#
#                                                            media  \
# sku
# NI114D0A8-K11  [{'path': 'NI/11/4D/0A/8K/11/NI114D0A8-K11@7.j...
# N1243E0J0-Q11  [{'path': 'N1/24/3E/0J/0Q/11/N1243E0J0-Q11@4.j...
# N1243A0XZ-C11  [{'path': 'N1/24/3A/0X/ZC/11/N1243A0XZ-C11@9.j...
# N1243G01D-N11  [{'path': 'N1/24/3G/01/DN/11/N1243G01D-N11@4.j...
# NI114D0A1-C12  [{'path': 'NI/11/4D/0A/1C/12/NI114D0A1-C12@7.j...
#
#                                                             name  \
# sku
# NI114D0A8-K11  AIR MAX 97 - Baskets basses - midnight navy/la...
# N1243E0J0-Q11         AIR PANT - Pantalon de survêtement - black
# N1243A0XZ-C11  FLEX RUNNER - Chaussures de running neutres - ...
# N1243G01D-N11  FULL ZIP - veste en sweat zippée - cargo khaki...
# NI114D0A1-C12    REACT PRESTO - Baskets basses - wolf grey/white
#
#               price.has_different_original_prices price.has_different_prices  \
# sku
# NI114D0A8-K11                               False                       True
# N1243E0J0-Q11                               False                       True
# N1243A0XZ-C11                               False                      False
# N1243G01D-N11                               False                      False
# NI114D0A1-C12                               False                       True
#
#               price.has_different_promotional_prices  \
# sku
# NI114D0A8-K11                                   True
# N1243E0J0-Q11                                   True
# N1243A0XZ-C11                                  False
# N1243G01D-N11                                  False
# NI114D0A1-C12                                   True
#
#               price.has_discount_on_selected_sizes_only  price.original  \
# sku
# NI114D0A8-K11                                     False          144.95
# N1243E0J0-Q11                                     False           44.95
# N1243A0XZ-C11                                     False           29.95
# N1243G01D-N11                                     False           39.95
# NI114D0A1-C12                                     False           94.95
#
#                price.promotional product_group  \
# sku
# NI114D0A8-K11              58.00          shoe
# N1243E0J0-Q11              13.49      clothing
# N1243A0XZ-C11              18.00          shoe
# N1243G01D-N11              16.00      clothing
# NI114D0A1-C12              38.00          shoe
#
#                                                   sizes  \
# sku
# NI114D0A8-K11              [35.5, 36, 38, 38.5, 39, 40]
# N1243E0J0-Q11     [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# N1243A0XZ-C11    [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]
# N1243G01D-N11           [8-10a, 10-12a, 12-13a, 13-15a]
# NI114D0A1-C12  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
#
#                                                          url_key  discount
# sku
# NI114D0A8-K11  nike-sportswear-air-max-97-baskets-basses-midn...     86.95
# N1243E0J0-Q11  nike-performance-air-pant-pantalon-de-survetem...     31.46
# N1243A0XZ-C11  nike-performance-flex-runner-chaussures-de-run...     11.95
# N1243G01D-N11  nike-performance-ya76-veste-en-sweat-n1243g01d...     23.95
# NI114D0A1-C12  nike-sportswear-react-presto-baskets-basses-ni...     56.95

# %%
df[['brand_name', 'discount']].loc[df['discount'] == 0]
# Out:
#                         brand_name  discount
# sku
# N1243A0XY-C11     Nike Performance       0.0
# AD124G02B-K11     adidas Originals       0.0
# AD123F009-T11     adidas Originals       0.0
# A0F83C00L-K11  Abercrombie & Fitch       0.0
# QU184C01C-K11           Quiksilver       0.0
# N1284C00K-E11     Nike Performance       0.0
# F5724C00F-E11               Friboo       0.0
# N1243D0YV-K11     Nike Performance       0.0
# N1243E0K8-C11     Nike Performance       0.0
# BU383C000-Q11              Buffalo       0.0
# P1314D000-Q11            Palladium       0.0
# GP023G0C5-C11                  GAP       0.0
# N1243N035-J12     Nike Performance       0.0
# RI923L010-K11         River Island       0.0
# BAK23D00P-A11        Bardot Junior       0.0
# P6824C01N-K11    Petrol Industries       0.0
# SN583C002-Q11            Sunseeker       0.0
# F0984C005-K11                Frugi       0.0
# P6824C01G-K11    Petrol Industries       0.0
# JOC43E00E-A12               Jordan       0.0
# OU524C00S-K11          Outfit Kids       0.0
# P6824G080-K11    Petrol Industries       0.0
# OV023F039-A11                  OVS       0.0
# N1243E0BW-I11     Nike Performance       0.0
# OV023F039-A11                  OVS       0.0
# N1243E0BW-I11     Nike Performance       0.0
# N1243E07T-N11     Nike Performance       0.0
# C1Q23B00H-A11            Cotton On       0.0
# KE543A0A1-K13                 Keen       0.0
# RG524C009-N11               Re-Gen       0.0
# ...                            ...       ...
# N1424B06W-O11              Noppies       0.0
# N1423F06N-J11              Noppies       0.0
# N1423F06S-J11              Noppies       0.0
# N1424G09Y-G11              Noppies       0.0
# N1424G0AE-C11              Noppies       0.0
# N1423G08L-J11              Noppies       0.0
# N1423G08I-K11              Noppies       0.0
# N1421J00A-G11              Noppies       0.0
# N1424G0AA-K11              Noppies       0.0
# N1423G08X-J12              Noppies       0.0
# N1424K03U-M11              Noppies       0.0
# N1423J02P-J11              Noppies       0.0
# NX324D03C-K11                 Next       0.0
# N1424G0AJ-K11              Noppies       0.0
# N1423G08X-J11              Noppies       0.0
# N1423G089-A11              Noppies       0.0
# N1426B028-O11              Noppies       0.0
# N1426B02O-A11              Noppies       0.0
# N1424G0AN-K11              Noppies       0.0
# N1426B02N-K11              Noppies       0.0
# P6824G08E-G11    Petrol Industries       0.0
# N1424L010-Q11              Noppies       0.0
# N1426J00V-E11              Noppies       0.0
# N1422G000-O11              Noppies       0.0
# N1426G01Y-O11              Noppies       0.0
# N1426K018-K11              Noppies       0.0
# N1424G0AO-J11              Noppies       0.0
# N1422S000-C11              Noppies       0.0
# N1486A00E-O11              Noppies       0.0
# AJ224G00S-K11       Emporio Armani       0.0
#
# [309 rows x 2 columns]

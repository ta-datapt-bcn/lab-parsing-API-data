# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
urlzal='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
headers_safari = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0.3 Safari/605.1.15',
    'Cookie': '_abck=D3A410542156C6446A65CE77A24C1962~-1~...~-1~-1~-1; Zalando-Client-Id=21c46254-40fc-44be-8f7e-b5740eeae773; _gat_zalga=1; bm_sv=FCE1A3F3B8D168898FAE490B0B094022~k9qt8e92MysEYyG7SZcdNF79Ynt/wNCbmOZ52ojVgRLEnNbWc/6q7xqs289Q/jo/Gk6IrKICLz07LI3GmqoFDRjfAJcslncOhiWXOKY0/qD6Y8Odr4RV6N2+S7JStdBnzmtyQh8c7U5NtCYhUSAAtGJN9ILdgnburXiNEBC7LuA=; _fbp=fb.1.1616582164479.1495405834; _ga=GA1.2.1536409037.1616582164; _gid=GA1.2.839128922.1616582164; ncx=k; _gcl_au=1.1.742902882.1616582164; sqt_cap=1616582151909; ak_bmsc=766A961EE4C14F7277332106EE3F0DCA~000000000000000000000000000000~...; fvgs_ml=mosaic; mpulseinject=false; bm_mi=B6F83C97ED5197A331B2167F3E9956B6~; bm_sz=005A1A795BE0753193A0DB3DC9FEADA3~; frsx=AAAAAIBbvAVqZJCEK0yUBKDVtRtYUfe3udRw3cWp9ervTdeUs0w7yWGO6vPp7jXpuOryCaKex_X_6F8tcQzWXIDHDTLiYOkygwBr6xoXTNY_NwdokXNH6VNW82y6zlNp0l8BlCSixYKqmdwXjojkps4='
}

# %%
respzal = requests.get(urlzal, headers = headers_safari)

# %%
respzal.status_code
# Out:
# 200

# %%
respzal.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-6-135866d881e7> in <module>
# ----> 1 respzal.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
respzal.text
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n    <link\n      rel="shortcut icon"\n      href="data:image/png;base64,..."\n    />\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <title>ZALANDO</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style>\n      html,\n      body {\n        padding: 0;\n        margin: 0;\n        height: 100%;\n      }\n      header {\n        height: 90px;\n        display: block;\n        text-align: center;\n      }\n      header svg {\n        padding-top: 30px;\n      }\n      .reference {\n        color: #ff6900;\n        font-size: 12px;\n        font-weight: bold;\n      }\n      .z-500-error-page {\n        display: flex;\n        align-items: center;\n        justify-content: center;\n        font-family: ArialMT, Arial, Helvetica, sans-serif;\n        color: #1a1a1a;\n        background-color: #f7f7f7;\n        min-height: 600px;\n        height: calc(100% - 92px);\n      }\n      main {\n        padding-top: 40px;\n        text-align: center;\n      }\n      .z-500-error-page svg {\n        margin: 0 auto 39px;\n      }\n      .z-500-error-page h1 {\n        margin: 0 auto;\n        margin-bottom: 20px;\n        font-size: 34px;\n        width: 60%;\n      }\n      .z-500-error-page p {\n        font-size: 16px;\n        margin: 0 auto 37px;\n        line-height: 1.5;\n        letter-spacing: 0.7px;\n        max-width: 660px;\n      }\n      .z-500-error-page a {\n        margin: 0 9px;\n        padding: 15px 50px;\n        display: inline-block;\n        color: white;\n        background: black;\n        font-size: 14px;\n        font-weight: 700;\n        text-align: center;\n        text-decoration: none;\n        letter-spacing: 0.5px;\n        cursor: pointer;\n        border: 2px solid #000;\n        position: relative;\n        min-width: 135px;\n        box-sizing: border-box;\n        border-radius: 5px;\n      }\n      .z-500-error-page a:before {\n        content: "";\n        position: absolute;\n        top: 0;\n        bottom: 0;\n        left: 0;\n        width: 0;\n        background-color: #000;\n        -o-transition: width 0.3s ease 0s;\n        -moz-transition: width 0.3s ease 0s;\n        -webkit-transition: width 0.3s ease 0s;\n        transition: width 0.3s ease 0s;\n        z-index: -1;\n      }\n      .z-500-error-page a:hover {\n        -o-transition: color 0.3s ease 0s;\n        -moz-transition: color 0.3s ease 0s;\n        -webkit-transition: color 0.3s ease 0s;\n        transition: color 0.3s ease 0s;\n      }\n      .z-500-error-page a:hover:before {\n        width: 100%;\n      }\n      @media screen and (max-width: 599px) {\n        .z-500-error-page {\n          padding: 30px 20px 50px;\n        }\n        .z-500-error-page h1 {\n          font-size: 24px;\n        }\n        .z-500-error-page a {\n          display: block;\n          margin: 28px auto;\n          width: 80%;\n        }\n      }\n      .z-500-error-page [lang] {\n        display: none;\n      }\n    </style>\n  </head>\n  <body>\n    <header>\n      <svg width="160" viewBox="0 0 99 20" xmlns="http://www.w3.org/2000/svg">\n        <title>zalando_logo_20</title>\n        <g fill="none" fill-rule="evenodd">\n          <path\n            d="M43.21 4.944c-.715-.398-1.777-.593-3.248-.593-2.012.002-3.88.426-4.586.693-.16.052-.33.192-.334.43v.054l.2 1.016.004.02c.062.205.232.3.385.3h.003c.05-.004.088-.014.124-.023l.335-.08c.877-.22 2.202-.558 3.68-.558.898 0 1.5.08 1.905.252.656.253.66.684.667 1.397v1.067c-.075-.002-.202-.003-.397-.003-.725 0-2.15.035-3.55.262-2.138.334-3.907.853-3.895 3.845 0 3.798 3.47 3.804 5.136 3.808 1.13-.002 2.175-.172 2.858-.314 1.555-.367 1.953-.868 1.932-2.437V7.763c0-.964.004-2.162-1.22-2.82zm-.855 9.753c-.828.273-1.734.41-2.694.41v.09-.09c-1.534-.012-3.03-.19-3.033-2.175.01-1.58.84-1.767 1.89-2.005l.073-.017c.934-.203 3.282-.24 3.765-.246v4.033zm19.41-6.935v6.314c.02 1.57-.377 2.07-1.933 2 ...

# %% [markdown]
# Nos carga una página de error a pesar de que el status code es 200. Probaremos con otra web conectada a una API.

# %% [markdown]
# #### Test with Stubbe Chocolates website

# %%
url='https://cdn4.editmysite.com/app/store/api/v13/editor/users/135718637/sites/228142249342516758/products?page=1&per_page=60&sort_by=category_order&sort_order=asc&categories[]=11eb584a0b77c3e79467ac1f6bbbcc9c&include=images,media_files'

# %%
# headers definition
resp = requests.get(url)

# %%
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '{"data":[{"id":"11eb5840016c06b19467ac1f6bbbcc9c","owner_id":"135718637","site_id":"228142249342516758","site_product_id":"2","visibility":"visible","visibility_tl":"Visible","visibility_locked":false,"name":"Verspielt","short_description":"<p>Verspielt, Daniel Stubbe\'s signature milk chocolate, translates from German as playful. This 40% cocoa milk chocolate is a rich, deep, memorable chocolate that playfully elevates the traditional milk chocolate taste with a higher cacao content.<\\/p><p> <\\/p><p><em>Availability same day pick-up, or next day delivery, if ordered before 3pm<\\/em><\\/p>","variation_type":"3","product_type":"physical","product_type_details":[],"taxable":true,"required_feature_to_sell":null,"min_prep_time":120,"site_shipping_box_id":3,"site_link":"product\\/verspielt\\/2","permalink":null,"seo_page_description":null,"seo_page_title":null,"avg_rating":null,"avg_rating_all":null,"inventory":{"total":33,"lowest":33,"enabled":true,"marked_sold_out_at_all_existing_locations":false,"marked_sold_out_skus_count":0,"has_location_not_tracking":false},"measurement_unit_abbreviation":null,"price":{"high":9,"high_with_modifiers":9,"high_formatted":"CAD$9.00","high_formatted_with_modifiers":"CAD$9.00","low":9,"low_with_modifiers":9,"low_formatted":"CAD$9.00","low_formatted_with_modifiers":"CAD$9.00","regular_high":9,"regular_high_with_modifiers":9,"regular_high_formatted":"CAD$9.00","regular_high_formatted_with_modifiers":"CAD$9.00","regular_low":9,"regular_low_with_modifiers":9,"regular_low_formatted":"CAD$9.00","regular_low_formatted_with_modifiers":"CAD$9.00"},"is_alcoholic":false,"created_date":"2021-01-16T21:15:48+00:00","updated_date":"2021-03-28T20:18:42+00:00","badges":{"low_stock":false,"out_of_stock":false,"on_sale":false},"seo_product_image_id":null,"og_title":null,"og_description":null,"thumbnail":{"data":{"id":"11eb602d820d36679467ac1f6bbbcc9c","owner_id":"135718637","site_id":"228142249342516758","site_product_image_id":"2","url":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png","absolute_url":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png","urls":{"80":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=80","160":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=160","320":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=320","640":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=640","1280":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=1280","1390":"\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png"},"width":1390,"height":1388,"format":"png","created_at":"2021-01-26T23:23:33+00:00","updated_at":"2021-01-26T23:23:33+00:00","absolute_urls":{"80":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=80","160":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=160","320":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=320","640":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=640","1280":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png?width=1280","1390":"https:\\/\\/www.stubbechocolates.com\\/uploads\\/1\\/3\\/5\\/7\\/135718637\\/s228142249342516758_p2_i2_w1390.png"}}},"placeholder_image":{"data":{"placeholder":true,"url":"\\/images\\/commerce\\/store-app\\/app\\/universal_product_placeholder.png","absolute_url":"cdn3.editmysite.com\\/images\\/commerce\\/store-app\\/app\\/universal_product_placeholder.png"}},"images":{"data":[{"id":"11eb602d820d36679467ac1f6bbbcc9c","owner_id": ...

# %%
choc = resp.json()

# %%
choc['data'][9]['owner_id']
# Out:
# '135718637'

# %%
choclist = choc['data']
choclist[0]['id']
# Out:
# '11eb5840016c06b19467ac1f6bbbcc9c'

# %%
df = pd.DataFrame()

# %%
for a in range(len(choclist)):
    df.loc[a, 'name'] = choclist[a]['name']
    df.loc[a, 'price'] = choclist[a]['price']['high']
    df.loc[a, 'description'] = choclist[a]['short_description']

# %%
# Your code

df
# Out:
#                                              name  price  \
# 0                                       Verspielt    9.0
# 1                                        Verliebt    9.0
# 2                           Verliebt Gianduja bar   10.0
# 3                          Garam Masala Pistachio   10.0
# 4              Mango Passion fruit Lime Chili bar   10.0
# 5                                        Mint bar    9.0
# 6                  Dulcey White Chocolate Caramel    9.0
# 7                         Cinnamon Milk Chocolate    9.0
# 8                                  Semisweet Bars    7.0
# 9                         Semisweet Sea Salt Bars    7.0
# 10                 Semisweet Pink Peppercorn Bars    7.0
# 11                     Semisweet Nut & Berry Bars    7.0
# 12                            Milk Chocolate Bars    7.0
# 13         Milk Chocolate with Roasted Cocoa Bean    7.0
# 14                    Milk Chocolate Sea Salt Bar    7.0
# 15                Milk Chocolate Nut & Berry Bars    7.0
# 16                         Rugoso - Nicaragua 71%    8.0
# 17       Mexico 66%  Single Origin Chocolate Bars    8.0
# 18  La Esmeralda - Organic Dominican Republic 74%    8.0
# 19                                 Venezuela, 72%    8.0
# 20                                  Tanzania, 75%    8.0
# 21               White Chocolate Nut & Berry Bars    7.0
# 22                  White Chocolate Cranberry Bar    7.0
# 23                           White Chocolate Bars    7.0
# 24                   Bittersweet 70% Sea Salt Bar    7.0
# 25                Bittersweet 70% Nut & Berry Bar    7.0
# 26                            Bittersweet 85% Bar    7.0
# 27                  Bittersweet 85% Sea Salt Bars    7.0
# 28                Bittersweet 85% Nut & Berry Bar    7.0
# 29                  Bittersweet 85% Cranberry Bar    7.0
# 30                     Bittersweet 85% Almond Bar    7.0
# 31               Organic Chocolate Bars Selection    9.0
# 32           Maltitol Dark Chocolate Hazelnut Bar    9.0
# 33                    Maltitol Dark Chocolate Bar    9.0
# 34                            Strawberry Love Bar    8.5
# 35                                  Yuzu Love Bar    8.5
#
#                                           description
# 0   <p>Verspielt, Daniel Stubbe's signature milk c...
# 1   <p>Verliebt, Daniel Stubbe's signature dark ch...
# 2   <p>This gourmet bar is made with the Stubbe si...
# 3   <p>Single origin Ghana milk chocolate combined...
# 4   <p>An exciting combination of creamy Zephyr wh...
# 5   <p>The Stubbe gourmet mint flavoured dark choc...
# 6   <p>Smooth, creamy chocolate with a velvety tex...
# 7   <p>Stubbe Chocolates cinnamon flavoured milk c...
# 8   <p>Stubbe semisweet dark chocolate bars have a...
# 9   <p>Stubbe semisweet dark chocolate bars, 54% c...
# 10  <p>Stubbe semisweet dark chocolate bars, 54% c...
# 11  <p>Stubbe semisweet dark chocolate bars, 54% c...
# 12  Stubbe milk chocolate bars are rich and creamy...
# 13  <p>Stubbe 33% cocoa content milk chocolate bar...
# 14  <p>Stubbe 33% cocoa content milk chocolate bar...
# 15  <p>Stubbe milk chocolate bar, rich and creamy ...
# 16  <p>Single origin chocolate from Nicaragua, Rug...
# 17  <p>Crafted with cocoa beans from Mexico this 6...
# 18  <p>La Esmeralda is produced from cocoa beans g...
# 19  <p>72% cocoa single origin chocolate from Vene...
# 20  <p>75% cocoa single origin chocolate from Tanz...
# 21  <p>Stubbe white chocolate bar, rich and creamy...
# 22  <p>Stubbe white chocolate bar, rich and creamy...
# 23  <p>Stubbe Chocolates white chocolate bar is cr...
# 24  <p>Our 70% cocoa content chocolate bar has a b...
# 25  <p>Our 70% cocoa content chocolate bar has a b...
# 26  <p>Dark and bitter, our 85% cocoa content choc...
# 27  <p>Dark and bitter, our 85% cocoa content choc...
# 28  <p>Dark and bitter, our 85% cocoa content choc...
# 29  <p>Dark and bitter, our 85% cocoa content choc...
# 30  <p>Dark and bitter, our 85% cocoa content choc...
# 31  <p>Our Bio-line is made with all organically p...
# 32  <p>Maltitol dark chocolate bar with roasted ha...
# 33  <p>Maltitol dark chocolate bar. *this is a veg...
# 34  <p>Strawberry puree and cocoa butter. This is ...
# 35  <p>Yuzu puree with cocoa butter. This is a veg...

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %% [markdown]
# Same exercise extracting more info with params as well

# %%
# Primero hacemos el test con la página del endpoint buscando la página 2 en parámetros

url2='https://cdn4.editmysite.com/app/store/api/v13/editor/users/135718637/sites/228142249342516758/products'

# %%
params2 = {'page':2}

# %%
resp2 = requests.get(url2, params = params2)

# %%
resp2.status_code
# Out:
# 200

# %%
resp2.json()
# Out:
# {'data': [{'id': '11eb59bf8ff39ceb9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '27',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Mozart Torte',
#    'short_description': '<p>Flourless almond cake with a layer of raspberry and a layer of dark chocolate ganache, covered in dark chocolate.</p><p><br /></p><p><em>Availability: two days after your order is placed</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': False,
#    'required_feature_to_sell': None,
#    'min_prep_time': 1440,
#    'site_shipping_box_id': None,
#    'site_link': 'product/mozart-torte/27',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto flourless almond cake with a layer of raspberry and a layer of dark chocolate ganache, covered in dark chocolate.',
#    'seo_page_title': 'Stubbe Chocolates Toronto Mozart Torte',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 15,
#     'lowest': 15,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 42,
#     'high_with_modifiers': 42,
#     'high_formatted': 'CAD$42.00',
#     'high_formatted_with_modifiers': 'CAD$42.00',
#     'low': 42,
#     'low_with_modifiers': 42,
#     'low_formatted': 'CAD$42.00',
#     'low_formatted_with_modifiers': 'CAD$42.00',
#     'regular_high': 42,
#     'regular_high_with_modifiers': 42,
#     'regular_high_formatted': 'CAD$42.00',
#     'regular_high_formatted_with_modifiers': 'CAD$42.00',
#     'regular_low': 42,
#     'regular_low_with_modifiers': 42,
#     'regular_low_formatted': 'CAD$42.00',
#     'regular_low_formatted_with_modifiers': 'CAD$42.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:01:25+00:00',
#    'updated_date': '2021-03-26T23:33:16+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d85186a5c9467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '2',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=640',
#       '692': '/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg'},
#      'width': 692,
#      'height': 692,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:38+00:00',
#      'updated_at': '2021-01-26T23:23:38+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg?width=640',
#       '692': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p27_i2_w692.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59bfb53667269467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '28',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'The Davenport',
#    'short_description': '<p>Gluten-free rice flour chocolate cake with layers of caramel milk chocolate ganache topped with sea salt dark chocolate wafers. *Our cakes are produced in a kitchen that uses a variety of nuts and flour (gluten).</p><p><br /></p><p><em>Availability: two days after your order is placed</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': False,
#    'required_feature_to_sell': None,
#    'min_prep_time': 1440,
#    'site_shipping_box_id': None,
#    'site_link': 'product/the-davenport/28',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto gluten-free rice flour chocolate cake with layers of caramel milk chocolate ganache topped with sea salt dark chocolate wafers. ',
#    'seo_page_title': 'Stubbe Chocolates Toronto Davenport Cake',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 15,
#     'lowest': 15,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 42,
#     'high_with_modifiers': 42,
#     'high_formatted': 'CAD$42.00',
#     'high_formatted_with_modifiers': 'CAD$42.00',
#     'low': 42,
#     'low_with_modifiers': 42,
#     'low_formatted': 'CAD$42.00',
#     'low_formatted_with_modifiers': 'CAD$42.00',
#     'regular_high': 42,
#     'regular_high_with_modifiers': 42,
#     'regular_high_formatted': 'CAD$42.00',
#     'regular_high_formatted_with_modifiers': 'CAD$42.00',
#     'regular_low': 42,
#     'regular_low_with_modifiers': 42,
#     'regular_low_formatted': 'CAD$42.00',
#     'regular_low_formatted_with_modifiers': 'CAD$42.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:02:27+00:00',
#    'updated_date': '2021-03-29T01:36:18+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d857bf36e9467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '2',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=640',
#       '1280': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=1280',
#       '1300': '/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg'},
#      'width': 1300,
#      'height': 1300,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:39+00:00',
#      'updated_at': '2021-01-26T23:23:39+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=640',
#       '1280': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg?width=1280',
#       '1300': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p28_i2_w1300.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c002b80c6e9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '29',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Anna Torte',
#    'short_description': '<p>Chocolate sponge cake with layers of orange-chocolate ganache, covered with dark chocolate. Ten servings.</p><p><br /></p><p><em>Availability: two days after your order is placed</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': False,
#    'required_feature_to_sell': None,
#    'min_prep_time': 1440,
#    'site_shipping_box_id': None,
#    'site_link': 'product/anna-torte/29',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto chocolate sponge cake with layers of orange-chocolate ganache, covered with dark chocolate. Ten servings.',
#    'seo_page_title': 'Stubbe Chocolates Toronto Anna Torte',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 20,
#     'lowest': 20,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 40,
#     'high_with_modifiers': 40,
#     'high_formatted': 'CAD$40.00',
#     'high_formatted_with_modifiers': 'CAD$40.00',
#     'low': 40,
#     'low_with_modifiers': 40,
#     'low_formatted': 'CAD$40.00',
#     'low_formatted_with_modifiers': 'CAD$40.00',
#     'regular_high': 40,
#     'regular_high_with_modifiers': 40,
#     'regular_high_formatted': 'CAD$40.00',
#     'regular_high_formatted_with_modifiers': 'CAD$40.00',
#     'regular_low': 40,
#     'regular_low_with_modifiers': 40,
#     'regular_low_formatted': 'CAD$40.00',
#     'regular_low_formatted_with_modifiers': 'CAD$40.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:04:37+00:00',
#    'updated_date': '2021-03-25T15:39:12+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d8555d36b9467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '3',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=640',
#       '1280': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=1280',
#       '1300': '/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg'},
#      'width': 1300,
#      'height': 1300,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:39+00:00',
#      'updated_at': '2021-01-26T23:23:39+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=640',
#       '1280': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg?width=1280',
#       '1300': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p29_i3_w1300.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c0437698ab9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '30',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Afternoon Relaxer for Two',
#    'short_description': '<p>This gift set is perfect for an afternoon treat for two. Included in the gift box are two Stubbe hot cocoa bombs, one milk and one dark, shortbread cookies, and a chocolate plaque with a short personal message of your choosing.</p><p><br /></p><p><em>Availability: one days after your order is placed</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 1440,
#    'site_shipping_box_id': 4,
#    'site_link': 'product/afternoon-relaxer-for-two/30',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto gift set for two included hot cocoa bombs, shortbread cookies, and a chocolate plaque with a short personal message of your choosing.',
#    'seo_page_title': 'Stubbe Chocolates Toronto Afternoon Relaxer for Two',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 26,
#     'lowest': 26,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 34,
#     'high_with_modifiers': 34,
#     'high_formatted': 'CAD$34.00',
#     'high_formatted_with_modifiers': 'CAD$34.00',
#     'low': 34,
#     'low_with_modifiers': 34,
#     'low_formatted': 'CAD$34.00',
#     'low_formatted_with_modifiers': 'CAD$34.00',
#     'regular_high': 34,
#     'regular_high_with_modifiers': 34,
#     'regular_high_formatted': 'CAD$34.00',
#     'regular_high_formatted_with_modifiers': 'CAD$34.00',
#     'regular_low': 34,
#     'regular_low_with_modifiers': 34,
#     'regular_low_formatted': 'CAD$34.00',
#     'regular_low_formatted_with_modifiers': 'CAD$34.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:06:26+00:00',
#    'updated_date': '2021-03-25T15:39:12+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb73ad15085131b276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '4',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-02-20T18:54:38+00:00',
#      'updated_at': '2021-02-20T18:54:38+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p30_i4_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c069531fa19467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '31',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Cocoa Powder',
#    'short_description': '100% cocoa powder in a 1kg bag. This is a vegan product',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 3,
#    'site_link': 'product/cocoa-powder/31',
#    'permalink': None,
#    'seo_page_description': None,
#    'seo_page_title': None,
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 3,
#     'lowest': 3,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 32,
#     'high_with_modifiers': 32,
#     'high_formatted': 'CAD$32.00',
#     'high_formatted_with_modifiers': 'CAD$32.00',
#     'low': 32,
#     'low_with_modifiers': 32,
#     'low_formatted': 'CAD$32.00',
#     'low_formatted_with_modifiers': 'CAD$32.00',
#     'regular_high': 32,
#     'regular_high_with_modifiers': 32,
#     'regular_high_formatted': 'CAD$32.00',
#     'regular_high_formatted_with_modifiers': 'CAD$32.00',
#     'regular_low': 32,
#     'regular_low_with_modifiers': 32,
#     'regular_low_formatted': 'CAD$32.00',
#     'regular_low_formatted_with_modifiers': 'CAD$32.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:07:30+00:00',
#    'updated_date': '2021-03-26T00:36:58+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb8330ef104a4fb276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-03-12T12:46:15+00:00',
#      'updated_at': '2021-03-12T12:46:15+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p31_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c147e6f3089467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '32',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Party Mix',
#    'short_description': '<p>Perfect for sharing, a cylinder with layers of almond clusters, berry clusters, nonpareils and tropfen (chocolate pearls). Small 460gr, large 650gr</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '2',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 4,
#    'site_link': 'product/party-mix/32',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto cylinder with layers of almond clusters, berry clusters, nonpareils and tropfen (chocolate pearls). ',
#    'seo_page_title': 'Stubbe Chocolates Toronto Party Mix',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 34,
#     'lowest': 14,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 42.5,
#     'high_with_modifiers': 42.5,
#     'high_formatted': 'CAD$42.50',
#     'high_formatted_with_modifiers': 'CAD$42.50',
#     'low': 29.75,
#     'low_with_modifiers': 29.75,
#     'low_formatted': 'CAD$29.75',
#     'low_formatted_with_modifiers': 'CAD$29.75',
#     'regular_high': 42.5,
#     'regular_high_with_modifiers': 42.5,
#     'regular_high_formatted': 'CAD$42.50',
#     'regular_high_formatted_with_modifiers': 'CAD$42.50',
#     'regular_low': 29.75,
#     'regular_low_with_modifiers': 29.75,
#     'regular_low_formatted': 'CAD$29.75',
#     'regular_low_formatted_with_modifiers': 'CAD$29.75'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:13:43+00:00',
#    'updated_date': '2021-03-28T19:06:42+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602eb5f181d59467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:32:10+00:00',
#      'updated_at': '2021-01-26T23:32:10+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p32_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c18b7c90ae9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '33',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Gateau Voyage Hazelnut',
#    'short_description': '<p>Our Hazelnut "Travel cake" is dense, moist and rich, with hints of lemon and vanilla. Iced in a dark chocolate glaze with caramelized hazelnut bits. Our Gateau Voyage cakes are only available as a 5" cake, perfect for a dinner party of 4.</p><p><br /></p><p><em>Availability: two days after your order is placed</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': False,
#    'required_feature_to_sell': None,
#    'min_prep_time': 1440,
#    'site_shipping_box_id': None,
#    'site_link': 'product/gateau-voyage-hazelnut/33',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Tonto hazelnut "Travel cake" is dense, moist and rich, with hints of lemon and vanilla. Iced in a dark chocolate glaze with caramelized hazelnut bits. ',
#    'seo_page_title': 'Stubbe Chocolates Tonto Gateau Voyage Hazelnut',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 11,
#     'lowest': 11,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 28.5,
#     'high_with_modifiers': 28.5,
#     'high_formatted': 'CAD$28.50',
#     'high_formatted_with_modifiers': 'CAD$28.50',
#     'low': 28.5,
#     'low_with_modifiers': 28.5,
#     'low_formatted': 'CAD$28.50',
#     'low_formatted_with_modifiers': 'CAD$28.50',
#     'regular_high': 28.5,
#     'regular_high_with_modifiers': 28.5,
#     'regular_high_formatted': 'CAD$28.50',
#     'regular_high_formatted_with_modifiers': 'CAD$28.50',
#     'regular_low': 28.5,
#     'regular_low_with_modifiers': 28.5,
#     'regular_low_formatted': 'CAD$28.50',
#     'regular_low_formatted_with_modifiers': 'CAD$28.50'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:15:36+00:00',
#    'updated_date': '2021-03-28T23:58:00+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb7bb4f1c09a5eb276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '3',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-03-03T00:11:04+00:00',
#      'updated_at': '2021-03-03T00:11:04+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p33_i3_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c64f5f41319467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '34',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Maltitol Dark Chocolate Almond Bark',
#    'short_description': '<p>Roasted Almonds in dark Maltitol chocolate broken into small sheet like pieces.</p><p>Maltitol is a sugar alcohol and used as a sugar substitute. It is a type of carbohydrate that is neither sugar nor alcohol. Sugar alcohols are found naturally in some fruits and vegetables. *this is a vegan product</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 4,
#    'site_link': 'product/maltitol-dark-chocolate-almond-bark/34',
#    'permalink': None,
#    'seo_page_description': None,
#    'seo_page_title': 'Tubbe Chocolates Toronto Maltitol Dark Chocolate Almond Bark',
#    'avg_rating': None,
#    'avg_rating_all': 5,
#    'inventory': {'total': 21,
#     'lowest': 21,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 24,
#     'high_with_modifiers': 24,
#     'high_formatted': 'CAD$24.00',
#     'high_formatted_with_modifiers': 'CAD$24.00',
#     'low': 24,
#     'low_with_modifiers': 24,
#     'low_formatted': 'CAD$24.00',
#     'low_formatted_with_modifiers': 'CAD$24.00',
#     'regular_high': 24,
#     'regular_high_with_modifiers': 24,
#     'regular_high_formatted': 'CAD$24.00',
#     'regular_high_formatted_with_modifiers': 'CAD$24.00',
#     'regular_low': 24,
#     'regular_low_with_modifiers': 24,
#     'regular_low_formatted': 'CAD$24.00',
#     'regular_low_formatted_with_modifiers': 'CAD$24.00'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:49:43+00:00',
#    'updated_date': '2021-03-25T15:39:12+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb60321b9d86a39467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:56:29+00:00',
#      'updated_at': '2021-01-26T23:56:29+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p34_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c67be5849b9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '35',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Hot Cocoa Bomb Set of four',
#    'short_description': '<p>The Stubbe Cocoa Bomb Set is a fun way to enjoy your hot chocolate with your family. The package comes with four hot cocoa bombs, two milk and two dark, and makes a great gift. Place your Bomb into a cup and pour hot milk over it. Watch the marshmallows and cocoa explode into a delicious chocolatey drink.</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': None,
#    'site_link': 'product/hot-cocoa-bomb-set-of-four/35',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto cocoa bomb set of four hot cocoa bombs, two milk and two dark.',
#    'seo_page_title': 'Stubbe Chocolates Toronto Cocoa Bombs',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 68,
#     'lowest': 68,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 20.5,
#     'high_with_modifiers': 20.5,
#     'high_formatted': 'CAD$20.50',
#     'high_formatted_with_modifiers': 'CAD$20.50',
#     'low': 20.5,
#     'low_with_modifiers': 20.5,
#     'low_formatted': 'CAD$20.50',
#     'low_formatted_with_modifiers': 'CAD$20.50',
#     'regular_high': 20.5,
#     'regular_high_with_modifiers': 20.5,
#     'regular_high_formatted': 'CAD$20.50',
#     'regular_high_formatted_with_modifiers': 'CAD$20.50',
#     'regular_low': 20.5,
#     'regular_low_with_modifiers': 20.5,
#     'regular_low_formatted': 'CAD$20.50',
#     'regular_low_formatted_with_modifiers': 'CAD$20.50'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:50:58+00:00',
#    'updated_date': '2021-03-28T18:47:08+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb7e7c5707648bb276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '3',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=640',
#       '960': '/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg'},
#      'width': 960,
#      'height': 1280,
#      'format': 'jpeg',
#      'created_at': '2021-03-06T13:03:26+00:00',
#      'updated_at': '2021-03-06T13:03:26+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg?width=640',
#       '960': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p35_i3_w960.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c6b8395e2e9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '36',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Almond Bark',
#    'short_description': '<p>Sheets of milk or dark chocolate with roasted almonds inside. </p><p>*Choose dark chocolate for a vegan option</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '2',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 2,
#    'site_link': 'product/almond-bark/36',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto almond bark, sheets of chocolate with roasted almonds inside. ',
#    'seo_page_title': 'Stubbe Chocolates Toronto Almond Bark',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 23,
#     'lowest': 9,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 20.5,
#     'high_with_modifiers': 20.5,
#     'high_formatted': 'CAD$20.50',
#     'high_formatted_with_modifiers': 'CAD$20.50',
#     'low': 20.5,
#     'low_with_modifiers': 20.5,
#     'low_formatted': 'CAD$20.50',
#     'low_formatted_with_modifiers': 'CAD$20.50',
#     'regular_high': 20.5,
#     'regular_high_with_modifiers': 20.5,
#     'regular_high_formatted': 'CAD$20.50',
#     'regular_high_formatted_with_modifiers': 'CAD$20.50',
#     'regular_low': 20.5,
#     'regular_low_with_modifiers': 20.5,
#     'regular_low_formatted': 'CAD$20.50',
#     'regular_low_formatted_with_modifiers': 'CAD$20.50'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:52:39+00:00',
#    'updated_date': '2021-03-26T20:28:43+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb60321b91efb09467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:56:29+00:00',
#      'updated_at': '2021-01-26T23:56:29+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p36_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c74b3d035d9467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '38',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Tool Set',
#    'short_description': '<p>Five piece tool set in milk and dark chocolate with white chocolate details.</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': None,
#    'site_link': 'product/tool-set/38',
#    'permalink': None,
#    'seo_page_description': None,
#    'seo_page_title': None,
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 4,
#     'lowest': 4,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 17.5,
#     'high_with_modifiers': 17.5,
#     'high_formatted': 'CAD$17.50',
#     'high_formatted_with_modifiers': 'CAD$17.50',
#     'low': 17.5,
#     'low_with_modifiers': 17.5,
#     'low_formatted': 'CAD$17.50',
#     'low_formatted_with_modifiers': 'CAD$17.50',
#     'regular_high': 17.5,
#     'regular_high_with_modifiers': 17.5,
#     'regular_high_formatted': 'CAD$17.50',
#     'regular_high_formatted_with_modifiers': 'CAD$17.50',
#     'regular_low': 17.5,
#     'regular_low_with_modifiers': 17.5,
#     'regular_low_formatted': 'CAD$17.50',
#     'regular_low_formatted_with_modifiers': 'CAD$17.50'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T19:56:46+00:00',
#    'updated_date': '2021-03-26T11:20:52+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d85a5b7289467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '2',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:39+00:00',
#      'updated_at': '2021-01-26T23:23:39+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p38_i2_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c7cafd53229467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '39',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Marzipan Fruit',
#    'short_description': '<p>Marzipan sculpted into six different fruit shapes. *This is a vegan product.</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 3,
#    'site_link': 'product/marzipan-fruit/39',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto fruit shaped marzipan, six piece box.',
#    'seo_page_title': 'Stubbe Chocolates Toronto Marzipan Fruit',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 43,
#     'lowest': 43,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 14.75,
#     'high_with_modifiers': 14.75,
#     'high_formatted': 'CAD$14.75',
#     'high_formatted_with_modifiers': 'CAD$14.75',
#     'low': 14.75,
#     'low_with_modifiers': 14.75,
#     'low_formatted': 'CAD$14.75',
#     'low_formatted_with_modifiers': 'CAD$14.75',
#     'regular_high': 14.75,
#     'regular_high_with_modifiers': 14.75,
#     'regular_high_formatted': 'CAD$14.75',
#     'regular_high_formatted_with_modifiers': 'CAD$14.75',
#     'regular_low': 14.75,
#     'regular_low_with_modifiers': 14.75,
#     'regular_low_formatted': 'CAD$14.75',
#     'regular_low_formatted_with_modifiers': 'CAD$14.75'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T20:00:20+00:00',
#    'updated_date': '2021-03-28T23:50:36+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb7adb8c0383afb276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-03-01T22:14:53+00:00',
#      'updated_at': '2021-03-01T22:14:53+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p39_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59c7e9f45f349467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '40',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Mozart Kugel',
#    'short_description': '<p>A rich Austrian speciality, hazelnut nougat centre wrapped in marzipan with pistachios, soaked in Kirsch brandy and dipped in dark chocolate. Decorated with gold flakes and packaged in a box of five pieces.</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 3,
#    'site_link': 'product/mozart-kugel/40',
#    'permalink': None,
#    'seo_page_description': 'Stubbe Chocolates Toronto hazelnut nougat centre wrapped in marzipan with pistachios, soaked in Kirsch brandy and dipped in dark chocolate. ',
#    'seo_page_title': 'Stubbe Chocolates Toronto Mozart Kugel',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 1,
#     'lowest': 1,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 14.75,
#     'high_with_modifiers': 14.75,
#     'high_formatted': 'CAD$14.75',
#     'high_formatted_with_modifiers': 'CAD$14.75',
#     'low': 14.75,
#     'low_with_modifiers': 14.75,
#     'low_formatted': 'CAD$14.75',
#     'low_formatted_with_modifiers': 'CAD$14.75',
#     'regular_high': 14.75,
#     'regular_high_with_modifiers': 14.75,
#     'regular_high_formatted': 'CAD$14.75',
#     'regular_high_formatted_with_modifiers': 'CAD$14.75',
#     'regular_low': 14.75,
#     'regular_low_with_modifiers': 14.75,
#     'regular_low_formatted': 'CAD$14.75',
#     'regular_low_formatted_with_modifiers': 'CAD$14.75'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T20:01:12+00:00',
#    'updated_date': '2021-03-28T15:56:33+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb7aea7bb155a3b276ac1f6bbba828',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '1',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-03-02T00:01:48+00:00',
#      'updated_at': '2021-03-02T00:01:48+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p40_i1_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59ca903f45129467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '42',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Six in the Six',
#    'short_description': '<p>Six assorted truffles in a clear box. </p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 3,
#    'site_link': 'product/six-in-the-six/42',
#    'permalink': None,
#    'seo_page_description': None,
#    'seo_page_title': 'Stubbe Chocolates Toronto Six Truffles',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 99,
#     'lowest': 99,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 14.5,
#     'high_with_modifiers': 14.5,
#     'high_formatted': 'CAD$14.50',
#     'high_formatted_with_modifiers': 'CAD$14.50',
#     'low': 14.5,
#     'low_with_modifiers': 14.5,
#     'low_formatted': 'CAD$14.50',
#     'low_formatted_with_modifiers': 'CAD$14.50',
#     'regular_high': 14.5,
#     'regular_high_with_modifiers': 14.5,
#     'regular_high_formatted': 'CAD$14.50',
#     'regular_high_formatted_with_modifiers': 'CAD$14.50',
#     'regular_low': 14.5,
#     'regular_low_with_modifiers': 14.5,
#     'regular_low_formatted': 'CAD$14.50',
#     'regular_low_formatted_with_modifiers': 'CAD$14.50'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T20:20:10+00:00',
#    'updated_date': '2021-03-28T08:53:47+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d85a524529467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '2',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:39+00:00',
#      'updated_at': '2021-01-26T23:23:39+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p42_i2_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}},
#   {'id': '11eb59cbaa07e3009467ac1f6bbbcc9c',
#    'owner_id': '135718637',
#    'site_id': '228142249342516758',
#    'site_product_id': '44',
#    'visibility': 'visible',
#    'visibility_tl': 'Visible',
#    'visibility_locked': False,
#    'name': 'Maltitol dark chocolate Hearts',
#    'short_description': '<p>Maltitol dark chocolate box of 18 solid hearts. Maltitol is a sugar alcohol and used as a sugar substitute. It is a type of carbohydrate that is neither sugar nor alcohol. Sugar alcohols are found naturally in some fruits and vegetables. *this is a vegan product</p><p><br /></p><p><em>Availability: Same day pick-up or next day delivery if ordered before 3pm</em></p>',
#    'variation_type': '3',
#    'product_type': 'physical',
#    'product_type_details': [],
#    'taxable': True,
#    'required_feature_to_sell': None,
#    'min_prep_time': 120,
#    'site_shipping_box_id': 3,
#    'site_link': 'product/maltitol-dark-chocolate-hearts/44',
#    'permalink': None,
#    'seo_page_description': None,
#    'seo_page_title': 'Stubbe Chocolates Maltitol dark chocolate Hearts',
#    'avg_rating': None,
#    'avg_rating_all': None,
#    'inventory': {'total': 43,
#     'lowest': 43,
#     'enabled': True,
#     'marked_sold_out_at_all_existing_locations': False,
#     'marked_sold_out_skus_count': 0,
#     'has_location_not_tracking': False},
#    'measurement_unit_abbreviation': None,
#    'price': {'high': 14.25,
#     'high_with_modifiers': 14.25,
#     'high_formatted': 'CAD$14.25',
#     'high_formatted_with_modifiers': 'CAD$14.25',
#     'low': 14.25,
#     'low_with_modifiers': 14.25,
#     'low_formatted': 'CAD$14.25',
#     'low_formatted_with_modifiers': 'CAD$14.25',
#     'regular_high': 14.25,
#     'regular_high_with_modifiers': 14.25,
#     'regular_high_formatted': 'CAD$14.25',
#     'regular_high_formatted_with_modifiers': 'CAD$14.25',
#     'regular_low': 14.25,
#     'regular_low_with_modifiers': 14.25,
#     'regular_low_formatted': 'CAD$14.25',
#     'regular_low_formatted_with_modifiers': 'CAD$14.25'},
#    'is_alcoholic': False,
#    'created_date': '2021-01-18T20:28:03+00:00',
#    'updated_date': '2021-03-25T15:39:12+00:00',
#    'badges': {'low_stock': False, 'out_of_stock': False, 'on_sale': False},
#    'seo_product_image_id': None,
#    'og_title': None,
#    'og_description': None,
#    'thumbnail': {'data': {'id': '11eb602d85acec8b9467ac1f6bbbcc9c',
#      'owner_id': '135718637',
#      'site_id': '228142249342516758',
#      'site_product_image_id': '2',
#      'url': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg',
#      'absolute_url': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg',
#      'urls': {'80': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=80',
#       '160': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=160',
#       '320': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=320',
#       '640': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=640',
#       '940': '/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg'},
#      'width': 940,
#      'height': 940,
#      'format': 'jpeg',
#      'created_at': '2021-01-26T23:23:39+00:00',
#      'updated_at': '2021-01-26T23:23:39+00:00',
#      'absolute_urls': {'80': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=80',
#       '160': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=160',
#       '320': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=320',
#       '640': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg?width=640',
#       '940': 'https://www.stubbechocolates.com/uploads/1/3/5/7/135718637/s228142249342516758_p44_i2_w940.jpeg'}}},
#    'placeholder_image': {'data': {'placeholder': True,
#      'url': '/images/commerce/store-app/app/universal_product_placeholder.png',
#      'absolute_url': 'cdn3.editmysite.com/images/commerce/store-app/app/universal_product_placeholder.png'}}}],
#  'meta': {'pagination': {'total': 157,
#    'count': 15,
#    'per_page': 15,
#    'current_page': 2,
#    'total_pages': 11,
#    'links': {'previous': 'https://www.weebly.com/app/store/api/v13/editor/users/135718637/sites/228142249342516758/products?page=1',
#     'next': 'https://www.weebly.com/app/store/api/v13/editor/users/135718637/sites/228142249342516758/products?page=3'}}}}

# %%
pd.json_normalize(resp2.json()['data'])[['name', 'short_description', 'price.low']]
# Out:
#                                    name  \
# 0                          Mozart Torte
# 1                         The Davenport
# 2                            Anna Torte
# 3             Afternoon Relaxer for Two
# 4                          Cocoa Powder
# 5                             Party Mix
# 6                Gateau Voyage Hazelnut
# 7   Maltitol Dark Chocolate Almond Bark
# 8            Hot Cocoa Bomb Set of four
# 9                           Almond Bark
# 10                             Tool Set
# 11                       Marzipan Fruit
# 12                         Mozart Kugel
# 13                       Six in the Six
# 14       Maltitol dark chocolate Hearts
#
#                                     short_description  price.low
# 0   <p>Flourless almond cake with a layer of raspb...      42.00
# 1   <p>Gluten-free rice flour chocolate cake with ...      42.00
# 2   <p>Chocolate sponge cake with layers of orange...      40.00
# 3   <p>This gift set is perfect for an afternoon t...      34.00
# 4   100% cocoa powder in a 1kg bag. This is a vega...      32.00
# 5   <p>Perfect for sharing, a cylinder with layers...      29.75
# 6   <p>Our Hazelnut "Travel cake" is dense, moist ...      28.50
# 7   <p>Roasted Almonds in dark Maltitol chocolate ...      24.00
# 8   <p>The Stubbe Cocoa Bomb Set is a fun way to e...      20.50
# 9   <p>Sheets of milk or dark chocolate with roast...      20.50
# 10  <p>Five piece tool set in milk and dark chocol...      17.50
# 11  <p>Marzipan sculpted into six different fruit ...      14.75
# 12  <p>A rich Austrian speciality, hazelnut nougat...      14.75
# 13  <p>Six assorted truffles in a clear box. </p><...      14.50
# 14  <p>Maltitol dark chocolate box of 18 solid hea...      14.25

# %%
table = pd.DataFrame()

# %%
# Hemos comprobado que hay 11 páginas. Iteramos a través de ellas y vamos añadiendo el contenido a un DataFrame

for a in range(1,12):
    resp2 = requests.get(url2, {'page':a})
    new = pd.json_normalize(resp2.json()['data'])[['name', 'short_description', 'price.low', 'price.low_formatted']]
    table = table.append(new)

# %%
# Reseteamos el índice

table = table.reset_index().drop(columns = 'index')

# %%
table
# Out:
#                         name  \
# 0                   Verliebt
# 1                  Verspielt
# 2              Truffle Torte
# 3               Sacher Torte
# 4           Heart Chocolates
# ..                       ...
# 152        Wild Bunnies card
# 153        Tulip Garden card
# 154      Strawberry Love Bar
# 155            Yuzu Love Bar
# 156  Easter Bonbon Selection
#
#                                      short_description  price.low  \
# 0    <p>Verliebt, Daniel Stubbe's signature dark ch...       9.00
# 1    <p>Verspielt, Daniel Stubbe's signature milk c...       9.00
# 2    <p>Chocolate cake with layers of dark chocolat...      40.00
# 3    <p>A Viennese chocolate torte with either the ...      40.00
# 4    <p>These little bite-sized heart shaped chocol...      11.75
# ..                                                 ...        ...
# 152  <p>Local artist, Susan Rosen, creates wonderfu...       6.00
# 153  <p>Local artist, Susan Rosen, creates wonderfu...       6.00
# 154  <p>Strawberry puree and cocoa butter. This is ...       8.50
# 155  <p>Yuzu puree with cocoa butter. This is a veg...       8.50
# 156  <p>Four colourful bonbons created by Chef Stub...      12.50
#
#     price.low_formatted
# 0              CAD$9.00
# 1              CAD$9.00
# 2             CAD$40.00
# 3             CAD$40.00
# 4             CAD$11.75
# ..                  ...
# 152            CAD$6.00
# 153            CAD$6.00
# 154            CAD$8.50
# 155            CAD$8.50
# 156           CAD$12.50
#
# [157 rows x 4 columns]

# %%
table.sort_values('price.low', ascending=False)
# Out:
#                                                name  \
# 101                                 Happy as a Duck
# 5                           Chocolate Adventure Box
# 100                              Giant Easter Bunny
# 150                                  Giant Nest Egg
# 139  Stubbe Classic Forty-Eight Piece Chocolate Box
# ..                                              ...
# 65                    Chocolate Dipped Orange Slice
# 113                              Easter Bunny lolly
# 91                                      Heart lolly
# 105                                      Star lolly
# 86                                   Sprinkle Lolly
#
#                                      short_description  price.low  \
# 101  <p>A large hollow duck (approximately 35cm tal...     195.00
# 5    <p>This gift box includes a large variety of d...     160.70
# 100  <p>This 64cm hollow chocolate bunny is a great...     145.00
# 150  <p>This 35cm hollow chocolate egg makes a grea...     125.50
# 139  <p>The forty-eight piece Stubbe Blue box is fi...     114.50
# ..                                                 ...        ...
# 65   <p>Candied orange slice half dipped in dark ch...       3.75
# 113  <p>Festive Easter bunny shaped lollies.</p><p>...       3.75
# 91   <p><em>Availability: Same day pick-up or next ...       3.50
# 105  <p>Chocolate lolly in the shape of a star with...       3.00
# 86   <p>Chocolate lolly covered in colourful candy ...       3.00
#
#     price.low_formatted
# 101          CAD$195.00
# 5            CAD$160.70
# 100          CAD$145.00
# 150          CAD$125.50
# 139          CAD$114.50
# ..                  ...
# 65             CAD$3.75
# 113            CAD$3.75
# 91             CAD$3.50
# 105            CAD$3.00
# 86             CAD$3.00
#
# [157 rows x 4 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
# n/a

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
# n/a

# %% [markdown]
# #### Display the brands without discount at all

# %%
# n/a

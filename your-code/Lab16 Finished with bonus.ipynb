# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %% [markdown]
# 1. Import libraries.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# 2. Define the initial API endpoint URL.

# %%
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=0&sort=popularity"

# %% [markdown]
# 3. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"}

# %%
response = requests.get(url, headers = headers) 
results = response.json()
results
# Out:
# {'total_count': 51330,
#  'pagination': {'page_count': 612, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'TI112C04A-702',
#    'name': '6 INCH PREMIUM - Bottes de neige - wheat',
#    'price': {'original': '219,95\xa0€',
#     'promotional': '175,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40',
#     '41',
#     '41.5',
#     '42',
#     '43',
#     '43.5',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47.5',
#     '49',
#     '50'],
#    'url_key': 'timberland-6-inch-premium-boots-a-lacets-marron-ti112c04a-702',
#    'media': [{'path': 'TI/11/2C/04/A7/02/TI112C04A-702@19.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'TI/11/2C/04/A7/02/TI112C04A-702@24.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Timberland',
#    'is_premium': False,
#    'family_articles': [{'sku': 'TI112C04A-702',
#      'url_key': 'timberland-6-inch-premium-boots-a-lacets-marron-ti112c04a-702',
#      'media': [{'path': 'TI/11/2C/04/A7/02/TI112C04A-702@19.2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': '6 INCH PREMIUM - Bottes de neige - wheat',
#      'sizes': ['40',
#       '41',
#       '41.5',
#       '42',
#       '43',
#       '43.5',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47.5',
#       '49',
#       '50'],
#      'price': {'original': '219,95\xa0€',
#       'promotional': '175,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032533:TI112C04A-702&c=30032533&a=30032539&s=TI112C04A-702&is=1689&at=browser&cm=180000&ovm=725&r=0.004041684325784445&ts=0&cs=2384995084'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032533:TI112C04A-702&c=30032533&a=30032539&s=TI112C04A-702&is=1689&at=browser&cm=180000&ovm=725&r=0.004041684325784445&ts=0&cs=2384995084',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GA322S02Y-A11',
#    'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - eggshell',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '89,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'gant-medium-shield-hoodie-sweatshirt-ga322s02y-a11',
#    'media': [{'path': 'GA/32/2S/02/YA/11/GA322S02Y-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'GA/32/2S/02/YA/11/GA322S02Y-A11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'GANT',
#    'is_premium': False,
#    'family_articles': [{'sku': 'GA322S02Y-A11',
#      'url_key': 'gant-medium-shield-hoodie-sweatshirt-ga322s02y-a11',
#      'media': [{'path': 'GA/32/2S/02/YA/11/GA322S02Y-A11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - eggshell',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'GA322S02Y-Q11',
#      'url_key': 'gant-medium-shield-hoodie-sweatshirt-ga322s02y-q11',
#      'media': [{'path': 'GA/32/2S/02/YQ/11/GA322S02Y-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'GA322S02Y-M11',
#      'url_key': 'gant-medium-shield-hoodie-sweatshirt-ga322s02y-m11',
#      'media': [{'path': 'GA/32/2S/02/YM/11/GA322S02Y-M11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - field green',
#      'sizes': ['XS', 'S', 'M'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'GA322S02Y-C11',
#      'url_key': 'gant-medium-shield-hoodie-sweatshirt-light-grey-melange-ga322s02y-c11',
#      'media': [{'path': 'GA/32/2S/02/YC/11/GA322S02Y-C11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - light grey melange',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '99,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'GA322S02Y-K11',
#      'url_key': 'gant-medium-shield-hoodie-sweatshirt-ga322s02y-k11',
#      'media': [{'path': 'GA/32/2S/02/YK/11/GA322S02Y-K11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MEDIUM SHIELD HOODIE - Sweat à capuche - evening blue',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032753:GA322S02Y-A11&c=30032753&a=30032754&s=GA322S02Y-A11&is=1689&at=browser&cm=170000&ovm=718&r=0.0042680054903030396&ts=0&cs=3423073739'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032753:GA322S02Y-A11&c=30032753&a=30032754&s=GA322S02Y-A11&is=1689&at=browser&cm=170000&ovm=718&r=0.0042680054903030396&ts=0&cs=3423073739',
#     'source': 'ccp'},
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': '1MI52F01P-O11',
#    'name': 'TALL CARD CASE - Étui pour cartes de visite - brown',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'michael-kors-tall-card-case-etui-pour-cartes-de-visite-brown-1mi52f01p-o11',
#    'media': [{'path': '1M/I5/2F/01/PO/11/1MI52F01P-O11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Michael Kors',
#    'is_premium': False,
#    'family_articles': [{'sku': '1MI52F01P-O11',
#      'url_key': 'michael-kors-tall-card-case-etui-pour-cartes-de-visite-brown-1mi52f01p-o11',
#      'media': [{'path': '1M/I5/2F/01/PO/11/1MI52F01P-O11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TALL CARD CASE - Étui pour cartes de visite - brown',
#      'sizes': ['One Size'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '23,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032871:1MI52F01P-O11&c=30032871&a=30032874&s=1MI52F01P-O11&is=1689&at=browser&cm=91950&ovm=706&r=0.007810869254171848&ts=0&cs=3056159942'],
#     'impression_beacon': 'https://ccp-et.metrigo.zalan.do/event/sbv?z=c6d03e9b-c7b4-4b28-a7d1-266ba0d8f361&b=bf5b74ab-1655-465f-bc08-9fe1eb2ceb7b:30032871:1MI52F01P-O11&c=30032871&a=30032874&s=1MI52F01P-O11&is=1689&at=browser&cm=91950&ovm=706&r=0.007810869254171848&ts=0&cs=3056159942',
#     'source': 'ccp'},
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'AD115B01K-A12',
#    'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - running white/green',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '85,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '50',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3',
#     '50 2/3',
#     '51 1/3',
#     '52 2/3',
#     '53 1/3',
#     '54 2/3',
#     '55 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-a12',
#    'media': [{'path': 'AD/11/5B/01/KA/12/AD115B01K-A12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [{'sku': 'AD115B01K-A12',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-a12',
#      'media': [{'path': 'AD/11/5B/01/KA/12/AD115B01K-A12@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - running white/green',
#      'sizes': ['36',
#       '38',
#       '40',
#       '42',
#       '44',
#       '46',
#       '48',
#       '50',
#       '36 2/3',
#       '37 1/3',
#       '38 2/3',
#       '39 1/3',
#       '40 2/3',
#       '41 1/3',
#       '42 2/3',
#       '43 1/3',
#       '44 2/3',
#       '45 1/3',
#       '46 2/3',
#       '47 1/3',
#       '48 2/3',
#       '49 1/3',
#       '50 2/3',
#       '51 1/3',
#       '52 2/3',
#       '53 1/3',
#       '54 2/3',
#       '55 2/3'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '85,45\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'AD115B01K-A13',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-a13',
#      'media': [{'path': 'AD/11/5B/01/KA/13/AD115B01K-A13@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - running white/collegiate red',
#      'sizes': ['50 2/3', '51 1/3', '52 2/3', '53 1/3', '54 2/3', '55 2/3'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '75,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'AD115B01K-A11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-blanc-ad115b01k-a11',
#      'media': [{'path': 'AD/11/5B/01/KA/11/AD115B01K-A11@18.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - run white/new navy',
#      'sizes': ['36',
#       '38',
#       '40',
#       '42',
#       '44',
#       '46',
#       '48',
#       '36 2/3',
#       '37 1/3',
#       '38 2/3',
#       '39 1/3',
#       '40 2/3',
#       '41 1/3',
#       '42 2/3',
#       '43 1/3',
#       '44 2/3',
#       '45 1/3',
#       '46 2/3',
#       '47 1/3',
#       '48 2/3',
#       '49 1/3',
#       '50 2/3',
#       '51 1/3',
#       '52 2/3',
#       '53 1/3',
#       '54 2/3',
#       '55 2/3'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '94,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'AD115B01K-Q11',
#      'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-q11',
#      'media': [{'path': 'AD/11/5B/01/KQ/11/AD115B01K-Q11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'STAN SMITH STREETWEAR-STYLE SHOES - Baskets basses - core black',
#      'sizes': ['36',
#       '38',
#       '40',
#       '42',
#       '44',
#       '46',
#       '48',
#       '50',
#       '36 2/3',
#       '37 1/3',
#       '38 2/3',
#       '39 1/3',
#       '40 2/3',
#       '41 1/3',
#       '42 2/3',
#       '43 1/3',
#       '44 2/3',
#       '45 1/3',
#       '46 2/3',
#       '47 1/3',
#       '48 2/3',
#       '49 1/3',
#       '50 2/3',
#       '51 1/3',
#       '52 2/3',
#       '53 1/3',
#       '54 2/3',
#       '55 2/3'],
#      'price': {'original': '94,95\xa0€',
#       'promotional': '94,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1242E0W3-N12',
#    'name': 'PANT TAPER - Pantalon de survêtement - cargo khaki/black',
#    'price': {'original': '42,95\xa0€',
#     'promotional': '36,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'L', 'XL'],
#    'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-n12',
#    'media': [{'path': 'N1/24/2E/0W/3N/12/N1242E0W3-N12@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2E/0W/3N/12/N1242E0W3-N12@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242E0W3-N12',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-n12',
#      'media': [{'path': 'N1/24/2E/0W/3N/12/N1242E0W3-N12@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - cargo khaki/black',
#      'sizes': ['S', 'L', 'XL'],
#      'price': {'original': '42,95\xa0€',
#       'promotional': '36,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E0W3-C11',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-c11',
#      'media': [{'path': 'N1/24/2E/0W/3C/11/N1242E0W3-C11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - dark grey heather/black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '40,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E0W3-Q11',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-q11',
#      'media': [{'path': 'N1/24/2E/0W/3Q/11/N1242E0W3-Q11@22.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - black/mtlc hematite',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '44,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1242E13Q-C11',
#    'name': 'Pantalon de survêtement - grey heather/black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-grey-heatherblack-n1242e13q-c11',
#    'media': [{'path': 'N1/24/2E/13/QC/11/N1242E13Q-C11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2E/13/QC/11/N1242E13Q-C11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242E13Q-C11',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-grey-heatherblack-n1242e13q-c11',
#      'media': [{'path': 'N1/24/2E/13/QC/11/N1242E13Q-C11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - grey heather/black',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '31,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E13Q-C12',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-n1242e13q-c12',
#      'media': [{'path': 'N1/24/2E/13/QC/12/N1242E13Q-C12@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - charcoal heather/black',
#      'sizes': ['S', 'XL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '39,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1242E13Q-Q12',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-n1242e13q-q12',
#      'media': [{'path': 'N1/24/2E/13/QQ/12/N1242E13Q-Q12@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - black/white',
#      'sizes': ['L', 'XL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '39,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1242E13Q-Q11',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-n1242e13q-q11',
#      'media': [{'path': 'N1/24/2E/13/QQ/11/N1242E13Q-Q11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - black/sequoia/electric green/habanero red',
#      'sizes': ['M'],
#      'price': {'original': '37,95\xa0€',
#       'promotional': '30,35\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E13Q-N11',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-n1242e13q-n11',
#      'media': [{'path': 'N1/24/2E/13/QN/11/N1242E13Q-N11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - cargo khaki/black',
#      'sizes': ['S', 'M', 'L', 'XL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '33,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E13Q-K11',
#      'url_key': 'nike-performance-dry-pant-taper-pantalon-de-survetement-n1242e13q-k11',
#      'media': [{'path': 'N1/24/2E/13/QK/11/N1242E13Q-K11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Pantalon de survêtement - game royal/black/habanero red/electric green',
#      'sizes': ['XXL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '23,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI122E01J-Q11',
#    'name': 'TECH - Pantalon de survêtement - black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '80,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-sportswear-pantalon-de-survetement-black-ni122e01j-q11',
#    'media': [{'path': 'NI/12/2E/01/JQ/11/NI122E01J-Q11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/2E/01/JQ/11/NI122E01J-Q11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI122E01J-Q11',
#      'url_key': 'nike-sportswear-pantalon-de-survetement-black-ni122e01j-q11',
#      'media': [{'path': 'NI/12/2E/01/JQ/11/NI122E01J-Q11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '80,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-10%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-J12',
#      'url_key': 'nike-sportswear-tech-pantalon-de-survetement-ni122e01j-j12',
#      'media': [{'path': 'NI/12/2E/01/JJ/12/NI122E01J-J12@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - light pink',
#      'sizes': ['XL', 'XXL', '3XL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-C13',
#      'url_key': 'nike-sportswear-tech-pantalon-de-survetement-ni122e01j-c13',
#      'media': [{'path': 'NI/12/2E/01/JC/13/NI122E01J-C13@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - smoke grey/pure platinum',
#      'sizes': ['XL', 'XXL', '3XL', '4XL'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-K17',
#      'url_key': 'nike-sportswear-tech-pantalon-de-survetement-ni122e01j-k17',
#      'media': [{'path': 'NI/12/2E/01/JK/17/NI122E01J-K17@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - royal blue',
#      'sizes': ['XXL', '3XL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-M18',
#      'url_key': 'nike-sportswear-tech-pantalon-de-survetement-ni122e01j-m18',
#      'media': [{'path': 'NI/12/2E/01/JM/18/NI122E01J-M18@24.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'TECH - Pantalon de survêtement - green/dark grey/black',
#      'sizes': ['S', 'M', 'L', 'XXL'],
#      'price': {'original': '90,00\xa0€',
#       'promotional': '90,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-C11',
#      'url_key': 'nike-sportswear-tech-fleece-pantalon-de-survetement-ni122e01j-c11',
#      'media': [{'path': 'NI/12/2E/01/JC/11/NI122E01J-C11@17.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - grey',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-C14',
#      'url_key': 'nike-sportswear-tech-pantalon-de-survetement-ni122e01j-c14',
#      'media': [{'path': 'NI/12/2E/01/JC/14/NI122E01J-C14@26.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'TECH - Pantalon de survêtement - grey/black',
#      'sizes': ['L'],
#      'price': {'original': '90,00\xa0€',
#       'promotional': '90,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-G14',
#      'url_key': 'nike-sportswear-tech-jogger-pantalon-de-survetement-ni122e01j-g14',
#      'media': [{'path': 'NI/12/2E/01/JG/14/NI122E01J-G14@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - team red/black',
#      'sizes': ['XL'],
#      'price': {'original': '90,00\xa0€',
#       'promotional': '90,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-G13',
#      'url_key': 'nike-sportswear-tech-jogger-pantalon-de-survetement-ni122e01j-g13',
#      'media': [{'path': 'NI/12/2E/01/JG/13/NI122E01J-G13@8.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - night maroon',
#      'sizes': ['XXL', '3XL'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'NI122E01J-K15',
#      'url_key': 'nike-sportswear-tech-jogger-pantalon-de-survetement-ni122e01j-k15',
#      'media': [{'path': 'NI/12/2E/01/JK/15/NI122E01J-K15@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TECH - Pantalon de survêtement - dark blue, white',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL', '4XL'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '89,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': 'PRIX MINI',
#        'tracking_value': 'fr_prixmini_old_season_2019_28'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1242E13V-N11',
#    'name': 'RUN STRIPE PANT - Pantalon de survêtement - sequoia/reflective silver',
#    'price': {'original': '37,95\xa0€',
#     'promotional': '32,25\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['L', 'XL', 'XXL'],
#    'url_key': 'nike-performance-run-stripe-pant-pantalon-de-survetement-n1242e13v-n11',
#    'media': [{'path': 'N1/24/2E/13/VN/11/N1242E13V-N11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2E/13/VN/11/N1242E13V-N11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242E13V-N11',
#      'url_key': 'nike-performance-run-stripe-pant-pantalon-de-survetement-n1242e13v-n11',
#      'media': [{'path': 'N1/24/2E/13/VN/11/N1242E13V-N11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RUN STRIPE PANT - Pantalon de survêtement - sequoia/reflective silver',
#      'sizes': ['L', 'XL', 'XXL'],
#      'price': {'original': '37,95\xa0€',
#       'promotional': '32,25\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E13V-Q11',
#      'url_key': 'nike-performance-run-stripe-pant-pantalon-de-survetement-n1242e13v-q11',
#      'media': [{'path': 'N1/24/2E/13/VQ/11/N1242E13V-Q11@11.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'RUN STRIPE PANT - Pantalon de survêtement - black/silver',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '39,95\xa0€',
#       'promotional': '39,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'C1422E00D-N14',
#    'name': 'MADISON JOGGER TRABUCO - Pantalon classique - moor rinsed',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'carhartt-wip-madison-trabuco-pantalon-classique-c1422e00d-n14',
#    'media': [{'path': 'C1/42/2E/00/DN/14/C1422E00D-N14@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'C1/42/2E/00/DN/14/C1422E00D-N14@5.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Carhartt WIP',
#    'is_premium': False,
#    'family_articles': [{'sku': 'C1422E00D-N14',
#      'url_key': 'carhartt-wip-madison-trabuco-pantalon-classique-c1422e00d-n14',
#      'media': [{'path': 'C1/42/2E/00/DN/14/C1422E00D-N14@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MADISON JOGGER TRABUCO - Pantalon classique - moor rinsed',
#      'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'C1422E00D-Q11',
#      'url_key': 'carhartt-madison-pantalon-classique-c1422e00d-q11',
#      'media': [{'path': 'C1/42/2E/00/DQ/11/C1422E00D-Q11@14.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'MADISON JOGGER TRABUCO - Pantalon classique - black rinsed',
#      'sizes': ['L', 'XL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'},
#       {'key': 'specialOffer',
#        'value': 'Exclusivité',
#        'tracking_value': 'special offer'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1242E0W3-C11',
#    'name': 'PANT TAPER - Pantalon de survêtement - dark grey heather/black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '40,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-c11',
#    'media': [{'path': 'N1/24/2E/0W/3C/11/N1242E0W3-C11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2E/0W/3C/11/N1242E0W3-C11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242E0W3-C11',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-c11',
#      'media': [{'path': 'N1/24/2E/0W/3C/11/N1242E0W3-C11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - dark grey heather/black',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '40,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -10%',
#        'tracking_value': 'discount rate'},
#       {'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E0W3-N12',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-n12',
#      'media': [{'path': 'N1/24/2E/0W/3N/12/N1242E0W3-N12@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - cargo khaki/black',
#      'sizes': ['S', 'L', 'XL'],
#      'price': {'original': '42,95\xa0€',
#       'promotional': '36,45\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -15%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E0W3-Q11',
#      'url_key': 'nike-performance-pant-taper-pantalon-de-survetement-n1242e0w3-q11',
#      'media': [{'path': 'N1/24/2E/0W/3Q/11/N1242E0W3-Q11@22.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'PANT TAPER - Pantalon de survêtement - black/mtlc hematite',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#      'price': {'original': '44,95\xa0€',
#       'promotional': '44,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': True,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1242D2MO-C11',
#    'name': 'FC BARCELONA PANT  - Article de supporter - smoke grey/cabana',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '54,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-performance-fc-barcelona-pant-pantalon-de-survetement-smoke-greycabana-n1242d2mo-c11',
#    'media': [{'path': 'N1/24/2D/2M/OC/11/N1242D2MO-C11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2D/2M/OC/11/N1242D2MO-C11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242D2MO-C11',
#      'url_key': 'nike-performance-fc-barcelona-pant-pantalon-de-survetement-smoke-greycabana-n1242d2mo-c11',
#      'media': [{'path': 'N1/24/2D/2M/OC/11/N1242D2MO-C11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'FC BARCELONA PANT  - Article de supporter - smoke grey/cabana',
#      'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#      'price': {'original': '99,95\xa0€',
#       'promotional': '54,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -45%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1242A1UC-Q11',
#    'name': "FLEXMETHOD TR - Chaussures d'entraînement et de fitness - black/cool grey",
#    'price': {'original': '79,95\xa0€',
#     'promotional': '63,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['39', '40.5', '41', '42', '43', '44', '45.5', '48.5'],
#    'url_key': 'nike-performance-flexmethod-trainer-chaussures-dentrainement-et-de-fitness-blackcool-grey-n1242a1uc-q11',
#    'media': [{'path': 'N1/24/2A/1U/CQ/11/N1242A1UC-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242A1UC-Q11',
#      'url_key': 'nike-performance-flexmethod-trainer-chaussures-dentrainement-et-de-fitness-blackcool-grey-n1242a1uc-q11',
#      'media': [{'path': 'N1/24/2A/1U/CQ/11/N1242A1UC-Q11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "FLEXMETHOD TR - Chaussures d'entraînement et de fitness - black/cool grey",
#      'sizes': ['39', '40.5', '41', '42', '43', '44', '45.5', '48.5'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '63,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242A1UC-K11',
#      'url_key': 'nike-performance-flexmethod-trainer-chaussures-dentrainement-et-de-fitness-n1242a1uc-k11',
#      'media': [{'path': 'N1/24/2A/1U/CK/11/N1242A1UC-K11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "FLEXMETHOD TR - Chaussures d'entraînement et de fitness - soar/total orange/black/white",
#      'sizes': ['39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5',
#       '49.5'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1242A1UC-C11',
#      'url_key': 'nike-performance-flexmethod-trainer-chaussures-dentrainement-et-de-fitness-n1242a1uc-c11',
#      'media': [{'path': 'N1/24/2A/1U/CC/11/N1242A1UC-C11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': "FLEXMETHOD TR - Chaussures d'entraînement et de fitness - dark smoke grey/black/string/pale ivory",
#      'sizes': ['39',
#       '40',
#       '40.5',
#       '41',
#       '42',
#       '42.5',
#       '43',
#       '44',
#       '44.5',
#       '45',
#       '45.5',
#       '46',
#       '47',
#       '47.5',
#       '48.5',
#       '49.5'],
#      'price': {'original': '79,95\xa0€',
#       'promotional': '79,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []}],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1242E13T-K12',
#    'name': 'FLEX PANT - Pantalon de survêtement - blackened blue/kumquat',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '47,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-performance-flex-pant-pantalon-de-survetement-n1242e13t-k12',
#    'media': [{'path': 'N1/24/2E/13/TK/12/N1242E13T-K12@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/2E/13/TK/12/N1242E13T-K12@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1242E13T-K12',
#      'url_key': 'nike-performance-flex-pant-pantalon-de-survetement-n1242e13t-k12',
#      'media': [{'path': 'N1/24/2E/13/TK/12/N1242E13T-K12@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'FLEX PANT - Pantalon de survêtement - blackened blue/kumquat',
#      'sizes': ['M', 'L', 'XL', 'XXL'],
#      'price': {'original': '59,95\xa0€',
#       'promotional': '47,95\xa0€',
#       'has_different_prices': True,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': True,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': 'Jusqu’à -20%',
#        'tracking_value': 'discount rate'}],
#      'delivery_promises': []},
#     {'sku': 'N1242E13T-M11',
#      'url_key': 'nike-performance-flex-pant-pantalon-de-survetement-n1242e13t-m11',
#      'media': [{'path': 'N1/24/2E/13/TM/11/N1242E13T-M11@39.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'FLEX PANT - Pantalon de survêtement - sequoia/black/electric green/pale ivory',
#      'sizes': ['S', 'XL'],
#      'price': {'original': '60,00\xa0€',
#       'promotional': '60,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [],
#      'delivery_promises': []},
#     {'sku': 'N1242E13T-Q11',
#      'url_key': 'nike-performance-flex-pant-pantalon-de-survetement-blacksequoiahabanero-redelectric-green-n1242e13t-q11',
#      'media': [{'path': 'N1/24/2E/13/TQ/11/N1242E13T-Q11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
# ...
#     {'key': 'VL7', 'label': 'Van Lier', 'is_family': False},
#     {'key': 'VA2', 'label': 'Vans', 'is_family': False},
#     {'key': 'VA4', 'label': 'Vaude', 'is_family': False},
#     {'key': 'VEK', 'label': 'Veganino', 'is_family': False},
#     {'key': 'VERS', 'label': 'Versace', 'is_family': True},
#     {'key': '1VE', 'label': 'Versace', 'is_family': False},
#     {'key': 'VC1',
#      'label': 'Versace Collection',
#      'family_id': 'VERS',
#      'is_family': False},
#     {'key': 'VEI',
#      'label': 'Versace Jeans Couture',
#      'family_id': 'VERS',
#      'is_family': False},
#     {'key': 'VB0', 'label': 'Vibram Fivefingers', 'is_family': False},
#     {'key': 'V14', 'label': 'Victorinox', 'is_family': False},
#     {'key': 'VIA', 'label': 'Viggo', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'V11', 'label': 'Vilebrequin', 'is_family': False},
#     {'key': 'VIO', 'label': 'Vintage Supply', 'is_family': False},
#     {'key': 'VIG', 'label': 'Vitaly', 'is_family': False},
#     {'key': 'VIVI', 'label': 'Vivienne Westwood', 'is_family': True},
#     {'key': 'VW9',
#      'label': 'Vivienne Westwood',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VW6',
#      'label': 'Vivienne Westwood Anglomania',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VB7', 'label': 'Voile Blanche', 'is_family': False},
#     {'key': 'V19', 'label': 'Volcom', 'is_family': False},
#     {'key': 'VO7', 'label': 'Volé la lumière', 'is_family': False},
#     {'key': 'V17', 'label': 'Vossen', 'is_family': False},
#     {'key': 'WY0', 'label': 'W6YZ', 'is_family': False},
#     {'key': 'W02', 'label': 'Walk London', 'is_family': False},
#     {'key': 'WEA', 'label': 'We are Cph', 'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'CLC', 'label': 'Wearcolour', 'is_family': False},
#     {'key': 'WEB', 'label': 'Weekday', 'is_family': False},
#     {'key': 'WE7', 'label': 'Weleda', 'is_family': False},
#     {'key': 'WEE', 'label': 'Wella EIMI', 'is_family': False},
#     {'key': 'WM1', 'label': 'Wemoto', 'is_family': False},
#     {'key': 'WE1', 'label': 'WeSC', 'is_family': False},
#     {'key': 'WH4', 'label': 'White Mountaineering', 'is_family': False},
#     {'key': 'WIA', 'label': 'Wild Feet', 'is_family': False},
#     {'key': 'WIC', 'label': 'Wildwuchs Bartpflege', 'is_family': False},
#     {'key': 'WO3', 'label': 'Won Hundred', 'is_family': False},
#     {'key': 'WO4', 'label': 'Wood Wood', 'is_family': False},
#     {'key': 'WOD', 'label': 'Woodbird', 'is_family': False},
#     {'key': 'WR1',
#      'label': 'Wrangler',
#      'family_id': 'WR00',
#      'is_family': False},
#     {'key': 'YE1', 'label': 'Yellow Cab', 'is_family': False},
#     {'key': 'YE9', 'label': 'YETI', 'is_family': False},
#     {'key': 'YO4', 'label': 'YMC You Must Create', 'is_family': False},
#     {'key': 'YO8', 'label': 'YOU & OIL', 'is_family': False},
#     {'key': 'YOA', 'label': 'Young and Reckless', 'is_family': False},
#     {'key': 'YT1',
#      'label': 'Your Turn Active',
#      'family_id': 'YOUR',
#      'is_family': False},
#     {'key': 'YOUR', 'label': 'YOURTURN', 'is_family': True},
#     {'key': 'YO1',
#      'label': 'YOURTURN',
#      'family_id': 'YOUR',
#      'is_family': False},
#     {'key': 'Z21',
#      'label': 'Zadig & Voltaire',
#      'family_id': 'ZA00',
#      'is_family': False},
#     {'key': 'ZA8',
#      'label': 'Zalando Essentials',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'ZED', 'label': 'Zew for Men', 'is_family': False},
#     {'key': 'Z10', 'label': 'Ziener', 'is_family': False},
#     {'key': 'ZI1', 'label': 'Zign', 'family_id': 'ZIGN', 'is_family': False},
#     {'key': 'ZW1', 'label': 'Zwilling', 'is_family': False},
#     {'key': '47B', 'label': "'47", 'is_family': False},
#     {'key': '111', 'label': '11 DEGREES', 'is_family': False},
#     {'key': '190', 'label': '1904', 'is_family': False},
#     {'key': '310', 'label': '3.1 Phillip Lim', 'is_family': False},
#     {'key': '7F1', 'label': '7 for all mankind', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 3.89,
#     'max': 1919.95,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'pure_cashmere', 'label': 'cachemire (100%)'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'CHECKERED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'FLORAL', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'STRIPED', 'label': 'rayures'},
#     {'key': 'POLKA_DOT', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'lengths',
#    'label': 'Longueur',
#    'url_key': 'length',
#    'kind': 'values',
#    'values': [{'key': '26', 'label': '26'},
#     {'key': '28', 'label': '28'},
#     {'key': '29', 'label': '29'},
#     {'key': '3/4', 'label': '3/4'},
#     {'key': '30', 'label': '30'},
#     {'key': '31', 'label': '31'},
#     {'key': '32', 'label': '32'},
#     {'key': '33', 'label': '33'},
#     {'key': '34', 'label': '34'},
#     {'key': '35', 'label': '35'},
#     {'key': '36', 'label': '36'},
#     {'key': '38', 'label': '38'},
#     {'key': '40', 'label': '40'},
#     {'key': '44', 'label': '44'},
#     {'key': '46', 'label': '46'},
#     {'key': '48', 'label': '48'},
#     {'key': '50', 'label': '50'},
#     {'key': '7/8', 'label': '7/8'},
#     {'key': 'courte', 'label': 'courte'},
#     {'key': 'extra courte', 'label': 'extra courte'},
#     {'key': 'extra longue', 'label': 'extra longue'},
#     {'key': "Jusqu'aux genoux", 'label': "Jusqu'aux genoux"},
#     {'key': 'longue', 'label': 'longue'},
#     {'key': 'Longueur mi-cuisse', 'label': 'Longueur mi-cuisse'},
#     {'key': 'Longueur midi', 'label': 'Longueur midi'},
#     {'key': 'Moyenne', 'label': 'Moyenne'},
#     {'key': 'normale', 'label': 'normale'},
#     {'key': 'socquettes', 'label': 'socquettes'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 51343,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '9191',
#    'url_key': 'promo-homme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-homme/',
#    'children': [{'label': 'Vêtements',
#      'id': '9205',
#      'url_key': 'promo-mode-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-homme/',
#      'children': [],
#      'article_count': 36674},
#     {'label': 'Chaussures',
#      'id': '9192',
#      'url_key': 'promo-chaussures-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-homme/',
#      'children': [],
#      'article_count': 9787},
#     {'label': 'Sport',
#      'id': '13690',
#      'url_key': 'promo-sport-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-homme/',
#      'children': [],
#      'article_count': 6161},
#     {'label': 'Accessoires',
#      'id': '9222',
#      'url_key': 'promo-accessoires-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-homme/',
#      'children': [],
#      'article_count': 4572},
#     {'label': 'Luxe',
#      'id': '13825',
#      'url_key': 'promo-luxe-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-homme/',
#      'children': [],
#      'article_count': 4052},
#     {'label': 'Beauté',
#      'id': '13865',
#      'url_key': 'beaute-homme-soins-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-homme-soins-promo/',
#      'children': [],
#      'article_count': 205}],
#    'article_count': 51351}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Homme',
#      'url_key': 'homme',
#      'full_url': '/homme/'},
#     {'label': 'Soldes',
#      'url_key': 'promo-homme',
#      'full_url': '/promo-homme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-homme',
#       'url_key': 'promo-homme',
#       'label': 'Soldes',
#       'seo_label': 'Promotions homme',
#       'reset_url': '/',
#       'id': '9191'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-homme/',
#   'reset_url': '/promo-homme/',
#   'app_url': '?urlKey=promo-homme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-homme',
#     'url_key': 'promo-homme',
#     'label': 'Soldes',
#     'seo_label': 'Promotions homme',
#     'reset_url': '/',
#     'id': '9191'}]},
#  'selectedFilters': {'categories': ['promo-homme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': 'Offrez-vous les tendances de la mode actuelle à prix réduits. Des costumes élégants aux baskets décontractées et lunettes de soleil tendances de marques célèbres, les articles en promo pour homme vous attendent',
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)
flattened_data
flattened_data["articles"]
flattened_data.articles[0]
articles = json_normalize(flattened_data.articles[0])   
articles.head()
# Out:
#              sku                                               name  \
# 0  TI112C04A-702           6 INCH PREMIUM - Bottes de neige - wheat
# 1  GA322S02Y-A11  MEDIUM SHIELD HOODIE - Sweat à capuche - eggshell
# 2  1MI52F01P-O11  TALL CARD CASE - Étui pour cartes de visite - ...
# 3  AD115B01K-A12  STAN SMITH STREETWEAR-STYLE SHOES - Baskets ba...
# 4  N1242E0W3-N12  PANT TAPER - Pantalon de survêtement - cargo k...
#
#                                                sizes  \
# 0  [40, 41, 41.5, 42, 43, 43.5, 44, 44.5, 45, 45....
# 1                        [XS, S, M, L, XL, XXL, 3XL]
# 2                                         [One Size]
# 3  [36, 38, 40, 42, 44, 46, 48, 50, 36 2/3, 37 1/...
# 4                                         [S, L, XL]
#
#                                              url_key  \
# 0  timberland-6-inch-premium-boots-a-lacets-marro...
# 1  gant-medium-shield-hoodie-sweatshirt-ga322s02y...
# 2  michael-kors-tall-card-case-etui-pour-cartes-d...
# 3  adidas-originals-stan-smith-baskets-basses-ad1...
# 4  nike-performance-pant-taper-pantalon-de-survet...
#
#                                                media        brand_name  \
# 0  [{'path': 'TI/11/2C/04/A7/02/TI112C04A-702@19....        Timberland
# 1  [{'path': 'GA/32/2S/02/YA/11/GA322S02Y-A11@4.j...              GANT
# 2  [{'path': '1M/I5/2F/01/PO/11/1MI52F01P-O11@8.j...      Michael Kors
# 3  [{'path': 'AD/11/5B/01/KA/12/AD115B01K-A12@12....  adidas Originals
# 4  [{'path': 'N1/24/2E/0W/3N/12/N1242E0W3-N12@9.j...  Nike Performance
#
#    is_premium                                    family_articles  \
# 0       False  [{'sku': 'TI112C04A-702', 'url_key': 'timberla...
# 1       False  [{'sku': 'GA322S02Y-A11', 'url_key': 'gant-med...
# 2       False  [{'sku': '1MI52F01P-O11', 'url_key': 'michael-...
# 3       False  [{'sku': 'AD115B01K-A12', 'url_key': 'adidas-o...
# 4       False  [{'sku': 'N1242E0W3-N12', 'url_key': 'nike-per...
#
#                                                flags product_group  ...  \
# 0  [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe  ...
# 1  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing  ...
# 2  [{'key': 'discountRate', 'value': '-60%', 'tra...   accessoires  ...
# 3  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe  ...
# 4  [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing  ...
#
#   price.original price.promotional price.has_different_prices  \
# 0       219,95 €          175,95 €                      False
# 1        99,95 €           89,95 €                      False
# 2        59,95 €           23,95 €                      False
# 3        94,95 €           85,45 €                      False
# 4        42,95 €           36,45 €                       True
#
#    price.has_different_original_prices  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                    True
#
#    price.has_discount_on_selected_sizes_only  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#         tracking_information.metrigo_impression_urls  \
# 0  [https://ccp-et.metrigo.zalan.do/event/sbv?z=c...
# 1  [https://ccp-et.metrigo.zalan.do/event/sbv?z=c...
# 2  [https://ccp-et.metrigo.zalan.do/event/sbv?z=c...
# 3                                                NaN
# 4                                                NaN
#
#               tracking_information.impression_beacon  \
# 0  https://ccp-et.metrigo.zalan.do/event/sbv?z=c6...
# 1  https://ccp-et.metrigo.zalan.do/event/sbv?z=c6...
# 2  https://ccp-et.metrigo.zalan.do/event/sbv?z=c6...
# 3                                                NaN
# 4                                                NaN
#
#   tracking_information.source outfits
# 0                         ccp     NaN
# 1                         ccp     NaN
# 2                         ccp     NaN
# 3                         NaN     NaN
# 4                         NaN     NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# 4. Find out the total page count in the 1st page data.

# %%
page_count = results["pagination"]["page_count"] 
page_count
# Out:
# 612

# %% [markdown]
# 5. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.

# %%
data = pd.DataFrame()

for page in range(page_count):
    url="https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity"
    response = requests.get(url, headers = headers) 
    results = response.json()
    flattened_data2 = json_normalize(results)
    flattened_data2 = json_normalize(flattened_data2.articles[0]) 
    flattened_data.append(flattened_data2)
    data = data.append(flattened_data2,sort=False)
# Out:
# C:\Users\Miguel\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [markdown]
# 6. Print and review the data you obtained.

# %%
data.head()
# Out:
#              sku                                               name  \
# 0  PO222D0IG-A11                 NATURAL SLIM FIT - Chemise - white
# 1  N1242A1R6-C12  AIR MAX ALPHA TRAINER 2 - Chaussures d'entraîn...
# 2  C1422E028-K11  BARNES PANT - Pantalon de survêtement - dark n...
# 3  PO222P04J-G11            SLIM SHORT SLEEVE - Polo - classic wine
# 4  C1422O060-K11                  MONUMENT - T-shirt imprimé - blue
#
#                                         sizes  \
# 0                                [M, XL, XXL]
# 1  [38.5, 39, 40, 40.5, 41, 42, 44, 44.5, 45]
# 2                                 [S, L, XXL]
# 3                                [M, XL, XXL]
# 4                           [XS, S, M, L, XL]
#
#                                              url_key  \
# 0  polo-ralph-lauren-natural-slim-fit-chemise-whi...
# 1  nike-performance-air-max-alpha-trainer-2-chaus...
# 2  carhartt-wip-barnes-pant-pantalon-de-surveteme...
# 3      polo-ralph-lauren-slim-fit-polo-po222p04j-g11
# 4  carhartt-wip-monument-t-shirt-imprime-c1422o06...
#
#                                                media         brand_name  \
# 0  [{'path': 'PO/22/2D/0I/GA/11/PO222D0IG-A11@9.j...  Polo Ralph Lauren
# 1  [{'path': 'N1/24/2A/1R/6C/12/N1242A1R6-C12@2.j...   Nike Performance
# 2  [{'path': 'C1/42/2E/02/8K/11/C1422E028-K11@6.j...       Carhartt WIP
# 3  [{'path': 'PO/22/2P/04/JG/11/PO222P04J-G11@8.j...  Polo Ralph Lauren
# 4  [{'path': 'C1/42/2O/06/0K/11/C1422O060-K11@7.j...       Carhartt WIP
#
#    is_premium                                    family_articles  \
# 0        True  [{'sku': 'PO222D0IG-A11', 'url_key': 'polo-ral...
# 1       False  [{'sku': 'N1242A1R6-C12', 'url_key': 'nike-per...
# 2       False  [{'sku': 'C1422E028-K11', 'url_key': 'carhartt...
# 3        True  [{'sku': 'PO222P04J-G11', 'url_key': 'polo-ral...
# 4       False  [{'sku': 'C1422O060-K11', 'url_key': 'carhartt...
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 1  [{'key': 'discountRate', 'value': 'Jusqu’à -20...          shoe
# 2  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 3  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
#
#   delivery_promises price.original price.promotional  \
# 0                []        99,95 €           79,95 €
# 1                []        79,95 €           63,95 €
# 2                []        89,95 €           71,95 €
# 3                []       109,95 €           87,95 €
# 4                []        34,95 €           27,95 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                       False                                False
# 1                        True                                False
# 2                       False                                False
# 3                       False                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#                                              outfits amount price.base_price
# 0                                                NaN    NaN              NaN
# 1                                                NaN    NaN              NaN
# 2  [{'id': 'n5uzd__ETt6', 'url_key': '/outfits/n5...    NaN              NaN
# 3                                                NaN    NaN              NaN
# 4                                                NaN    NaN              NaN

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %% [markdown]
# 1. The trending brand.

# %%
Trending_brand = pd.DataFrame(data["brand_name"].value_counts())
Trending_brand
# Out:
#                       brand_name
# Nike Performance            5664
# Carhartt WIP                4392
# Pier One                    4150
# Jack & Jones                3818
# Polo Ralph Lauren           3781
# Nike Sportswear             3471
# Levi's®                     2642
# Tommy Jeans                 1600
# Lacoste                     1516
# BOSS                        1394
# adidas Originals            1302
# HUGO                        1178
# adidas Performance           921
# Tommy Hilfiger               921
# G-Star                       917
# Zalando Essentials           891
# YOURTURN                     848
# Only & Sons                  766
# Calvin Klein Jeans           717
# Lacoste Sport                614
# New Balance                  614
# Timberland                   612
# Superdry                     610
# Michael Kors                 596
# Hollister Co.                516
# INDICODE JEANS               343
# Superga                      307
# PULL&BEAR                    307
# LTB                          305
# Converse                     305
# Key Largo                    305
# Napapijri                    305
# Benetton                     305
# Porsche Design               305
# Jack & Jones PREMIUM         305
# The North Face               305
# Geox                         305
# edc by Esprit                305
# Esprit                       305
# Quiksilver                   305
# Barber Pro                   305
# Esprit Collection            305
# Pepe Jeans                   304
# Isaac Dewhirst               280
# GANT                         273
# Brave Soul                   269
# Versace                      236
# Under Armour                 179
# Champion                     154
# Hi-Tec                        35

# %% [markdown]
# 2. The product(s) with the highest discount.

# %%
def cleaning_time(data, series):
    data[series] = [product.strip("€").strip() for product in data[series]]
    data[series] = data[series].str.replace(',','.')
    data[series] = pd.to_numeric(data[series],errors="coerce",downcast="float")

cleaning_time(data,"price.original")
cleaning_time(data,"price.promotional")

# %%
data["discount"] = data["price.original"] - data["price.promotional"]

# %%
data = data.sort_values(by=["discount"], ascending=False)
data[["brand_name","name","discount"]].head()
# Out:
#    brand_name                  name  discount
# 57       BOSS  Portefeuille - black     171.0
# 58       BOSS  Portefeuille - black     171.0
# 65       BOSS  Portefeuille - black     171.0
# 66       BOSS  Portefeuille - black     171.0
# 58       BOSS  Portefeuille - black     171.0

# %% [markdown]
# 3. The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
sum_of_discounts = data["price.promotional"].sum() / data["price.original"].sum()
sum_of_discounts
# Out:
# 0.7122527
